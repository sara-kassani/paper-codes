# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14319549001551669421,
#  name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 3594882004302030367
#  physical_device_desc: "device: XLA_CPU device",
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15695549568
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 13425479618213371515
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0",
#  name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 2751610729638603086
#  physical_device_desc: "device: XLA_GPU device"]

# %%
# from hyperopt import fmin, tpe, hp, STATUS_OK, Trials, partial, rand, space_eval
# from sklearn.metrics import log_loss
import sys
# import time
import math
import os
import pandas as pd
# from keras.callbacks import EarlyStopping
import numpy as np
# from glob import glob
# import cv2
# import skimage
# from skimage.transform import resize
from keras.utils.np_utils import to_categorical
# import keras
# from keras import layers
# from keras import models
# from keras import optimizers
# from keras.models import load_model
# import keras.callbacks as kcall
from keras.optimizers import Adam, RMSprop,SGD
from keras.models import Model
from keras.models import Sequential
from keras.layers import Flatten, Dense, Activation, Dropout, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, Input,concatenate
# from keras.applications.xception import Xception, preprocess_input
from keras.preprocessing.image import ImageDataGenerator
# from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint
# from keras.applications.vgg19 import VGG19
from keras.regularizers import l2, l1

import matplotlib.pyplot as plt
# from keras.layers import Input, concatenate
# from keras import optimizers, metrics, models
# from keras.layers import Input, Flatten, Dense

# %matplotlib inline

# %%
import keras
import tensorflow as tf

print("Keras Version", keras.__version__)
print("tensorflow Version", tf.__version__)
# print("dim_ordering:", K.image_dim_ordering())
# Out:
# Keras Version 2.4.3
# tensorflow Version 2.3.0

# %%
batch_size = 32
img_height, img_width = 512, 512
input_shape = (img_height, img_width, 3)
epochs = 1000

# %%
print(os.listdir("../input/data-pig/"))
# Out:
# ['train', 'test']

# %%
# print(os.listdir("../input/full-keras-pretrained-no-top"))

# %%
train_dir = '../input/data-pig/train/'
test_dir = '../input/data-pig/test/'

# %%
random_seed = np.random.seed(1142)

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True,
    validation_split= 0.25,
    zoom_range=0.2,
    shear_range=0.2)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    seed = random_seed,
    shuffle = False,
    subset = 'training',
    class_mode='categorical')

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    seed = random_seed,
    shuffle = False,
    subset = 'validation',
    class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1. / 255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    seed = random_seed,
    shuffle = False,
    class_mode='categorical')
# Out:
# Found 7556 images belonging to 4 classes.
# Found 2517 images belonging to 4 classes.
# Found 1776 images belonging to 4 classes.

# %%
nb_train_samples = len(train_generator.filenames)
nb_validation_samples = len(validation_generator.filenames)
nb_test_samples = len(test_generator.filenames)

predict_size_train = int(math.ceil(nb_train_samples / batch_size))
predict_size_validation = int(math.ceil(nb_validation_samples / batch_size))
predict_size_test = int(math.ceil(nb_test_samples / batch_size))

num_classes = len(train_generator.class_indices)

print("nb_train_samples:", nb_train_samples)
print("nb_validation_samples:", nb_validation_samples)
print("nb_test_samples:", nb_test_samples)

print("\npredict_size_train:", predict_size_train)
print("predict_size_validation:", predict_size_validation)
print("predict_size_test:", predict_size_test)

print("\n num_classes:", num_classes)
# Out:
# nb_train_samples: 7556
# nb_validation_samples: 2517
# nb_test_samples: 1776
#
# predict_size_train: 237
# predict_size_validation: 79
# predict_size_test: 56
#
#  num_classes: 4

# %%
vgg19_weights ="../input/full-keras-pretrained-no-top/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5"
inception_weights ="../input/full-keras-pretrained-no-top//inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5"
# vgg16_weights ="../input/full-keras-pretrained-no-top/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5"
# denseNet201_weights ="../input/full-keras-pretrained-no-top/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5"
# denseNet121_weights ="../input/full-keras-pretrained-no-top/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5"
# resenet50_weights ="../input/full-keras-pretrained-no-top/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5"
# inception_resnet_v2_weights ="../input/full-keras-pretrained-no-top/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5"
# nasnet_weights ="../input/full-keras-pretrained-no-top/nasnet_large_no_top.h5"
# nasnet_mobile_weights ="../input/full-keras-pretrained-no-top/nasnet_mobile_no_top.h5"
# mobilenet_weights ="../input/full-keras-pretrained-no-top/mobilenet_1_0_224_tf_no_top.h5"

# %%
from keras.applications.vgg19 import VGG19
from keras.applications.inception_v3 import InceptionV3
# from keras.applications.vgg16 import VGG16
# from keras.applications.xception import Xception, preprocess_input
# from keras.applications import DenseNet201
# from keras.applications import DenseNet121
# from keras.applications import ResNet50
# from keras.applications.inception_resnet_v2 import InceptionResNetV2
# from keras.applications import NASNetLarge, NASNetMobile
# from keras.applications import MobileNet

input_tensor = Input(shape = input_shape)  

base_model1=InceptionV3(weights=inception_weights, include_top=False, pooling = "avg")

bottleneck_final_model = base_model1

# %%
# for i, layer in enumerate(model.layers):
#     print(i, layer.name)

# %%
os.mkdir("extracted_features")
extracted_features_dir = "extracted_features/" 
model_name = "inceotionV3_densenet201_descriptors"

# %%
bottleneck_features_train = bottleneck_final_model.predict_generator(train_generator, predict_size_train)
np.save(extracted_features_dir+'bottleneck_features_train_'+model_name+'.npy', bottleneck_features_train)

# %%
bottleneck_features_validation = bottleneck_final_model.predict_generator(validation_generator, predict_size_validation)
np.save(extracted_features_dir+'bottleneck_features_validation_'+model_name+'.npy', bottleneck_features_validation)

# %%
bottleneck_features_test = bottleneck_final_model.predict_generator(test_generator, predict_size_test)
np.save(extracted_features_dir+'bottleneck_features_test_'+model_name+'.npy', bottleneck_features_test)

# %%
# import tensorflow as tf
# from keras.backend.tensorflow_backend import get_session
# from keras.backend.tensorflow_backend import clear_session
# from keras.backend.tensorflow_backend import set_session

# def reset_keras_tf_session():
#     """
#     this function clears the gpu memory and set the 
#     tf session to not use the whole gpu
#     """
#     sess = get_session()
#     clear_session()
#     sess.close()
#     sess = get_session()

#     config = tf.ConfigProto()
#     config.gpu_options.allow_growth = True
#     set_session(tf.Session(config=config))


# reset_keras_tf_session()

# %%
train_data = np.load(extracted_features_dir+'bottleneck_features_train_'+model_name+'.npy')
validation_data = np.load(extracted_features_dir+'bottleneck_features_validation_'+model_name+'.npy')
test_data = np.load(extracted_features_dir+'bottleneck_features_test_'+model_name+'.npy')

train_labels = train_generator.classes
train_labels = to_categorical(train_labels, num_classes=num_classes)

validation_labels = validation_generator.classes
validation_labels = to_categorical(validation_labels, num_classes=num_classes)

test_labels = test_generator.classes
test_labels = to_categorical(test_labels, num_classes=num_classes)

# %%
model = Sequential()
model.add(Dense(512, activation="selu", kernel_regularizer=l2(1e-06), bias_regularizer=l2(1e-05), activity_regularizer=l1(0.0001)))

model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

adam_opt=Adam(lr = 1e-06, beta_1=0.7, beta_2=0.5)
model.compile(optimizer=adam_opt, loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(validation_data, validation_labels),
                    verbose= 2)
# Out:
# Epoch 1/1000
# 237/237 - 1s - loss: 1.5994 - accuracy: 0.2942 - val_loss: 1.3238 - val_accuracy: 0.3842
# Epoch 2/1000
# 237/237 - 1s - loss: 1.4037 - accuracy: 0.3743 - val_loss: 1.2433 - val_accuracy: 0.4823
# Epoch 3/1000
# 237/237 - 1s - loss: 1.3050 - accuracy: 0.4084 - val_loss: 1.1639 - val_accuracy: 0.5459
# Epoch 4/1000
# 237/237 - 1s - loss: 1.1899 - accuracy: 0.4815 - val_loss: 1.0896 - val_accuracy: 0.6544
# Epoch 5/1000
# 237/237 - 1s - loss: 1.0921 - accuracy: 0.5476 - val_loss: 1.0195 - val_accuracy: 0.7239
# Epoch 6/1000
# 237/237 - 1s - loss: 1.0006 - accuracy: 0.6153 - val_loss: 0.9560 - val_accuracy: 0.7970
# Epoch 7/1000
# 237/237 - 1s - loss: 0.9126 - accuracy: 0.6777 - val_loss: 0.8905 - val_accuracy: 0.8347
# Epoch 8/1000
# 237/237 - 1s - loss: 0.8217 - accuracy: 0.7440 - val_loss: 0.8347 - val_accuracy: 0.8768
# Epoch 9/1000
# 237/237 - 1s - loss: 0.7585 - accuracy: 0.7881 - val_loss: 0.7784 - val_accuracy: 0.8959
# Epoch 10/1000
# 237/237 - 1s - loss: 0.6864 - accuracy: 0.8314 - val_loss: 0.7254 - val_accuracy: 0.9110
# Epoch 11/1000
# 237/237 - 1s - loss: 0.6234 - accuracy: 0.8763 - val_loss: 0.6853 - val_accuracy: 0.9130
# Epoch 12/1000
# 237/237 - 1s - loss: 0.5609 - accuracy: 0.9013 - val_loss: 0.6408 - val_accuracy: 0.9205
# Epoch 13/1000
# 237/237 - 1s - loss: 0.5130 - accuracy: 0.9234 - val_loss: 0.6056 - val_accuracy: 0.9166
# Epoch 14/1000
# 237/237 - 1s - loss: 0.4683 - accuracy: 0.9383 - val_loss: 0.5554 - val_accuracy: 0.9396
# Epoch 15/1000
# 237/237 - 1s - loss: 0.4222 - accuracy: 0.9528 - val_loss: 0.5314 - val_accuracy: 0.9305
# Epoch 16/1000
# 237/237 - 1s - loss: 0.3853 - accuracy: 0.9614 - val_loss: 0.4959 - val_accuracy: 0.9384
# Epoch 17/1000
# 237/237 - 1s - loss: 0.3533 - accuracy: 0.9660 - val_loss: 0.4789 - val_accuracy: 0.9289
# Epoch 18/1000
# 237/237 - 1s - loss: 0.3188 - accuracy: 0.9733 - val_loss: 0.4515 - val_accuracy: 0.9305
# Epoch 19/1000
# 237/237 - 1s - loss: 0.2926 - accuracy: 0.9776 - val_loss: 0.4222 - val_accuracy: 0.9408
# Epoch 20/1000
# 237/237 - 1s - loss: 0.2711 - accuracy: 0.9799 - val_loss: 0.4112 - val_accuracy: 0.9321
# Epoch 21/1000
# 237/237 - 1s - loss: 0.2488 - accuracy: 0.9811 - val_loss: 0.3863 - val_accuracy: 0.9392
# Epoch 22/1000
# 237/237 - 1s - loss: 0.2276 - accuracy: 0.9844 - val_loss: 0.3613 - val_accuracy: 0.9487
# Epoch 23/1000
# 237/237 - 1s - loss: 0.2102 - accuracy: 0.9849 - val_loss: 0.3441 - val_accuracy: 0.9539
# Epoch 24/1000
# 237/237 - 1s - loss: 0.1957 - accuracy: 0.9860 - val_loss: 0.3282 - val_accuracy: 0.9519
# Epoch 25/1000
# 237/237 - 1s - loss: 0.1805 - accuracy: 0.9880 - val_loss: 0.3105 - val_accuracy: 0.9579
# Epoch 26/1000
# 237/237 - 1s - loss: 0.1694 - accuracy: 0.9885 - val_loss: 0.3088 - val_accuracy: 0.9491
# Epoch 27/1000
# 237/237 - 1s - loss: 0.1558 - accuracy: 0.9905 - val_loss: 0.2933 - val_accuracy: 0.9551
# Epoch 28/1000
# 237/237 - 1s - loss: 0.1457 - accuracy: 0.9909 - val_loss: 0.2707 - val_accuracy: 0.9674
# Epoch 29/1000
# 237/237 - 1s - loss: 0.1380 - accuracy: 0.9906 - val_loss: 0.2729 - val_accuracy: 0.9583
# Epoch 30/1000
# 237/237 - 1s - loss: 0.1271 - accuracy: 0.9917 - val_loss: 0.2454 - val_accuracy: 0.9730
# Epoch 31/1000
# 237/237 - 1s - loss: 0.1197 - accuracy: 0.9922 - val_loss: 0.2469 - val_accuracy: 0.9682
# Epoch 32/1000
# 237/237 - 1s - loss: 0.1139 - accuracy: 0.9927 - val_loss: 0.2351 - val_accuracy: 0.9698
# Epoch 33/1000
# 237/237 - 1s - loss: 0.1072 - accuracy: 0.9922 - val_loss: 0.2282 - val_accuracy: 0.9698
# Epoch 34/1000
# 237/237 - 1s - loss: 0.1027 - accuracy: 0.9921 - val_loss: 0.2183 - val_accuracy: 0.9754
# Epoch 35/1000
# 237/237 - 1s - loss: 0.0957 - accuracy: 0.9946 - val_loss: 0.2154 - val_accuracy: 0.9710
# Epoch 36/1000
# 237/237 - 1s - loss: 0.0920 - accuracy: 0.9923 - val_loss: 0.2023 - val_accuracy: 0.9781
# Epoch 37/1000
# 237/237 - 1s - loss: 0.0868 - accuracy: 0.9942 - val_loss: 0.2012 - val_accuracy: 0.9754
# Epoch 38/1000
# 237/237 - 1s - loss: 0.0826 - accuracy: 0.9947 - val_loss: 0.1882 - val_accuracy: 0.9789
# Epoch 39/1000
# 237/237 - 1s - loss: 0.0788 - accuracy: 0.9940 - val_loss: 0.1890 - val_accuracy: 0.9774
# Epoch 40/1000
# 237/237 - 1s - loss: 0.0745 - accuracy: 0.9946 - val_loss: 0.1806 - val_accuracy: 0.9785
# Epoch 41/1000
# 237/237 - 1s - loss: 0.0724 - accuracy: 0.9939 - val_loss: 0.1865 - val_accuracy: 0.9758
# Epoch 42/1000
# 237/237 - 1s - loss: 0.0685 - accuracy: 0.9954 - val_loss: 0.1680 - val_accuracy: 0.9805
# Epoch 43/1000
# 237/237 - 1s - loss: 0.0657 - accuracy: 0.9955 - val_loss: 0.1760 - val_accuracy: 0.9774
# Epoch 44/1000
# 237/237 - 1s - loss: 0.0636 - accuracy: 0.9955 - val_loss: 0.1548 - val_accuracy: 0.9817
# Epoch 45/1000
# 237/237 - 1s - loss: 0.0610 - accuracy: 0.9950 - val_loss: 0.1539 - val_accuracy: 0.9817
# Epoch 46/1000
# 237/237 - 1s - loss: 0.0582 - accuracy: 0.9960 - val_loss: 0.1561 - val_accuracy: 0.9801
# Epoch 47/1000
# 237/237 - 1s - loss: 0.0565 - accuracy: 0.9956 - val_loss: 0.1501 - val_accuracy: 0.9805
# Epoch 48/1000
# 237/237 - 1s - loss: 0.0542 - accuracy: 0.9962 - val_loss: 0.1435 - val_accuracy: 0.9825
# Epoch 49/1000
# 237/237 - 1s - loss: 0.0526 - accuracy: 0.9964 - val_loss: 0.1418 - val_accuracy: 0.9821
# Epoch 50/1000
# 237/237 - 1s - loss: 0.0511 - accuracy: 0.9959 - val_loss: 0.1378 - val_accuracy: 0.9833
# Epoch 51/1000
# 237/237 - 1s - loss: 0.0491 - accuracy: 0.9964 - val_loss: 0.1335 - val_accuracy: 0.9837
# Epoch 52/1000
# 237/237 - 1s - loss: 0.0476 - accuracy: 0.9966 - val_loss: 0.1319 - val_accuracy: 0.9841
# Epoch 53/1000
# 237/237 - 1s - loss: 0.0472 - accuracy: 0.9962 - val_loss: 0.1360 - val_accuracy: 0.9825
# Epoch 54/1000
# 237/237 - 1s - loss: 0.0447 - accuracy: 0.9970 - val_loss: 0.1257 - val_accuracy: 0.9841
# Epoch 55/1000
# 237/237 - 1s - loss: 0.0444 - accuracy: 0.9963 - val_loss: 0.1271 - val_accuracy: 0.9837
# Epoch 56/1000
# 237/237 - 1s - loss: 0.0425 - accuracy: 0.9966 - val_loss: 0.1252 - val_accuracy: 0.9833
# Epoch 57/1000
# 237/237 - 1s - loss: 0.0413 - accuracy: 0.9970 - val_loss: 0.1202 - val_accuracy: 0.9841
# Epoch 58/1000
# 237/237 - 1s - loss: 0.0405 - accuracy: 0.9971 - val_loss: 0.1252 - val_accuracy: 0.9825
# Epoch 59/1000
# 237/237 - 1s - loss: 0.0394 - accuracy: 0.9966 - val_loss: 0.1266 - val_accuracy: 0.9821
# Epoch 60/1000
# 237/237 - 1s - loss: 0.0379 - accuracy: 0.9978 - val_loss: 0.1114 - val_accuracy: 0.9877
# Epoch 61/1000
# 237/237 - 1s - loss: 0.0378 - accuracy: 0.9972 - val_loss: 0.1142 - val_accuracy: 0.9849
# Epoch 62/1000
# 237/237 - 1s - loss: 0.0367 - accuracy: 0.9968 - val_loss: 0.1127 - val_accuracy: 0.9845
# Epoch 63/1000
# 237/237 - 1s - loss: 0.0356 - accuracy: 0.9979 - val_loss: 0.1125 - val_accuracy: 0.9853
# Epoch 64/1000
# 237/237 - 1s - loss: 0.0351 - accuracy: 0.9968 - val_loss: 0.1068 - val_accuracy: 0.9873
# Epoch 65/1000
# 237/237 - 1s - loss: 0.0341 - accuracy: 0.9971 - val_loss: 0.1030 - val_accuracy: 0.9873
# Epoch 66/1000
# 237/237 - 1s - loss: 0.0332 - accuracy: 0.9980 - val_loss: 0.1076 - val_accuracy: 0.9861
# Epoch 67/1000
# 237/237 - 1s - loss: 0.0332 - accuracy: 0.9974 - val_loss: 0.1014 - val_accuracy: 0.9869
# Epoch 68/1000
# 237/237 - 1s - loss: 0.0324 - accuracy: 0.9971 - val_loss: 0.1009 - val_accuracy: 0.9869
# Epoch 69/1000
# 237/237 - 1s - loss: 0.0316 - accuracy: 0.9975 - val_loss: 0.1022 - val_accuracy: 0.9865
# Epoch 70/1000
# 237/237 - 1s - loss: 0.0310 - accuracy: 0.9976 - val_loss: 0.1009 - val_accuracy: 0.9873
# Epoch 71/1000
# 237/237 - 1s - loss: 0.0306 - accuracy: 0.9976 - val_loss: 0.0974 - val_accuracy: 0.9877
# Epoch 72/1000
# 237/237 - 1s - loss: 0.0297 - accuracy: 0.9976 - val_loss: 0.0908 - val_accuracy: 0.9893
# Epoch 73/1000
# 237/237 - 1s - loss: 0.0290 - accuracy: 0.9979 - val_loss: 0.0963 - val_accuracy: 0.9877
# Epoch 74/1000
# 237/237 - 1s - loss: 0.0292 - accuracy: 0.9979 - val_loss: 0.0968 - val_accuracy: 0.9861
# Epoch 75/1000
# 237/237 - 1s - loss: 0.0285 - accuracy: 0.9983 - val_loss: 0.0937 - val_accuracy: 0.9881
# Epoch 76/1000
# 237/237 - 1s - loss: 0.0277 - accuracy: 0.9985 - val_loss: 0.0905 - val_accuracy: 0.9885
# Epoch 77/1000
# 237/237 - 1s - loss: 0.0277 - accuracy: 0.9980 - val_loss: 0.0921 - val_accuracy: 0.9881
# Epoch 78/1000
# 237/237 - 1s - loss: 0.0265 - accuracy: 0.9981 - val_loss: 0.0919 - val_accuracy: 0.9881
# Epoch 79/1000
# 237/237 - 1s - loss: 0.0264 - accuracy: 0.9985 - val_loss: 0.0875 - val_accuracy: 0.9893
# Epoch 80/1000
# 237/237 - 1s - loss: 0.0262 - accuracy: 0.9980 - val_loss: 0.0887 - val_accuracy: 0.9881
# Epoch 81/1000
# 237/237 - 1s - loss: 0.0259 - accuracy: 0.9980 - val_loss: 0.0869 - val_accuracy: 0.9893
# Epoch 82/1000
# 237/237 - 1s - loss: 0.0256 - accuracy: 0.9979 - val_loss: 0.0813 - val_accuracy: 0.9893
# Epoch 83/1000
# 237/237 - 1s - loss: 0.0255 - accuracy: 0.9979 - val_loss: 0.0844 - val_accuracy: 0.9893
# Epoch 84/1000
# 237/237 - 1s - loss: 0.0249 - accuracy: 0.9985 - val_loss: 0.0807 - val_accuracy: 0.9897
# Epoch 85/1000
# 237/237 - 1s - loss: 0.0247 - accuracy: 0.9985 - val_loss: 0.0881 - val_accuracy: 0.9881
# Epoch 86/1000
# 237/237 - 1s - loss: 0.0239 - accuracy: 0.9989 - val_loss: 0.0793 - val_accuracy: 0.9897
# Epoch 87/1000
# 237/237 - 1s - loss: 0.0239 - accuracy: 0.9983 - val_loss: 0.0761 - val_accuracy: 0.9905
# Epoch 88/1000
# 237/237 - 1s - loss: 0.0237 - accuracy: 0.9985 - val_loss: 0.0769 - val_accuracy: 0.9905
# Epoch 89/1000
# 237/237 - 1s - loss: 0.0232 - accuracy: 0.9985 - val_loss: 0.0782 - val_accuracy: 0.9897
# Epoch 90/1000
# 237/237 - 1s - loss: 0.0234 - accuracy: 0.9985 - val_loss: 0.0800 - val_accuracy: 0.9893
# Epoch 91/1000
# 237/237 - 1s - loss: 0.0231 - accuracy: 0.9983 - val_loss: 0.0774 - val_accuracy: 0.9893
# Epoch 92/1000
# 237/237 - 1s - loss: 0.0228 - accuracy: 0.9983 - val_loss: 0.0808 - val_accuracy: 0.9893
# Epoch 93/1000
# 237/237 - 1s - loss: 0.0225 - accuracy: 0.9985 - val_loss: 0.0779 - val_accuracy: 0.9893
# Epoch 94/1000
# 237/237 - 1s - loss: 0.0227 - accuracy: 0.9981 - val_loss: 0.0736 - val_accuracy: 0.9901
# Epoch 95/1000
# 237/237 - 1s - loss: 0.0224 - accuracy: 0.9987 - val_loss: 0.0774 - val_accuracy: 0.9893
# Epoch 96/1000
# 237/237 - 1s - loss: 0.0218 - accuracy: 0.9985 - val_loss: 0.0715 - val_accuracy: 0.9901
# Epoch 97/1000
# 237/237 - 1s - loss: 0.0218 - accuracy: 0.9985 - val_loss: 0.0730 - val_accuracy: 0.9901
# Epoch 98/1000
# 237/237 - 1s - loss: 0.0215 - accuracy: 0.9987 - val_loss: 0.0710 - val_accuracy: 0.9905
# Epoch 99/1000
# 237/237 - 1s - loss: 0.0209 - accuracy: 0.9988 - val_loss: 0.0689 - val_accuracy: 0.9909
# Epoch 100/1000
# 237/237 - 1s - loss: 0.0210 - accuracy: 0.9985 - val_loss: 0.0721 - val_accuracy: 0.9905
# Epoch 101/1000
# 237/237 - 1s - loss: 0.0206 - accuracy: 0.9987 - val_loss: 0.0679 - val_accuracy: 0.9905
# Epoch 102/1000
# 237/237 - 1s - loss: 0.0208 - accuracy: 0.9987 - val_loss: 0.0745 - val_accuracy: 0.9893
# Epoch 103/1000
# 237/237 - 1s - loss: 0.0206 - accuracy: 0.9987 - val_loss: 0.0734 - val_accuracy: 0.9897
# Epoch 104/1000
# 237/237 - 1s - loss: 0.0202 - accuracy: 0.9988 - val_loss: 0.0669 - val_accuracy: 0.9909
# Epoch 105/1000
# 237/237 - 1s - loss: 0.0202 - accuracy: 0.9987 - val_loss: 0.0650 - val_accuracy: 0.9909
# Epoch 106/1000
# 237/237 - 1s - loss: 0.0202 - accuracy: 0.9983 - val_loss: 0.0665 - val_accuracy: 0.9913
# Epoch 107/1000
# 237/237 - 1s - loss: 0.0198 - accuracy: 0.9989 - val_loss: 0.0709 - val_accuracy: 0.9897
# Epoch 108/1000
# 237/237 - 1s - loss: 0.0201 - accuracy: 0.9984 - val_loss: 0.0697 - val_accuracy: 0.9897
# Epoch 109/1000
# 237/237 - 1s - loss: 0.0197 - accuracy: 0.9988 - val_loss: 0.0662 - val_accuracy: 0.9913
# Epoch 110/1000
# 237/237 - 1s - loss: 0.0197 - accuracy: 0.9987 - val_loss: 0.0619 - val_accuracy: 0.9913
# Epoch 111/1000
# 237/237 - 1s - loss: 0.0191 - accuracy: 0.9988 - val_loss: 0.0662 - val_accuracy: 0.9913
# Epoch 112/1000
# 237/237 - 1s - loss: 0.0195 - accuracy: 0.9985 - val_loss: 0.0658 - val_accuracy: 0.9913
# Epoch 113/1000
# 237/237 - 1s - loss: 0.0190 - accuracy: 0.9989 - val_loss: 0.0656 - val_accuracy: 0.9913
# Epoch 114/1000
# 237/237 - 1s - loss: 0.0189 - accuracy: 0.9989 - val_loss: 0.0656 - val_accuracy: 0.9913
# Epoch 115/1000
# 237/237 - 1s - loss: 0.0189 - accuracy: 0.9988 - val_loss: 0.0620 - val_accuracy: 0.9913
# Epoch 116/1000
# 237/237 - 1s - loss: 0.0189 - accuracy: 0.9989 - val_loss: 0.0661 - val_accuracy: 0.9909
# Epoch 117/1000
# 237/237 - 1s - loss: 0.0190 - accuracy: 0.9988 - val_loss: 0.0633 - val_accuracy: 0.9913
# Epoch 118/1000
# 237/237 - 1s - loss: 0.0183 - accuracy: 0.9991 - val_loss: 0.0594 - val_accuracy: 0.9917
# Epoch 119/1000
# 237/237 - 1s - loss: 0.0185 - accuracy: 0.9988 - val_loss: 0.0632 - val_accuracy: 0.9909
# Epoch 120/1000
# 237/237 - 1s - loss: 0.0184 - accuracy: 0.9987 - val_loss: 0.0596 - val_accuracy: 0.9917
# Epoch 121/1000
# 237/237 - 1s - loss: 0.0184 - accuracy: 0.9989 - val_loss: 0.0609 - val_accuracy: 0.9913
# Epoch 122/1000
# 237/237 - 1s - loss: 0.0182 - accuracy: 0.9989 - val_loss: 0.0594 - val_accuracy: 0.9917
# Epoch 123/1000
# 237/237 - 1s - loss: 0.0177 - accuracy: 0.9989 - val_loss: 0.0609 - val_accuracy: 0.9913
# Epoch 124/1000
# 237/237 - 1s - loss: 0.0178 - accuracy: 0.9988 - val_loss: 0.0596 - val_accuracy: 0.9913
# Epoch 125/1000
# 237/237 - 1s - loss: 0.0181 - accuracy: 0.9989 - val_loss: 0.0592 - val_accuracy: 0.9917
# Epoch 126/1000
# 237/237 - 1s - loss: 0.0176 - accuracy: 0.9991 - val_loss: 0.0603 - val_accuracy: 0.9913
# Epoch 127/1000
# 237/237 - 1s - loss: 0.0179 - accuracy: 0.9992 - val_loss: 0.0579 - val_accuracy: 0.9917
# Epoch 128/1000
# 237/237 - 1s - loss: 0.0174 - accuracy: 0.9989 - val_loss: 0.0583 - val_accuracy: 0.9917
# Epoch 129/1000
# 237/237 - 1s - loss: 0.0173 - accuracy: 0.9989 - val_loss: 0.0609 - val_accuracy: 0.9905
# Epoch 130/1000
# 237/237 - 1s - loss: 0.0172 - accuracy: 0.9991 - val_loss: 0.0590 - val_accuracy: 0.9913
# Epoch 131/1000
# 237/237 - 1s - loss: 0.0176 - accuracy: 0.9989 - val_loss: 0.0573 - val_accuracy: 0.9917
# Epoch 132/1000
# 237/237 - 1s - loss: 0.0172 - accuracy: 0.9989 - val_loss: 0.0601 - val_accuracy: 0.9909
# Epoch 133/1000
# 237/237 - 1s - loss: 0.0171 - accuracy: 0.9991 - val_loss: 0.0566 - val_accuracy: 0.9909
# Epoch 134/1000
# 237/237 - 1s - loss: 0.0170 - accuracy: 0.9988 - val_loss: 0.0551 - val_accuracy: 0.9921
# Epoch 135/1000
# 237/237 - 1s - loss: 0.0168 - accuracy: 0.9989 - val_loss: 0.0579 - val_accuracy: 0.9905
# Epoch 136/1000
# 237/237 - 1s - loss: 0.0166 - accuracy: 0.9989 - val_loss: 0.0555 - val_accuracy: 0.9913
# Epoch 137/1000
# 237/237 - 1s - loss: 0.0167 - accuracy: 0.9991 - val_loss: 0.0548 - val_accuracy: 0.9913
# Epoch 138/1000
# 237/237 - 1s - loss: 0.0169 - accuracy: 0.9988 - val_loss: 0.0585 - val_accuracy: 0.9905
# Epoch 139/1000
# 237/237 - 1s - loss: 0.0169 - accuracy: 0.9989 - val_loss: 0.0544 - val_accuracy: 0.9913
# Epoch 140/1000
# 237/237 - 1s - loss: 0.0167 - accuracy: 0.9991 - val_loss: 0.0563 - val_accuracy: 0.9913
# Epoch 141/1000
# 237/237 - 1s - loss: 0.0167 - accuracy: 0.9989 - val_loss: 0.0538 - val_accuracy: 0.9917
# Epoch 142/1000
# 237/237 - 1s - loss: 0.0167 - accuracy: 0.9991 - val_loss: 0.0551 - val_accuracy: 0.9917
# Epoch 143/1000
# 237/237 - 1s - loss: 0.0162 - accuracy: 0.9993 - val_loss: 0.0528 - val_accuracy: 0.9925
# Epoch 144/1000
# 237/237 - 1s - loss: 0.0166 - accuracy: 0.9988 - val_loss: 0.0567 - val_accuracy: 0.9905
# Epoch 145/1000
# 237/237 - 1s - loss: 0.0163 - accuracy: 0.9989 - val_loss: 0.0540 - val_accuracy: 0.9917
# Epoch 146/1000
# 237/237 - 1s - loss: 0.0160 - accuracy: 0.9992 - val_loss: 0.0525 - val_accuracy: 0.9925
# Epoch 147/1000
# 237/237 - 1s - loss: 0.0162 - accuracy: 0.9992 - val_loss: 0.0542 - val_accuracy: 0.9909
# Epoch 148/1000
# 237/237 - 1s - loss: 0.0159 - accuracy: 0.9992 - val_loss: 0.0527 - val_accuracy: 0.9917
# Epoch 149/1000
# 237/237 - 1s - loss: 0.0161 - accuracy: 0.9991 - val_loss: 0.0514 - val_accuracy: 0.9925
# Epoch 150/1000
# 237/237 - 1s - loss: 0.0161 - accuracy: 0.9991 - val_loss: 0.0515 - val_accuracy: 0.9925
# Epoch 151/1000
# 237/237 - 1s - loss: 0.0158 - accuracy: 0.9989 - val_loss: 0.0542 - val_accuracy: 0.9913
# Epoch 152/1000
# 237/237 - 1s - loss: 0.0157 - accuracy: 0.9992 - val_loss: 0.0517 - val_accuracy: 0.9921
# Epoch 153/1000
# 237/237 - 1s - loss: 0.0157 - accuracy: 0.9992 - val_loss: 0.0532 - val_accuracy: 0.9913
# Epoch 154/1000
# 237/237 - 1s - loss: 0.0157 - accuracy: 0.9992 - val_loss: 0.0509 - val_accuracy: 0.9925
# Epoch 155/1000
# 237/237 - 1s - loss: 0.0158 - accuracy: 0.9991 - val_loss: 0.0517 - val_accuracy: 0.9921
# Epoch 156/1000
# 237/237 - 1s - loss: 0.0157 - accuracy: 0.9993 - val_loss: 0.0503 - val_accuracy: 0.9925
# Epoch 157/1000
# 237/237 - 1s - loss: 0.0155 - accuracy: 0.9992 - val_loss: 0.0500 - val_accuracy: 0.9925
# Epoch 158/1000
# 237/237 - 1s - loss: 0.0154 - accuracy: 0.9992 - val_loss: 0.0522 - val_accuracy: 0.9917
# Epoch 159/1000
# 237/237 - 1s - loss: 0.0155 - accuracy: 0.9992 - val_loss: 0.0506 - val_accuracy: 0.9921
# Epoch 160/1000
# 237/237 - 1s - loss: 0.0153 - accuracy: 0.9992 - val_loss: 0.0486 - val_accuracy: 0.9936
# Epoch 161/1000
# 237/237 - 1s - loss: 0.0154 - accuracy: 0.9992 - val_loss: 0.0501 - val_accuracy: 0.9925
# Epoch 162/1000
# 237/237 - 1s - loss: 0.0154 - accuracy: 0.9992 - val_loss: 0.0500 - val_accuracy: 0.9925
# Epoch 163/1000
# 237/237 - 1s - loss: 0.0152 - accuracy: 0.9992 - val_loss: 0.0499 - val_accuracy: 0.9925
# Epoch 164/1000
# 237/237 - 1s - loss: 0.0151 - accuracy: 0.9993 - val_loss: 0.0523 - val_accuracy: 0.9913
# Epoch 165/1000
# 237/237 - 1s - loss: 0.0151 - accuracy: 0.9992 - val_loss: 0.0476 - val_accuracy: 0.9936
# Epoch 166/1000
# 237/237 - 1s - loss: 0.0152 - accuracy: 0.9995 - val_loss: 0.0486 - val_accuracy: 0.9928
# Epoch 167/1000
# 237/237 - 1s - loss: 0.0148 - accuracy: 0.9993 - val_loss: 0.0491 - val_accuracy: 0.9928
# Epoch 168/1000
# 237/237 - 1s - loss: 0.0149 - accuracy: 0.9992 - val_loss: 0.0507 - val_accuracy: 0.9913
# Epoch 169/1000
# 237/237 - 1s - loss: 0.0150 - accuracy: 0.9991 - val_loss: 0.0489 - val_accuracy: 0.9925
# Epoch 170/1000
# 237/237 - 1s - loss: 0.0148 - accuracy: 0.9993 - val_loss: 0.0469 - val_accuracy: 0.9936
# Epoch 171/1000
# 237/237 - 1s - loss: 0.0148 - accuracy: 0.9993 - val_loss: 0.0478 - val_accuracy: 0.9932
# Epoch 172/1000
# 237/237 - 1s - loss: 0.0146 - accuracy: 0.9991 - val_loss: 0.0497 - val_accuracy: 0.9913
# Epoch 173/1000
# 237/237 - 1s - loss: 0.0148 - accuracy: 0.9993 - val_loss: 0.0483 - val_accuracy: 0.9928
# Epoch 174/1000
# 237/237 - 1s - loss: 0.0148 - accuracy: 0.9993 - val_loss: 0.0464 - val_accuracy: 0.9936
# Epoch 175/1000
# 237/237 - 1s - loss: 0.0146 - accuracy: 0.9992 - val_loss: 0.0473 - val_accuracy: 0.9936
# Epoch 176/1000
# 237/237 - 1s - loss: 0.0144 - accuracy: 0.9996 - val_loss: 0.0466 - val_accuracy: 0.9936
# Epoch 177/1000
# 237/237 - 1s - loss: 0.0144 - accuracy: 0.9993 - val_loss: 0.0474 - val_accuracy: 0.9932
# Epoch 178/1000
# 237/237 - 1s - loss: 0.0146 - accuracy: 0.9993 - val_loss: 0.0470 - val_accuracy: 0.9928
# Epoch 179/1000
# 237/237 - 1s - loss: 0.0145 - accuracy: 0.9995 - val_loss: 0.0477 - val_accuracy: 0.9925
# Epoch 180/1000
# 237/237 - 1s - loss: 0.0146 - accuracy: 0.9993 - val_loss: 0.0485 - val_accuracy: 0.9921
# Epoch 181/1000
# 237/237 - 1s - loss: 0.0142 - accuracy: 0.9997 - val_loss: 0.0462 - val_accuracy: 0.9932
# Epoch 182/1000
# 237/237 - 1s - loss: 0.0144 - accuracy: 0.9993 - val_loss: 0.0474 - val_accuracy: 0.9928
# Epoch 183/1000
# 237/237 - 1s - loss: 0.0146 - accuracy: 0.9993 - val_loss: 0.0462 - val_accuracy: 0.9932
# Epoch 184/1000
# 237/237 - 1s - loss: 0.0144 - accuracy: 0.9993 - val_loss: 0.0459 - val_accuracy: 0.9932
# Epoch 185/1000
# 237/237 - 1s - loss: 0.0142 - accuracy: 0.9995 - val_loss: 0.0474 - val_accuracy: 0.9925
# Epoch 186/1000
# 237/237 - 1s - loss: 0.0140 - accuracy: 0.9997 - val_loss: 0.0438 - val_accuracy: 0.9940
# Epoch 187/1000
# 237/237 - 1s - loss: 0.0141 - accuracy: 0.9993 - val_loss: 0.0466 - val_accuracy: 0.9928
# Epoch 188/1000
# 237/237 - 1s - loss: 0.0143 - accuracy: 0.9993 - val_loss: 0.0457 - val_accuracy: 0.9932
# Epoch 189/1000
# 237/237 - 1s - loss: 0.0142 - accuracy: 0.9995 - val_loss: 0.0450 - val_accuracy: 0.9932
# Epoch 190/1000
# 237/237 - 1s - loss: 0.0142 - accuracy: 0.9992 - val_loss: 0.0464 - val_accuracy: 0.9932
# Epoch 191/1000
# 237/237 - 1s - loss: 0.0144 - accuracy: 0.9992 - val_loss: 0.0471 - val_accuracy: 0.9928
# Epoch 192/1000
# 237/237 - 1s - loss: 0.0141 - accuracy: 0.9993 - val_loss: 0.0446 - val_accuracy: 0.9932
# Epoch 193/1000
# 237/237 - 1s - loss: 0.0139 - accuracy: 0.9996 - val_loss: 0.0452 - val_accuracy: 0.9932
# Epoch 194/1000
# 237/237 - 1s - loss: 0.0137 - accuracy: 0.9995 - val_loss: 0.0433 - val_accuracy: 0.9936
# Epoch 195/1000
# 237/237 - 1s - loss: 0.0138 - accuracy: 0.9993 - val_loss: 0.0442 - val_accuracy: 0.9932
# Epoch 196/1000
# 237/237 - 1s - loss: 0.0138 - accuracy: 0.9993 - val_loss: 0.0441 - val_accuracy: 0.9932
# Epoch 197/1000
# 237/237 - 1s - loss: 0.0139 - accuracy: 0.9993 - val_loss: 0.0435 - val_accuracy: 0.9932
# Epoch 198/1000
# 237/237 - 1s - loss: 0.0138 - accuracy: 0.9995 - val_loss: 0.0439 - val_accuracy: 0.9932
# Epoch 199/1000
# 237/237 - 1s - loss: 0.0137 - accuracy: 0.9993 - val_loss: 0.0437 - val_accuracy: 0.9932
# Epoch 200/1000
# 237/237 - 1s - loss: 0.0137 - accuracy: 0.9997 - val_loss: 0.0429 - val_accuracy: 0.9936
# Epoch 201/1000
# 237/237 - 1s - loss: 0.0136 - accuracy: 0.9995 - val_loss: 0.0445 - val_accuracy: 0.9928
# Epoch 202/1000
# 237/237 - 1s - loss: 0.0135 - accuracy: 0.9995 - val_loss: 0.0461 - val_accuracy: 0.9932
# Epoch 203/1000
# 237/237 - 1s - loss: 0.0139 - accuracy: 0.9993 - val_loss: 0.0459 - val_accuracy: 0.9928
# Epoch 204/1000
# 237/237 - 1s - loss: 0.0135 - accuracy: 0.9996 - val_loss: 0.0441 - val_accuracy: 0.9932
# Epoch 205/1000
# 237/237 - 1s - loss: 0.0138 - accuracy: 0.9995 - val_loss: 0.0438 - val_accuracy: 0.9936
# Epoch 206/1000
# 237/237 - 1s - loss: 0.0136 - accuracy: 0.9992 - val_loss: 0.0435 - val_accuracy: 0.9932
# Epoch 207/1000
# 237/237 - 1s - loss: 0.0134 - accuracy: 0.9995 - val_loss: 0.0437 - val_accuracy: 0.9936
# Epoch 208/1000
# 237/237 - 1s - loss: 0.0137 - accuracy: 0.9993 - val_loss: 0.0406 - val_accuracy: 0.9936
# Epoch 209/1000
# 237/237 - 1s - loss: 0.0133 - accuracy: 0.9993 - val_loss: 0.0432 - val_accuracy: 0.9940
# Epoch 210/1000
# 237/237 - 1s - loss: 0.0134 - accuracy: 0.9995 - val_loss: 0.0427 - val_accuracy: 0.9936
# Epoch 211/1000
# 237/237 - 1s - loss: 0.0132 - accuracy: 0.9996 - val_loss: 0.0438 - val_accuracy: 0.9936
# Epoch 212/1000
# 237/237 - 1s - loss: 0.0131 - accuracy: 0.9997 - val_loss: 0.0419 - val_accuracy: 0.9936
# Epoch 213/1000
# 237/237 - 1s - loss: 0.0130 - accuracy: 0.9997 - val_loss: 0.0425 - val_accuracy: 0.9936
# Epoch 214/1000
# 237/237 - 1s - loss: 0.0133 - accuracy: 0.9995 - val_loss: 0.0414 - val_accuracy: 0.9936
# Epoch 215/1000
# 237/237 - 1s - loss: 0.0130 - accuracy: 0.9995 - val_loss: 0.0421 - val_accuracy: 0.9936
# Epoch 216/1000
# 237/237 - 1s - loss: 0.0130 - accuracy: 0.9995 - val_loss: 0.0398 - val_accuracy: 0.9936
# Epoch 217/1000
# 237/237 - 1s - loss: 0.0132 - accuracy: 0.9993 - val_loss: 0.0412 - val_accuracy: 0.9936
# Epoch 218/1000
# 237/237 - 1s - loss: 0.0131 - accuracy: 0.9993 - val_loss: 0.0424 - val_accuracy: 0.9940
# Epoch 219/1000
# 237/237 - 1s - loss: 0.0131 - accuracy: 0.9996 - val_loss: 0.0395 - val_accuracy: 0.9936
# Epoch 220/1000
# 237/237 - 1s - loss: 0.0130 - accuracy: 0.9995 - val_loss: 0.0413 - val_accuracy: 0.9944
# Epoch 221/1000
# 237/237 - 1s - loss: 0.0131 - accuracy: 0.9996 - val_loss: 0.0409 - val_accuracy: 0.9936
# Epoch 222/1000
# 237/237 - 1s - loss: 0.0130 - accuracy: 0.9996 - val_loss: 0.0413 - val_accuracy: 0.9944
# Epoch 223/1000
# 237/237 - 1s - loss: 0.0128 - accuracy: 0.9996 - val_loss: 0.0419 - val_accuracy: 0.9936
# Epoch 224/1000
# 237/237 - 1s - loss: 0.0129 - accuracy: 0.9996 - val_loss: 0.0404 - val_accuracy: 0.9944
# Epoch 225/1000
# 237/237 - 1s - loss: 0.0129 - accuracy: 0.9993 - val_loss: 0.0407 - val_accuracy: 0.9936
# Epoch 226/1000
# 237/237 - 1s - loss: 0.0129 - accuracy: 0.9996 - val_loss: 0.0393 - val_accuracy: 0.9936
# Epoch 227/1000
# 237/237 - 1s - loss: 0.0129 - accuracy: 0.9996 - val_loss: 0.0403 - val_accuracy: 0.9940
# Epoch 228/1000
# 237/237 - 1s - loss: 0.0129 - accuracy: 0.9996 - val_loss: 0.0399 - val_accuracy: 0.9944
# Epoch 229/1000
# 237/237 - 1s - loss: 0.0128 - accuracy: 0.9996 - val_loss: 0.0387 - val_accuracy: 0.9936
# Epoch 230/1000
# 237/237 - 1s - loss: 0.0126 - accuracy: 0.9996 - val_loss: 0.0383 - val_accuracy: 0.9936
# Epoch 231/1000
# 237/237 - 1s - loss: 0.0127 - accuracy: 0.9996 - val_loss: 0.0406 - val_accuracy: 0.9940
# Epoch 232/1000
# 237/237 - 1s - loss: 0.0128 - accuracy: 0.9996 - val_loss: 0.0395 - val_accuracy: 0.9944
# Epoch 233/1000
# 237/237 - 1s - loss: 0.0127 - accuracy: 0.9997 - val_loss: 0.0386 - val_accuracy: 0.9936
# Epoch 234/1000
# 237/237 - 1s - loss: 0.0128 - accuracy: 0.9995 - val_loss: 0.0385 - val_accuracy: 0.9936
# Epoch 235/1000
# 237/237 - 1s - loss: 0.0125 - accuracy: 0.9995 - val_loss: 0.0406 - val_accuracy: 0.9936
# Epoch 236/1000
# 237/237 - 1s - loss: 0.0126 - accuracy: 0.9996 - val_loss: 0.0384 - val_accuracy: 0.9940
# Epoch 237/1000
# 237/237 - 1s - loss: 0.0126 - accuracy: 0.9995 - val_loss: 0.0392 - val_accuracy: 0.9944
# Epoch 238/1000
# 237/237 - 1s - loss: 0.0126 - accuracy: 0.9997 - val_loss: 0.0392 - val_accuracy: 0.9944
# Epoch 239/1000
# 237/237 - 1s - loss: 0.0124 - accuracy: 0.9997 - val_loss: 0.0398 - val_accuracy: 0.9940
# Epoch 240/1000
# 237/237 - 1s - loss: 0.0125 - accuracy: 0.9996 - val_loss: 0.0401 - val_accuracy: 0.9940
# Epoch 241/1000
# 237/237 - 1s - loss: 0.0123 - accuracy: 0.9997 - val_loss: 0.0399 - val_accuracy: 0.9944
# Epoch 242/1000
# 237/237 - 1s - loss: 0.0126 - accuracy: 0.9997 - val_loss: 0.0394 - val_accuracy: 0.9944
# Epoch 243/1000
# 237/237 - 1s - loss: 0.0125 - accuracy: 0.9995 - val_loss: 0.0384 - val_accuracy: 0.9944
# Epoch 244/1000
# 237/237 - 1s - loss: 0.0122 - accuracy: 0.9997 - val_loss: 0.0383 - val_accuracy: 0.9944
# Epoch 245/1000
# 237/237 - 1s - loss: 0.0124 - accuracy: 0.9996 - val_loss: 0.0387 - val_accuracy: 0.9944
# Epoch 246/1000
# 237/237 - 1s - loss: 0.0122 - accuracy: 0.9996 - val_loss: 0.0382 - val_accuracy: 0.9944
# Epoch 247/1000
# 237/237 - 1s - loss: 0.0122 - accuracy: 0.9997 - val_loss: 0.0368 - val_accuracy: 0.9940
# Epoch 248/1000
# 237/237 - 1s - loss: 0.0122 - accuracy: 0.9996 - val_loss: 0.0381 - val_accuracy: 0.9944
# Epoch 249/1000
# 237/237 - 1s - loss: 0.0123 - accuracy: 0.9996 - val_loss: 0.0385 - val_accuracy: 0.9944
# Epoch 250/1000
# 237/237 - 1s - loss: 0.0123 - accuracy: 0.9995 - val_loss: 0.0378 - val_accuracy: 0.9944
# Epoch 251/1000
# 237/237 - 1s - loss: 0.0124 - accuracy: 0.9995 - val_loss: 0.0371 - val_accuracy: 0.9940
# Epoch 252/1000
# 237/237 - 1s - loss: 0.0122 - accuracy: 0.9997 - val_loss: 0.0370 - val_accuracy: 0.9944
# Epoch 253/1000
# 237/237 - 1s - loss: 0.0121 - accuracy: 0.9996 - val_loss: 0.0373 - val_accuracy: 0.9944
# Epoch 254/1000
# 237/237 - 1s - loss: 0.0120 - accuracy: 0.9997 - val_loss: 0.0362 - val_accuracy: 0.9940
# Epoch 255/1000
# 237/237 - 1s - loss: 0.0120 - accuracy: 0.9997 - val_loss: 0.0383 - val_accuracy: 0.9944
# Epoch 256/1000
# 237/237 - 1s - loss: 0.0121 - accuracy: 0.9997 - val_loss: 0.0383 - val_accuracy: 0.9944
# Epoch 257/1000
# 237/237 - 1s - loss: 0.0120 - accuracy: 0.9997 - val_loss: 0.0356 - val_accuracy: 0.9940
# Epoch 258/1000
# 237/237 - 1s - loss: 0.0122 - accuracy: 0.9997 - val_loss: 0.0366 - val_accuracy: 0.9944
# Epoch 259/1000
# 237/237 - 1s - loss: 0.0120 - accuracy: 0.9996 - val_loss: 0.0359 - val_accuracy: 0.9940
# Epoch 260/1000
# 237/237 - 1s - loss: 0.0119 - accuracy: 0.9997 - val_loss: 0.0351 - val_accuracy: 0.9936
# Epoch 261/1000
# 237/237 - 1s - loss: 0.0120 - accuracy: 0.9996 - val_loss: 0.0359 - val_accuracy: 0.9940
# Epoch 262/1000
# 237/237 - 1s - loss: 0.0120 - accuracy: 0.9997 - val_loss: 0.0379 - val_accuracy: 0.9944
# Epoch 263/1000
# 237/237 - 1s - loss: 0.0121 - accuracy: 0.9995 - val_loss: 0.0372 - val_accuracy: 0.9944
# Epoch 264/1000
# 237/237 - 1s - loss: 0.0119 - accuracy: 0.9996 - val_loss: 0.0369 - val_accuracy: 0.9944
# Epoch 265/1000
# 237/237 - 1s - loss: 0.0119 - accuracy: 0.9997 - val_loss: 0.0348 - val_accuracy: 0.9940
# Epoch 266/1000
# 237/237 - 1s - loss: 0.0118 - accuracy: 0.9997 - val_loss: 0.0362 - val_accuracy: 0.9944
# Epoch 267/1000
# 237/237 - 1s - loss: 0.0117 - accuracy: 0.9997 - val_loss: 0.0348 - val_accuracy: 0.9940
# Epoch 268/1000
# 237/237 - 1s - loss: 0.0117 - accuracy: 0.9997 - val_loss: 0.0353 - val_accuracy: 0.9940
# Epoch 269/1000
# 237/237 - 1s - loss: 0.0117 - accuracy: 0.9997 - val_loss: 0.0359 - val_accuracy: 0.9944
# Epoch 270/1000
# 237/237 - 1s - loss: 0.0118 - accuracy: 0.9997 - val_loss: 0.0361 - val_accuracy: 0.9944
# Epoch 271/1000
# 237/237 - 1s - loss: 0.0118 - accuracy: 0.9996 - val_loss: 0.0363 - val_accuracy: 0.9944
# Epoch 272/1000
# 237/237 - 1s - loss: 0.0118 - accuracy: 0.9997 - val_loss: 0.0356 - val_accuracy: 0.9944
# Epoch 273/1000
# 237/237 - 1s - loss: 0.0118 - accuracy: 0.9996 - val_loss: 0.0354 - val_accuracy: 0.9944
# Epoch 274/1000
# 237/237 - 1s - loss: 0.0115 - accuracy: 0.9997 - val_loss: 0.0354 - val_accuracy: 0.9944
# Epoch 275/1000
# 237/237 - 1s - loss: 0.0117 - accuracy: 0.9997 - val_loss: 0.0366 - val_accuracy: 0.9944
# Epoch 276/1000
# 237/237 - 1s - loss: 0.0116 - accuracy: 0.9997 - val_loss: 0.0350 - val_accuracy: 0.9944
# Epoch 277/1000
# 237/237 - 1s - loss: 0.0115 - accuracy: 0.9997 - val_loss: 0.0343 - val_accuracy: 0.9940
# Epoch 278/1000
# 237/237 - 1s - loss: 0.0116 - accuracy: 0.9997 - val_loss: 0.0351 - val_accuracy: 0.9944
# Epoch 279/1000
# 237/237 - 1s - loss: 0.0117 - accuracy: 0.9997 - val_loss: 0.0346 - val_accuracy: 0.9944
# Epoch 280/1000
# 237/237 - 1s - loss: 0.0114 - accuracy: 0.9997 - val_loss: 0.0347 - val_accuracy: 0.9944
# Epoch 281/1000
# 237/237 - 1s - loss: 0.0117 - accuracy: 0.9996 - val_loss: 0.0351 - val_accuracy: 0.9944
# Epoch 282/1000
# 237/237 - 1s - loss: 0.0113 - accuracy: 0.9997 - val_loss: 0.0350 - val_accuracy: 0.9944
# Epoch 283/1000
# 237/237 - 1s - loss: 0.0115 - accuracy: 0.9997 - val_loss: 0.0357 - val_accuracy: 0.9944
# Epoch 284/1000
# 237/237 - 1s - loss: 0.0114 - accuracy: 0.9997 - val_loss: 0.0350 - val_accuracy: 0.9944
# Epoch 285/1000
# 237/237 - 1s - loss: 0.0114 - accuracy: 0.9997 - val_loss: 0.0351 - val_accuracy: 0.9944
# Epoch 286/1000
# 237/237 - 1s - loss: 0.0114 - accuracy: 0.9997 - val_loss: 0.0333 - val_accuracy: 0.9944
# Epoch 287/1000
# 237/237 - 1s - loss: 0.0115 - accuracy: 0.9997 - val_loss: 0.0340 - val_accuracy: 0.9944
# Epoch 288/1000
# 237/237 - 1s - loss: 0.0112 - accuracy: 0.9997 - val_loss: 0.0352 - val_accuracy: 0.9944
# Epoch 289/1000
# 237/237 - 1s - loss: 0.0112 - accuracy: 0.9997 - val_loss: 0.0354 - val_accuracy: 0.9944
# Epoch 290/1000
# 237/237 - 1s - loss: 0.0114 - accuracy: 0.9997 - val_loss: 0.0340 - val_accuracy: 0.9948
# Epoch 291/1000
# 237/237 - 1s - loss: 0.0113 - accuracy: 0.9996 - val_loss: 0.0349 - val_accuracy: 0.9944
# Epoch 292/1000
# 237/237 - 1s - loss: 0.0114 - accuracy: 0.9996 - val_loss: 0.0344 - val_accuracy: 0.9944
# Epoch 293/1000
# 237/237 - 1s - loss: 0.0112 - accuracy: 0.9997 - val_loss: 0.0345 - val_accuracy: 0.9944
# Epoch 294/1000
# 237/237 - 1s - loss: 0.0112 - accuracy: 0.9997 - val_loss: 0.0348 - val_accuracy: 0.9944
# Epoch 295/1000
# 237/237 - 1s - loss: 0.0112 - accuracy: 0.9997 - val_loss: 0.0340 - val_accuracy: 0.9948
# Epoch 296/1000
# 237/237 - 1s - loss: 0.0114 - accuracy: 0.9997 - val_loss: 0.0335 - val_accuracy: 0.9948
# Epoch 297/1000
# 237/237 - 1s - loss: 0.0111 - accuracy: 0.9997 - val_loss: 0.0343 - val_accuracy: 0.9948
# Epoch 298/1000
# 237/237 - 1s - loss: 0.0112 - accuracy: 0.9997 - val_loss: 0.0342 - val_accuracy: 0.9948
# Epoch 299/1000
# 237/237 - 1s - loss: 0.0112 - accuracy: 0.9996 - val_loss: 0.0332 - val_accuracy: 0.9948
# Epoch 300/1000
# 237/237 - 1s - loss: 0.0110 - accuracy: 0.9997 - val_loss: 0.0334 - val_accuracy: 0.9948
# Epoch 301/1000
# 237/237 - 1s - loss: 0.0113 - accuracy: 0.9996 - val_loss: 0.0338 - val_accuracy: 0.9948
# Epoch 302/1000
# 237/237 - 1s - loss: 0.0110 - accuracy: 0.9997 - val_loss: 0.0336 - val_accuracy: 0.9948
# Epoch 303/1000
# 237/237 - 1s - loss: 0.0109 - accuracy: 0.9999 - val_loss: 0.0326 - val_accuracy: 0.9944
# Epoch 304/1000
# 237/237 - 1s - loss: 0.0112 - accuracy: 0.9997 - val_loss: 0.0333 - val_accuracy: 0.9948
# Epoch 305/1000
# 237/237 - 1s - loss: 0.0110 - accuracy: 0.9997 - val_loss: 0.0327 - val_accuracy: 0.9948
# Epoch 306/1000
# 237/237 - 1s - loss: 0.0110 - accuracy: 0.9996 - val_loss: 0.0340 - val_accuracy: 0.9948
# Epoch 307/1000
# 237/237 - 1s - loss: 0.0112 - accuracy: 0.9997 - val_loss: 0.0335 - val_accuracy: 0.9948
# Epoch 308/1000
# 237/237 - 1s - loss: 0.0109 - accuracy: 0.9997 - val_loss: 0.0337 - val_accuracy: 0.9948
# Epoch 309/1000
# 237/237 - 1s - loss: 0.0109 - accuracy: 0.9997 - val_loss: 0.0326 - val_accuracy: 0.9948
# Epoch 310/1000
# 237/237 - 1s - loss: 0.0109 - accuracy: 0.9997 - val_loss: 0.0326 - val_accuracy: 0.9948
# Epoch 311/1000
# 237/237 - 1s - loss: 0.0109 - accuracy: 0.9997 - val_loss: 0.0330 - val_accuracy: 0.9948
# Epoch 312/1000
# 237/237 - 1s - loss: 0.0110 - accuracy: 0.9997 - val_loss: 0.0335 - val_accuracy: 0.9948
# Epoch 313/1000
# 237/237 - 1s - loss: 0.0109 - accuracy: 0.9997 - val_loss: 0.0329 - val_accuracy: 0.9948
# Epoch 314/1000
# 237/237 - 1s - loss: 0.0110 - accuracy: 0.9997 - val_loss: 0.0323 - val_accuracy: 0.9948
# Epoch 315/1000
# 237/237 - 1s - loss: 0.0109 - accuracy: 0.9999 - val_loss: 0.0319 - val_accuracy: 0.9948
# Epoch 316/1000
# 237/237 - 1s - loss: 0.0108 - accuracy: 0.9996 - val_loss: 0.0337 - val_accuracy: 0.9948
# Epoch 317/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9997 - val_loss: 0.0328 - val_accuracy: 0.9948
# Epoch 318/1000
# 237/237 - 1s - loss: 0.0109 - accuracy: 0.9997 - val_loss: 0.0334 - val_accuracy: 0.9948
# Epoch 319/1000
# 237/237 - 1s - loss: 0.0108 - accuracy: 0.9997 - val_loss: 0.0321 - val_accuracy: 0.9944
# Epoch 320/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9997 - val_loss: 0.0328 - val_accuracy: 0.9948
# Epoch 321/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9997 - val_loss: 0.0332 - val_accuracy: 0.9948
# Epoch 322/1000
# 237/237 - 1s - loss: 0.0108 - accuracy: 0.9997 - val_loss: 0.0330 - val_accuracy: 0.9948
# Epoch 323/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9997 - val_loss: 0.0335 - val_accuracy: 0.9948
# Epoch 324/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9997 - val_loss: 0.0326 - val_accuracy: 0.9948
# Epoch 325/1000
# 237/237 - 1s - loss: 0.0106 - accuracy: 0.9997 - val_loss: 0.0327 - val_accuracy: 0.9948
# Epoch 326/1000
# 237/237 - 1s - loss: 0.0106 - accuracy: 0.9997 - val_loss: 0.0320 - val_accuracy: 0.9948
# Epoch 327/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9997 - val_loss: 0.0324 - val_accuracy: 0.9948
# Epoch 328/1000
# 237/237 - 1s - loss: 0.0105 - accuracy: 0.9997 - val_loss: 0.0323 - val_accuracy: 0.9948
# Epoch 329/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9997 - val_loss: 0.0334 - val_accuracy: 0.9948
# Epoch 330/1000
# 237/237 - 1s - loss: 0.0106 - accuracy: 0.9997 - val_loss: 0.0322 - val_accuracy: 0.9948
# Epoch 331/1000
# 237/237 - 1s - loss: 0.0106 - accuracy: 0.9997 - val_loss: 0.0315 - val_accuracy: 0.9948
# Epoch 332/1000
# 237/237 - 1s - loss: 0.0106 - accuracy: 0.9997 - val_loss: 0.0317 - val_accuracy: 0.9948
# Epoch 333/1000
# 237/237 - 1s - loss: 0.0104 - accuracy: 0.9997 - val_loss: 0.0308 - val_accuracy: 0.9944
# Epoch 334/1000
# 237/237 - 1s - loss: 0.0106 - accuracy: 0.9997 - val_loss: 0.0316 - val_accuracy: 0.9948
# Epoch 335/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9997 - val_loss: 0.0317 - val_accuracy: 0.9948
# Epoch 336/1000
# 237/237 - 1s - loss: 0.0105 - accuracy: 0.9997 - val_loss: 0.0316 - val_accuracy: 0.9948
# Epoch 337/1000
# 237/237 - 1s - loss: 0.0105 - accuracy: 0.9997 - val_loss: 0.0308 - val_accuracy: 0.9948
# Epoch 338/1000
# 237/237 - 1s - loss: 0.0105 - accuracy: 0.9997 - val_loss: 0.0318 - val_accuracy: 0.9948
# Epoch 339/1000
# 237/237 - 1s - loss: 0.0104 - accuracy: 0.9997 - val_loss: 0.0317 - val_accuracy: 0.9948
# Epoch 340/1000
# 237/237 - 1s - loss: 0.0105 - accuracy: 0.9997 - val_loss: 0.0315 - val_accuracy: 0.9948
# Epoch 341/1000
# 237/237 - 1s - loss: 0.0104 - accuracy: 0.9999 - val_loss: 0.0324 - val_accuracy: 0.9948
# Epoch 342/1000
# 237/237 - 1s - loss: 0.0105 - accuracy: 0.9997 - val_loss: 0.0315 - val_accuracy: 0.9948
# Epoch 343/1000
# 237/237 - 1s - loss: 0.0105 - accuracy: 0.9997 - val_loss: 0.0305 - val_accuracy: 0.9948
# Epoch 344/1000
# 237/237 - 1s - loss: 0.0105 - accuracy: 0.9997 - val_loss: 0.0311 - val_accuracy: 0.9948
# Epoch 345/1000
# 237/237 - 1s - loss: 0.0104 - accuracy: 0.9997 - val_loss: 0.0318 - val_accuracy: 0.9948
# Epoch 346/1000
# 237/237 - 1s - loss: 0.0104 - accuracy: 0.9997 - val_loss: 0.0312 - val_accuracy: 0.9948
# Epoch 347/1000
# 237/237 - 1s - loss: 0.0104 - accuracy: 0.9997 - val_loss: 0.0310 - val_accuracy: 0.9948
# Epoch 348/1000
# 237/237 - 1s - loss: 0.0104 - accuracy: 0.9997 - val_loss: 0.0321 - val_accuracy: 0.9948
# Epoch 349/1000
# 237/237 - 1s - loss: 0.0104 - accuracy: 0.9997 - val_loss: 0.0304 - val_accuracy: 0.9952
# Epoch 350/1000
# 237/237 - 1s - loss: 0.0105 - accuracy: 0.9997 - val_loss: 0.0304 - val_accuracy: 0.9952
# Epoch 351/1000
# 237/237 - 1s - loss: 0.0103 - accuracy: 0.9997 - val_loss: 0.0309 - val_accuracy: 0.9948
# Epoch 352/1000
# 237/237 - 1s - loss: 0.0102 - accuracy: 0.9997 - val_loss: 0.0310 - val_accuracy: 0.9948
# Epoch 353/1000
# 237/237 - 1s - loss: 0.0103 - accuracy: 0.9997 - val_loss: 0.0309 - val_accuracy: 0.9948
# Epoch 354/1000
# 237/237 - 1s - loss: 0.0102 - accuracy: 0.9999 - val_loss: 0.0314 - val_accuracy: 0.9948
# Epoch 355/1000
# 237/237 - 1s - loss: 0.0101 - accuracy: 0.9999 - val_loss: 0.0311 - val_accuracy: 0.9948
# Epoch 356/1000
# 237/237 - 1s - loss: 0.0102 - accuracy: 0.9997 - val_loss: 0.0300 - val_accuracy: 0.9952
# Epoch 357/1000
# 237/237 - 1s - loss: 0.0102 - accuracy: 0.9997 - val_loss: 0.0308 - val_accuracy: 0.9948
# Epoch 358/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9997 - val_loss: 0.0306 - val_accuracy: 0.9948
# Epoch 359/1000
# 237/237 - 1s - loss: 0.0103 - accuracy: 0.9999 - val_loss: 0.0298 - val_accuracy: 0.9952
# Epoch 360/1000
# 237/237 - 1s - loss: 0.0103 - accuracy: 0.9997 - val_loss: 0.0301 - val_accuracy: 0.9952
# Epoch 361/1000
# 237/237 - 1s - loss: 0.0101 - accuracy: 0.9997 - val_loss: 0.0302 - val_accuracy: 0.9948
# Epoch 362/1000
# 237/237 - 1s - loss: 0.0101 - accuracy: 0.9997 - val_loss: 0.0308 - val_accuracy: 0.9948
# Epoch 363/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9999 - val_loss: 0.0307 - val_accuracy: 0.9948
# Epoch 364/1000
# 237/237 - 1s - loss: 0.0102 - accuracy: 0.9997 - val_loss: 0.0299 - val_accuracy: 0.9952
# Epoch 365/1000
# 237/237 - 1s - loss: 0.0099 - accuracy: 0.9997 - val_loss: 0.0298 - val_accuracy: 0.9952
# Epoch 366/1000
# 237/237 - 1s - loss: 0.0101 - accuracy: 0.9999 - val_loss: 0.0298 - val_accuracy: 0.9952
# Epoch 367/1000
# 237/237 - 1s - loss: 0.0102 - accuracy: 0.9997 - val_loss: 0.0293 - val_accuracy: 0.9952
# Epoch 368/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9997 - val_loss: 0.0299 - val_accuracy: 0.9952
# Epoch 369/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9997 - val_loss: 0.0297 - val_accuracy: 0.9952
# Epoch 370/1000
# 237/237 - 1s - loss: 0.0099 - accuracy: 0.9999 - val_loss: 0.0305 - val_accuracy: 0.9948
# Epoch 371/1000
# 237/237 - 1s - loss: 0.0101 - accuracy: 0.9997 - val_loss: 0.0310 - val_accuracy: 0.9948
# Epoch 372/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9997 - val_loss: 0.0296 - val_accuracy: 0.9952
# Epoch 373/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9997 - val_loss: 0.0297 - val_accuracy: 0.9952
# Epoch 374/1000
# 237/237 - 1s - loss: 0.0099 - accuracy: 0.9997 - val_loss: 0.0303 - val_accuracy: 0.9948
# Epoch 375/1000
# 237/237 - 1s - loss: 0.0099 - accuracy: 0.9999 - val_loss: 0.0300 - val_accuracy: 0.9948
# Epoch 376/1000
# 237/237 - 1s - loss: 0.0099 - accuracy: 0.9997 - val_loss: 0.0295 - val_accuracy: 0.9956
# Epoch 377/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9997 - val_loss: 0.0292 - val_accuracy: 0.9956
# Epoch 378/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9997 - val_loss: 0.0303 - val_accuracy: 0.9948
# Epoch 379/1000
# 237/237 - 1s - loss: 0.0098 - accuracy: 0.9997 - val_loss: 0.0295 - val_accuracy: 0.9952
# Epoch 380/1000
# 237/237 - 1s - loss: 0.0098 - accuracy: 0.9997 - val_loss: 0.0291 - val_accuracy: 0.9952
# Epoch 381/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9997 - val_loss: 0.0297 - val_accuracy: 0.9948
# Epoch 382/1000
# 237/237 - 1s - loss: 0.0099 - accuracy: 0.9997 - val_loss: 0.0297 - val_accuracy: 0.9956
# Epoch 383/1000
# 237/237 - 1s - loss: 0.0096 - accuracy: 0.9999 - val_loss: 0.0296 - val_accuracy: 0.9956
# Epoch 384/1000
# 237/237 - 1s - loss: 0.0098 - accuracy: 0.9997 - val_loss: 0.0296 - val_accuracy: 0.9948
# Epoch 385/1000
# 237/237 - 1s - loss: 0.0098 - accuracy: 0.9997 - val_loss: 0.0288 - val_accuracy: 0.9956
# Epoch 386/1000
# 237/237 - 1s - loss: 0.0098 - accuracy: 0.9997 - val_loss: 0.0293 - val_accuracy: 0.9956
# Epoch 387/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9997 - val_loss: 0.0292 - val_accuracy: 0.9956
# Epoch 388/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9999 - val_loss: 0.0296 - val_accuracy: 0.9948
# Epoch 389/1000
# 237/237 - 1s - loss: 0.0099 - accuracy: 0.9997 - val_loss: 0.0294 - val_accuracy: 0.9956
# Epoch 390/1000
# 237/237 - 1s - loss: 0.0101 - accuracy: 0.9997 - val_loss: 0.0294 - val_accuracy: 0.9956
# Epoch 391/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9997 - val_loss: 0.0294 - val_accuracy: 0.9948
# Epoch 392/1000
# 237/237 - 1s - loss: 0.0099 - accuracy: 0.9997 - val_loss: 0.0297 - val_accuracy: 0.9948
# Epoch 393/1000
# 237/237 - 1s - loss: 0.0096 - accuracy: 0.9999 - val_loss: 0.0281 - val_accuracy: 0.9956
# Epoch 394/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9997 - val_loss: 0.0292 - val_accuracy: 0.9956
# Epoch 395/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9999 - val_loss: 0.0296 - val_accuracy: 0.9952
# Epoch 396/1000
# 237/237 - 1s - loss: 0.0098 - accuracy: 0.9997 - val_loss: 0.0293 - val_accuracy: 0.9948
# Epoch 397/1000
# 237/237 - 1s - loss: 0.0096 - accuracy: 0.9997 - val_loss: 0.0291 - val_accuracy: 0.9956
# Epoch 398/1000
# 237/237 - 1s - loss: 0.0096 - accuracy: 0.9997 - val_loss: 0.0285 - val_accuracy: 0.9960
# Epoch 399/1000
# 237/237 - 1s - loss: 0.0098 - accuracy: 0.9997 - val_loss: 0.0292 - val_accuracy: 0.9956
# Epoch 400/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9999 - val_loss: 0.0289 - val_accuracy: 0.9956
# Epoch 401/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9997 - val_loss: 0.0294 - val_accuracy: 0.9956
# Epoch 402/1000
# 237/237 - 1s - loss: 0.0096 - accuracy: 0.9997 - val_loss: 0.0289 - val_accuracy: 0.9956
# Epoch 403/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9997 - val_loss: 0.0296 - val_accuracy: 0.9952
# Epoch 404/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9997 - val_loss: 0.0281 - val_accuracy: 0.9960
# Epoch 405/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.0284 - val_accuracy: 0.9960
# Epoch 406/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9997 - val_loss: 0.0282 - val_accuracy: 0.9960
# Epoch 407/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9999 - val_loss: 0.0294 - val_accuracy: 0.9952
# Epoch 408/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9997 - val_loss: 0.0283 - val_accuracy: 0.9960
# Epoch 409/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.0291 - val_accuracy: 0.9956
# Epoch 410/1000
# 237/237 - 1s - loss: 0.0096 - accuracy: 0.9997 - val_loss: 0.0286 - val_accuracy: 0.9960
# Epoch 411/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.0280 - val_accuracy: 0.9960
# Epoch 412/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9997 - val_loss: 0.0291 - val_accuracy: 0.9956
# Epoch 413/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.0285 - val_accuracy: 0.9956
# Epoch 414/1000
# 237/237 - 1s - loss: 0.0096 - accuracy: 0.9997 - val_loss: 0.0284 - val_accuracy: 0.9960
# Epoch 415/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.0284 - val_accuracy: 0.9960
# Epoch 416/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9999 - val_loss: 0.0276 - val_accuracy: 0.9960
# Epoch 417/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.0285 - val_accuracy: 0.9960
# Epoch 418/1000
# 237/237 - 1s - loss: 0.0096 - accuracy: 0.9997 - val_loss: 0.0278 - val_accuracy: 0.9960
# Epoch 419/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.0291 - val_accuracy: 0.9952
# Epoch 420/1000
# 237/237 - 1s - loss: 0.0094 - accuracy: 0.9997 - val_loss: 0.0287 - val_accuracy: 0.9956
# Epoch 421/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9997 - val_loss: 0.0283 - val_accuracy: 0.9956
# Epoch 422/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9999 - val_loss: 0.0288 - val_accuracy: 0.9956
# Epoch 423/1000
# 237/237 - 1s - loss: 0.0094 - accuracy: 0.9997 - val_loss: 0.0278 - val_accuracy: 0.9960
# Epoch 424/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9997 - val_loss: 0.0280 - val_accuracy: 0.9960
# Epoch 425/1000
# 237/237 - 1s - loss: 0.0094 - accuracy: 0.9997 - val_loss: 0.0283 - val_accuracy: 0.9960
# Epoch 426/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9999 - val_loss: 0.0277 - val_accuracy: 0.9960
# Epoch 427/1000
# 237/237 - 1s - loss: 0.0094 - accuracy: 0.9997 - val_loss: 0.0285 - val_accuracy: 0.9956
# Epoch 428/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9999 - val_loss: 0.0280 - val_accuracy: 0.9960
# Epoch 429/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9999 - val_loss: 0.0278 - val_accuracy: 0.9960
# Epoch 430/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9997 - val_loss: 0.0278 - val_accuracy: 0.9960
# Epoch 431/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9999 - val_loss: 0.0282 - val_accuracy: 0.9960
# Epoch 432/1000
# 237/237 - 1s - loss: 0.0094 - accuracy: 0.9997 - val_loss: 0.0281 - val_accuracy: 0.9960
# Epoch 433/1000
# 237/237 - 1s - loss: 0.0094 - accuracy: 0.9997 - val_loss: 0.0276 - val_accuracy: 0.9960
# Epoch 434/1000
# 237/237 - 1s - loss: 0.0094 - accuracy: 0.9999 - val_loss: 0.0284 - val_accuracy: 0.9960
# Epoch 435/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9999 - val_loss: 0.0279 - val_accuracy: 0.9960
# Epoch 436/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9997 - val_loss: 0.0285 - val_accuracy: 0.9956
# Epoch 437/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9999 - val_loss: 0.0281 - val_accuracy: 0.9960
# Epoch 438/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9999 - val_loss: 0.0281 - val_accuracy: 0.9960
# Epoch 439/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9997 - val_loss: 0.0282 - val_accuracy: 0.9960
# Epoch 440/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9997 - val_loss: 0.0281 - val_accuracy: 0.9960
# Epoch 441/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9997 - val_loss: 0.0272 - val_accuracy: 0.9960
# Epoch 442/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9997 - val_loss: 0.0272 - val_accuracy: 0.9960
# Epoch 443/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9999 - val_loss: 0.0273 - val_accuracy: 0.9960
# Epoch 444/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9999 - val_loss: 0.0272 - val_accuracy: 0.9960
# Epoch 445/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9999 - val_loss: 0.0273 - val_accuracy: 0.9960
# Epoch 446/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9997 - val_loss: 0.0275 - val_accuracy: 0.9960
# Epoch 447/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9997 - val_loss: 0.0278 - val_accuracy: 0.9960
# Epoch 448/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9999 - val_loss: 0.0277 - val_accuracy: 0.9960
# Epoch 449/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9997 - val_loss: 0.0280 - val_accuracy: 0.9960
# Epoch 450/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9997 - val_loss: 0.0281 - val_accuracy: 0.9960
# Epoch 451/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9999 - val_loss: 0.0279 - val_accuracy: 0.9960
# Epoch 452/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9997 - val_loss: 0.0277 - val_accuracy: 0.9960
# Epoch 453/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9999 - val_loss: 0.0274 - val_accuracy: 0.9960
# Epoch 454/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9999 - val_loss: 0.0273 - val_accuracy: 0.9960
# Epoch 455/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9997 - val_loss: 0.0272 - val_accuracy: 0.9960
# Epoch 456/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9999 - val_loss: 0.0268 - val_accuracy: 0.9960
# Epoch 457/1000
# 237/237 - 1s - loss: 0.0089 - accuracy: 0.9999 - val_loss: 0.0277 - val_accuracy: 0.9960
# Epoch 458/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9999 - val_loss: 0.0272 - val_accuracy: 0.9960
# Epoch 459/1000
# 237/237 - 1s - loss: 0.0089 - accuracy: 0.9999 - val_loss: 0.0275 - val_accuracy: 0.9960
# Epoch 460/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9997 - val_loss: 0.0277 - val_accuracy: 0.9960
# Epoch 461/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9999 - val_loss: 0.0267 - val_accuracy: 0.9960
# Epoch 462/1000
# 237/237 - 1s - loss: 0.0089 - accuracy: 0.9999 - val_loss: 0.0272 - val_accuracy: 0.9960
# Epoch 463/1000
# ...
# Epoch 848/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9968
# Epoch 849/1000
# 237/237 - 1s - loss: 0.0065 - accuracy: 0.9999 - val_loss: 0.0212 - val_accuracy: 0.9968
# Epoch 850/1000
# 237/237 - 1s - loss: 0.0065 - accuracy: 0.9999 - val_loss: 0.0216 - val_accuracy: 0.9968
# Epoch 851/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9968
# Epoch 852/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 0.9964
# Epoch 853/1000
# 237/237 - 1s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9964
# Epoch 854/1000
# 237/237 - 1s - loss: 0.0065 - accuracy: 0.9999 - val_loss: 0.0215 - val_accuracy: 0.9964
# Epoch 855/1000
# 237/237 - 1s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 0.9968
# Epoch 856/1000
# 237/237 - 1s - loss: 0.0065 - accuracy: 0.9999 - val_loss: 0.0215 - val_accuracy: 0.9964
# Epoch 857/1000
# 237/237 - 1s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9964
# Epoch 858/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0221 - val_accuracy: 0.9964
# Epoch 859/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9968
# Epoch 860/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9964
# Epoch 861/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9968
# Epoch 862/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0221 - val_accuracy: 0.9964
# Epoch 863/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9964
# Epoch 864/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9968
# Epoch 865/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 0.9999 - val_loss: 0.0213 - val_accuracy: 0.9968
# Epoch 866/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 0.9999 - val_loss: 0.0213 - val_accuracy: 0.9968
# Epoch 867/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9964
# Epoch 868/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9968
# Epoch 869/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 870/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9968
# Epoch 871/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9964
# Epoch 872/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9964
# Epoch 873/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9964
# Epoch 874/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 0.9964
# Epoch 875/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 0.9999 - val_loss: 0.0220 - val_accuracy: 0.9964
# Epoch 876/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9968
# Epoch 877/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 0.9999 - val_loss: 0.0213 - val_accuracy: 0.9968
# Epoch 878/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9968
# Epoch 879/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 0.9999 - val_loss: 0.0224 - val_accuracy: 0.9964
# Epoch 880/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9968
# Epoch 881/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9964
# Epoch 882/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 0.9999 - val_loss: 0.0213 - val_accuracy: 0.9968
# Epoch 883/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9964
# Epoch 884/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9964
# Epoch 885/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 0.9999 - val_loss: 0.0214 - val_accuracy: 0.9964
# Epoch 886/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9964
# Epoch 887/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9964
# Epoch 888/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 889/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9968
# Epoch 890/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9968
# Epoch 891/1000
# 237/237 - 1s - loss: 0.0064 - accuracy: 0.9999 - val_loss: 0.0218 - val_accuracy: 0.9964
# Epoch 892/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9964
# Epoch 893/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9968
# Epoch 894/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9968
# Epoch 895/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9964
# Epoch 896/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 897/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9964
# Epoch 898/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 0.9999 - val_loss: 0.0220 - val_accuracy: 0.9964
# Epoch 899/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9964
# Epoch 900/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 0.9999 - val_loss: 0.0208 - val_accuracy: 0.9968
# Epoch 901/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 902/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 0.9999 - val_loss: 0.0212 - val_accuracy: 0.9968
# Epoch 903/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9968
# Epoch 904/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 0.9999 - val_loss: 0.0214 - val_accuracy: 0.9964
# Epoch 905/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9968
# Epoch 906/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 0.9964
# Epoch 907/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9964
# Epoch 908/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9964
# Epoch 909/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9964
# Epoch 910/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 0.9964
# Epoch 911/1000
# 237/237 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9964
# Epoch 912/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9964
# Epoch 913/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9968
# Epoch 914/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9964
# Epoch 915/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9964
# Epoch 916/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9964
# Epoch 917/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 0.9964
# Epoch 918/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9964
# Epoch 919/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9964
# Epoch 920/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9964
# Epoch 921/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9964
# Epoch 922/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9964
# Epoch 923/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 0.9999 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 924/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 0.9999 - val_loss: 0.0211 - val_accuracy: 0.9964
# Epoch 925/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9968
# Epoch 926/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9964
# Epoch 927/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9968
# Epoch 928/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9964
# Epoch 929/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9964
# Epoch 930/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9964
# Epoch 931/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9968
# Epoch 932/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9968
# Epoch 933/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9964
# Epoch 934/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9968
# Epoch 935/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9964
# Epoch 936/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9968
# Epoch 937/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9964
# Epoch 938/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9964
# Epoch 939/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9964
# Epoch 940/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9964
# Epoch 941/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9964
# Epoch 942/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9964
# Epoch 943/1000
# 237/237 - 1s - loss: 0.0062 - accuracy: 0.9999 - val_loss: 0.0206 - val_accuracy: 0.9968
# Epoch 944/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9964
# Epoch 945/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9968
# Epoch 946/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 0.9999 - val_loss: 0.0212 - val_accuracy: 0.9964
# Epoch 947/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9968
# Epoch 948/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9964
# Epoch 949/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9964
# Epoch 950/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 0.9999 - val_loss: 0.0211 - val_accuracy: 0.9968
# Epoch 951/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9964
# Epoch 952/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9964
# Epoch 953/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9964
# Epoch 954/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9968
# Epoch 955/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9964
# Epoch 956/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9968
# Epoch 957/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9968
# Epoch 958/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9964
# Epoch 959/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9964
# Epoch 960/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9964
# Epoch 961/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 0.9999 - val_loss: 0.0208 - val_accuracy: 0.9964
# Epoch 962/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9964
# Epoch 963/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 0.9999 - val_loss: 0.0209 - val_accuracy: 0.9968
# Epoch 964/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9964
# Epoch 965/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9964
# Epoch 966/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 967/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9968
# Epoch 968/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9964
# Epoch 969/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9964
# Epoch 970/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9964
# Epoch 971/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9964
# Epoch 972/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9964
# Epoch 973/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9968
# Epoch 974/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9964
# Epoch 975/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 0.9999 - val_loss: 0.0211 - val_accuracy: 0.9964
# Epoch 976/1000
# 237/237 - 1s - loss: 0.0061 - accuracy: 0.9999 - val_loss: 0.0205 - val_accuracy: 0.9964
# Epoch 977/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9964
# Epoch 978/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9964
# Epoch 979/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9964
# Epoch 980/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9964
# Epoch 981/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9968
# Epoch 982/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9964
# Epoch 983/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 0.9999 - val_loss: 0.0211 - val_accuracy: 0.9964
# Epoch 984/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 0.9999 - val_loss: 0.0207 - val_accuracy: 0.9964
# Epoch 985/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9964
# Epoch 986/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 987/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9968
# Epoch 988/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9964
# Epoch 989/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9964
# Epoch 990/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9964
# Epoch 991/1000
# 237/237 - 1s - loss: 0.0060 - accuracy: 0.9999 - val_loss: 0.0205 - val_accuracy: 0.9964
# Epoch 992/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9964
# Epoch 993/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9964
# Epoch 994/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9964
# Epoch 995/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9964
# Epoch 996/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9964
# Epoch 997/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9964
# Epoch 998/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9968
# Epoch 999/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9964
# Epoch 1000/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9964

# %%
import seaborn
plt.style.use('seaborn-white')
plt.figure(figsize=(8,4))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training Acc', 'Test Acc'], loc='lower right')
plt.show()

# summarize history for loss
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], 'o-')
plt.plot(history.history['val_loss'], 'x-')
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training Loss', 'Test Loss'], loc='upper right')

plt.show()

plt.figure()
plt.figure(figsize=(8,4))
N = epochs
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="center right")

# %%
(eval_loss, eval_accuracy) = model.evaluate(validation_data, validation_labels, batch_size= batch_size, verbose=1)

print("Validation Accuracy: {:.4f}%".format(eval_accuracy * 100))
print("Validation Loss: {}".format(eval_loss))
# Out:
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 0.9964
# Validation Accuracy: 99.6424%
# Validation Loss: 0.020717628300189972

# %%
from sklearn.metrics import accuracy_score,roc_curve, confusion_matrix, roc_auc_score, auc, f1_score

preds = model.predict(test_data)

predictions = [i.argmax() for i in preds]
y_true = [i.argmax() for i in test_labels]
cm = confusion_matrix(y_pred=predictions, y_true=y_true)

print('Accuracy {}'.format(accuracy_score(y_true=y_true, y_pred=predictions)))
# Out:
# Accuracy 0.9971846846846847

# %%
plt.rcParams["axes.grid"] = False
plt.rcParams.update({'font.size': 20})

labels = []

label = test_generator.class_indices
indexlabel = dict((value, key) for key, value in label.items())

for k,v in indexlabel.items():
    labels.append(v)

from sklearn.metrics import confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion Matrix')

    print(cm)
#     fig = plt.figure()
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
#     plt.title(title)
#     plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
#     plt.savefig('plots/3.InceptionV3-2-Private-DataSet-CM.png', bbox_inches='tight', dpi = 100) 


plt.figure(figsize=(10,10))
plot_confusion_matrix(cm, classes=labels, title=' ')
# Out:
# Confusion Matrix
# [[354   0   0   0]
#  [  0 411   0   1]
#  [  1   3 651   0]
#  [  0   0   0 355]]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
y_pred=predictions
y_pred_probabilities=y_pred

# y_pred = np.argmax(y_pred,axis = 1) 
y_actual = y_true

classnames=[]
for classname in test_generator.class_indices:
    classnames.append(classname)

confusion_mtx = confusion_matrix(y_actual, y_pred) 
print(confusion_mtx)
target_names = classnames
print(classification_report(y_actual, y_pred, target_names=target_names))
# Out:
# [[354   0   0   0]
#  [  0 411   0   1]
#  [  1   3 651   0]
#  [  0   0   0 355]]
#               precision    recall  f1-score   support
#
#         left       1.00      1.00      1.00       354
#        right       0.99      1.00      1.00       412
#      sitting       1.00      0.99      1.00       655
#     standing       1.00      1.00      1.00       355
#
#     accuracy                           1.00      1776
#    macro avg       1.00      1.00      1.00      1776
# weighted avg       1.00      1.00      1.00      1776

# %%
total=sum(sum(cm))

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity*100 )

Specificity = cm[1,1]/(cm[1,1]+cm[0,1])
print('Specificity : ', Specificity*100 )
# Out:
# Sensitivity :  100.0
# Specificity :  100.0

# %%
y_pred_class = model.predict(test_data, verbose=1)

y_pred_class = [np.argmax(r) for r in y_pred_class]
test_y = [np.argmax(r) for r in test_labels]


from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, cohen_kappa_score, roc_auc_score, roc_curve

# Precision
print('Precision = ', precision_score(test_y, y_pred_class, average='weighted'))
# (None, 'micro', 'macro', 'weighted', 'samples')

# Recall
print('Recall = ', recall_score(test_y, y_pred_class, average='weighted'))

# f1_score
print('f1_score = ', f1_score(test_y, y_pred_class, average='weighted'))
# Out:
# 56/56 [==============================] - 0s 1ms/step
# Precision =  0.997196012749885
# Recall =  0.9971846846846847
# f1_score =  0.9971847553458545

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelBinarizer

def multiclass_roc_auc_score(y_test, y_pred, average="weighted"):
    label_binarizer = LabelBinarizer()
    label_binarizer.fit(y_test)

    truth = label_binarizer.transform(y_test)
    pred = label_binarizer.transform(y_pred)
    return roc_auc_score(truth, pred, average=average)
# roc_auc_score
print('roc_auc_score = ', multiclass_roc_auc_score(test_y, y_pred_class))
# Out:
# roc_auc_score =  0.9981968109310222

# %%
predict = model.predict_proba(test_data, batch_size=batch_size, verbose=1)
# Out:
# 56/56 [==============================] - 0s 1ms/step

# %%
from sklearn.preprocessing import label_binarize

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
y = label_binarize(test_labels, classes=[0, 1, 2, 3])
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y[:, i], predict[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y.ravel(), predict.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

from scipy import interp
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(num_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= num_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams["axes.grid"] = False
plt.rcParams.update({'font.size': 15})

from itertools import cycle
classnames=[]
for classname in test_generator.class_indices:
    classnames.append(classname)
    

plt.figure(figsize=(10, 10))
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),linewidth=2)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         linewidth=2)
plot_name = 'no variation'
colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])

for i, color in zip(range(num_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()

# %%
# Zoom in view of the upper left corner.
plt.figure(figsize=(12,10))
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)


plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=1)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=1)

colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")

plt.show()

# %%
from sklearn.manifold.t_sne import TSNE

model_predictions = np.vstack(preds)
classes = np.hstack(y_pred)

tsne = TSNE(n_components=2)
tsne_data = tsne.fit_transform(model_predictions)

seaborn.scatterplot(tsne_data[:,0], tsne_data[:,1], hue=classes)

# %%
from sklearn.metrics import accuracy_score,roc_curve, confusion_matrix, roc_auc_score, auc, f1_score, classification_report
import sklearn

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier, plot_importance
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

from sklearn.svm import SVC
from PIL import Image
from sklearn.model_selection import KFold, train_test_split
from sklearn.model_selection import cross_val_score

# %%
train_data = np.load(extracted_features_dir+'bottleneck_features_train_'+model_name+'.npy')
validation_data = np.load(extracted_features_dir+'bottleneck_features_validation_'+model_name+'.npy')
test_data = np.load(extracted_features_dir+'bottleneck_features_test_'+model_name+'.npy')

train_labels = train_generator.classes
validation_labels = validation_generator.classes
test_labels = test_generator.classes

# %%
print("Training Data Shape : {0}".format(train_data.shape))
print("Training Data label Shape : {0}".format(train_labels.shape))
# Out:
# Training Data Shape : (7556, 2048)
# Training Data label Shape : (7556,)

# %% [markdown]
#  # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()
clf.fit(train_data, train_labels)
# Out:
# RandomForestClassifier()

# %%
print(clf.score(train_data, train_labels))
print(clf.score(validation_data, validation_labels ))
print(clf.score(test_data, test_labels))
# Out:
# 1.0
# 0.9856972586412396
# 0.9881756756756757

# %%
y_test_pred = clf.predict(test_data)
clf_test = accuracy_score(test_labels, y_test_pred)
print('Random Forest test accuracies %.4f' % (clf_test))
# Out:
# Random Forest test accuracies 0.9882

# %%
print(classification_report(test_labels, y_test_pred))
print(confusion_matrix(test_labels, y_test_pred))
print(accuracy_score(test_labels, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       354
#            1       1.00      1.00      1.00       412
#            2       0.99      0.98      0.98       655
#            3       0.96      0.98      0.97       355
#
#     accuracy                           0.99      1776
#    macro avg       0.99      0.99      0.99      1776
# weighted avg       0.99      0.99      0.99      1776
#
# [[354   0   0   0]
#  [  0 410   1   1]
#  [  0   0 642  13]
#  [  0   0   6 349]]
# 0.9881756756756757

# %% [markdown]
# # KNeighborsClassifier

# %%
clf = KNeighborsClassifier(n_neighbors=8)
clf.fit(train_data, train_labels)
print("Train accuracy", clf.score(train_data, train_labels))
print("Validation accuracy", clf.score(validation_data, validation_labels ))
print("Test accuracy", clf.score(test_data, test_labels))

y_test_pred = clf.predict(test_data)
clf_test = accuracy_score(test_labels, y_test_pred)
print('KNeighbors Classifier test accuracies %.4f' % (clf_test))
# Out:
# Train accuracy 0.9984118581259925
# Validation accuracy 0.9698053237981724
# Test accuracy 0.9904279279279279
# KNeighbors Classifier test accuracies 0.9904

# %%
print(classification_report(test_labels, y_test_pred))
print(confusion_matrix(test_labels, y_test_pred))
print(accuracy_score(test_labels, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       354
#            1       1.00      1.00      1.00       412
#            2       0.99      0.98      0.99       655
#            3       1.00      0.99      0.99       355
#
#     accuracy                           0.99      1776
#    macro avg       0.99      0.99      0.99      1776
# weighted avg       0.99      0.99      0.99      1776
#
# [[354   0   0   0]
#  [  0 412   0   0]
#  [ 10   2 643   0]
#  [  0   0   5 350]]
# 0.9904279279279279

# %% [markdown]
# # BaggingClassifier

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier

clf = BaggingClassifier(RandomForestClassifier(), n_estimators = 300 )
clf.fit(train_data, train_labels)
print("Train accuracy", clf.score(train_data, train_labels))
print("Validation accuracy", clf.score(validation_data, validation_labels ))
print("Test accuracy", clf.score(test_data, test_labels))

y_test_pred = clf.predict(test_data)
clf_test = accuracy_score(test_labels, y_test_pred)
print('Bagging Classifier test accuracies %.4f' % (clf_test))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-defe26ca7522> in <module>
#       3
#       4 clf = BaggingClassifier(RandomForestClassifier(), n_estimators = 300 )
# ----> 5 clf.fit(train_data, train_labels)
#       6 print("Train accuracy", clf.score(train_data, train_labels))
#       7 print("Validation accuracy", clf.score(validation_data, validation_labels ))
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_bagging.py in fit(self, X, y, sample_weight)
#     241         self : object
#     242         """
# --> 243         return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#     244
#     245     def _parallel_args(self):
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_bagging.py in _fit(self, X, y, max_samples, max_depth, sample_weight)
#     378                 total_n_estimators,
#     379                 verbose=self.verbose)
# --> 380             for i in range(n_jobs))
#     381
#     382         # Reduce
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# /opt/conda/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# /opt/conda/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_bagging.py in _parallel_build_estimators(n_estimators, ensemble, X, y, sample_weight, seeds, total_n_estimators, verbose)
#     108                 curr_sample_weight[not_indices_mask] = 0
#     109
# --> 110             estimator.fit(X[:, features], y, sample_weight=curr_sample_weight)
#     111
#     112         else:
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     390                     verbose=self.verbose, class_weight=self.class_weight,
#     391                     n_samples_bootstrap=n_samples_bootstrap)
# --> 392                 for i, t in enumerate(trees))
#     393
#     394             # Collect newly grown trees
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# /opt/conda/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# /opt/conda/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     892             sample_weight=sample_weight,
#     893             check_input=check_input,
# --> 894             X_idx_sorted=X_idx_sorted)
#     895         return self
#     896
#
# /opt/conda/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
print(classification_report(test_labels, y_test_pred))

print(confusion_matrix(test_labels, y_test_pred))
print(accuracy_score(test_labels, y_test_pred))

# %% [markdown]
# # AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

clf = AdaBoostClassifier(DecisionTreeClassifier(), n_estimators = 300 )
clf.fit(train_data, train_labels)
print("Train accuracy", clf.score(train_data, train_labels))
print("Validation accuracy", clf.score(validation_data, validation_labels ))
print("Test accuracy", clf.score(test_data, test_labels))

predictions = clf.predict(test_data)
clf_test = accuracy_score(test_labels, y_test_pred)
print('AdaBoost Classifier test accuracies %.4f' % (clf_test))

# %%
print(classification_report(test_labels, y_test_pred))

print(confusion_matrix(test_labels, y_test_pred))
print(accuracy_score(test_labels, y_test_pred))

# %% [markdown]
# # XGBClassifier

# %%
import xgboost as xgb
from xgboost import XGBClassifier

clf = xgb.XGBClassifier()
clf.fit(train_data, train_labels)
print("Train accuracy", clf.score(train_data, train_labels))
print("Validation accuracy", clf.score(validation_data, validation_labels ))
print("Test accuracy", clf.score(test_data, test_labels))

y_test_pred = clf.predict(test_data)
clf_test = accuracy_score(test_labels, y_test_pred)
print('XGBClassifier test accuracies %.4f' % (clf_test))

# %%
print(classification_report(test_labels, y_test_pred))

print(confusion_matrix(test_labels, y_test_pred))
print(accuracy_score(test_labels, y_test_pred))

# %%
output_filename = "Pig_InceptionV3"
dir_name = "/kaggle/working"

import shutil
shutil.make_archive(output_filename, "zip", dir_name)
# Out:
# '/kaggle/working/Pig_InceptionV3.zip'

# %%
print("Done!!!")
