# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 17093720489183991733,
#  name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 1980112158150973784
#  physical_device_desc: "device: XLA_CPU device",
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15695549568
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 15189336133101165696
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0",
#  name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 276347429385545533
#  physical_device_desc: "device: XLA_GPU device"]

# %%
# from hyperopt import fmin, tpe, hp, STATUS_OK, Trials, partial, rand, space_eval
# from sklearn.metrics import log_loss
import sys
# import time
import math
import os
import pandas as pd
# from keras.callbacks import EarlyStopping
import numpy as np
# from glob import glob
# import cv2
# import skimage
# from skimage.transform import resize
from keras.utils.np_utils import to_categorical
# import keras
# from keras import layers
# from keras import models
# from keras import optimizers
# from keras.models import load_model
# import keras.callbacks as kcall
from keras.optimizers import Adam, RMSprop,SGD
from keras.models import Model
from keras.models import Sequential
from keras.layers import Flatten, Dense, Activation, Dropout, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, Input,concatenate
# from keras.applications.xception import Xception, preprocess_input
from keras.preprocessing.image import ImageDataGenerator
# from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint
# from keras.applications.vgg19 import VGG19
from keras.regularizers import l2, l1

import matplotlib.pyplot as plt
# from keras.layers import Input, concatenate
# from keras import optimizers, metrics, models
# from keras.layers import Input, Flatten, Dense

# %matplotlib inline

# %%
import keras
import tensorflow as tf

print("Keras Version", keras.__version__)
print("tensorflow Version", tf.__version__)
# print("dim_ordering:", K.image_dim_ordering())
# Out:
# Keras Version 2.4.3
# tensorflow Version 2.3.0

# %%
batch_size = 32
img_height, img_width = 800, 600
input_shape = (img_height, img_width, 3)
epochs = 1000

# %%
print(os.listdir("../input/keras-pretrained-models/"))
# Out:
# ['vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5', 'Kuszma.JPG', 'inception_resnet_v2_weights_tf_dim_ordering_tf_kernels.h5', 'inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5', 'inception_v3_weights_tf_dim_ordering_tf_kernels.h5', 'imagenet_class_index.json', 'xception_weights_tf_dim_ordering_tf_kernels.h5', 'resnet50_weights_tf_dim_ordering_tf_kernels.h5', 'resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5', 'inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5', 'xception_weights_tf_dim_ordering_tf_kernels_notop.h5']

# %%
# print(os.listdir("../input/full-keras-pretrained-no-top"))

# %%
train_dir = '../input/data-pig/train/'
test_dir = '../input/data-pig/test/'

# %%
random_seed = np.random.seed(1142)

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True,
    validation_split= 0.25,
    zoom_range=0.2,
    shear_range=0.2)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    seed = random_seed,
    shuffle = False,
    subset = 'training',
    class_mode='categorical')

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    seed = random_seed,
    shuffle = False,
    subset = 'validation',
    class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1. / 255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    seed = random_seed,
    shuffle = False,
    class_mode='categorical')
# Out:
# Found 7556 images belonging to 4 classes.
# Found 2517 images belonging to 4 classes.
# Found 1776 images belonging to 4 classes.

# %%
nb_train_samples = len(train_generator.filenames)
nb_validation_samples = len(validation_generator.filenames)
nb_test_samples = len(test_generator.filenames)

predict_size_train = int(math.ceil(nb_train_samples / batch_size))
predict_size_validation = int(math.ceil(nb_validation_samples / batch_size))
predict_size_test = int(math.ceil(nb_test_samples / batch_size))

num_classes = len(train_generator.class_indices)

print("nb_train_samples:", nb_train_samples)
print("nb_validation_samples:", nb_validation_samples)
print("nb_test_samples:", nb_test_samples)

print("\npredict_size_train:", predict_size_train)
print("predict_size_validation:", predict_size_validation)
print("predict_size_test:", predict_size_test)

print("\n num_classes:", num_classes)
# Out:
# nb_train_samples: 7556
# nb_validation_samples: 2517
# nb_test_samples: 1776
#
# predict_size_train: 237
# predict_size_validation: 79
# predict_size_test: 56
#
#  num_classes: 4

# %%
vgg19_weights ="../input/full-keras-pretrained-no-top/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5"
inception_weights ="../input/full-keras-pretrained-no-top//inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5"
vgg16_weights ="../input/full-keras-pretrained-no-top/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5"
denseNet201_weights ="../input/full-keras-pretrained-no-top/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5"
denseNet121_weights ="../input/full-keras-pretrained-no-top/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5"
resenet50_weights ="../input/full-keras-pretrained-no-top/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5"
inception_resnet_v2_weights ="../input/full-keras-pretrained-no-top/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5"
nasnet_weights ="../input/full-keras-pretrained-no-top/nasnet_large_no_top.h5"
nasnet_mobile_weights ="../input/full-keras-pretrained-no-top/nasnet_mobile_no_top.h5"
mobilenet_weights ="../input/full-keras-pretrained-no-top/mobilenet_1_0_224_tf_no_top.h5"
xception_weights ="../input/keras-pretrained-models/xception_weights_tf_dim_ordering_tf_kernels_notop.h5"

# %%
from keras.applications.vgg19 import VGG19
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.applications.xception import Xception, preprocess_input
from keras.applications import DenseNet201
from keras.applications import DenseNet121
from keras.applications import ResNet50
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.applications import NASNetLarge, NASNetMobile
from keras.applications import MobileNet

input_tensor = Input(shape = input_shape)  

base_model1=DenseNet201(weights=denseNet201_weights, include_top=False, pooling = "avg")

bottleneck_final_model = base_model1

# %%
# for i, layer in enumerate(model.layers):
#     print(i, layer.name)

# %%
os.mkdir("extracted_features")
extracted_features_dir = "extracted_features/" 
model_name = "DenseNet201_descriptors"

# %%
bottleneck_features_train = bottleneck_final_model.predict_generator(train_generator, predict_size_train)
np.save(extracted_features_dir+'bottleneck_features_train_'+model_name+'.npy', bottleneck_features_train)

# %%
bottleneck_features_validation = bottleneck_final_model.predict_generator(validation_generator, predict_size_validation)
np.save(extracted_features_dir+'bottleneck_features_validation_'+model_name+'.npy', bottleneck_features_validation)

# %%
bottleneck_features_test = bottleneck_final_model.predict_generator(test_generator, predict_size_test)
np.save(extracted_features_dir+'bottleneck_features_test_'+model_name+'.npy', bottleneck_features_test)

# %%
# import tensorflow as tf
# from keras.backend.tensorflow_backend import get_session
# from keras.backend.tensorflow_backend import clear_session
# from keras.backend.tensorflow_backend import set_session

# def reset_keras_tf_session():
#     """
#     this function clears the gpu memory and set the 
#     tf session to not use the whole gpu
#     """
#     sess = get_session()
#     clear_session()
#     sess.close()
#     sess = get_session()

#     config = tf.ConfigProto()
#     config.gpu_options.allow_growth = True
#     set_session(tf.Session(config=config))


# reset_keras_tf_session()

# %%
train_data = np.load(extracted_features_dir+'bottleneck_features_train_'+model_name+'.npy')
validation_data = np.load(extracted_features_dir+'bottleneck_features_validation_'+model_name+'.npy')
test_data = np.load(extracted_features_dir+'bottleneck_features_test_'+model_name+'.npy')

train_labels = train_generator.classes
train_labels = to_categorical(train_labels, num_classes=num_classes)

validation_labels = validation_generator.classes
validation_labels = to_categorical(validation_labels, num_classes=num_classes)

test_labels = test_generator.classes
test_labels = to_categorical(test_labels, num_classes=num_classes)

# %%
model = Sequential()
model.add(Dense(512, activation="selu", kernel_regularizer=l2(1e-06), bias_regularizer=l2(1e-05), activity_regularizer=l1(0.0001)))

model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

adam_opt=Adam(lr = 1e-06, beta_1=0.7, beta_2=0.5)
model.compile(optimizer=adam_opt, loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(validation_data, validation_labels),
                    verbose= 2)
# Out:
# Epoch 1/1000
# 237/237 - 1s - loss: 1.5206 - accuracy: 0.3289 - val_loss: 1.3288 - val_accuracy: 0.3770
# Epoch 2/1000
# 237/237 - 1s - loss: 1.4495 - accuracy: 0.3413 - val_loss: 1.2938 - val_accuracy: 0.3774
# Epoch 3/1000
# 237/237 - 1s - loss: 1.4060 - accuracy: 0.3646 - val_loss: 1.2592 - val_accuracy: 0.3842
# Epoch 4/1000
# 237/237 - 1s - loss: 1.3544 - accuracy: 0.3933 - val_loss: 1.2270 - val_accuracy: 0.3909
# Epoch 5/1000
# 237/237 - 1s - loss: 1.3057 - accuracy: 0.4099 - val_loss: 1.1951 - val_accuracy: 0.4068
# Epoch 6/1000
# 237/237 - 1s - loss: 1.2469 - accuracy: 0.4517 - val_loss: 1.1631 - val_accuracy: 0.4930
# Epoch 7/1000
# 237/237 - 1s - loss: 1.2145 - accuracy: 0.4663 - val_loss: 1.1310 - val_accuracy: 0.5411
# Epoch 8/1000
# 237/237 - 1s - loss: 1.1593 - accuracy: 0.5079 - val_loss: 1.1009 - val_accuracy: 0.6456
# Epoch 9/1000
# 237/237 - 1s - loss: 1.1258 - accuracy: 0.5273 - val_loss: 1.0713 - val_accuracy: 0.7124
# Epoch 10/1000
# 237/237 - 1s - loss: 1.0776 - accuracy: 0.5487 - val_loss: 1.0422 - val_accuracy: 0.7632
# Epoch 11/1000
# 237/237 - 1s - loss: 1.0348 - accuracy: 0.5895 - val_loss: 1.0126 - val_accuracy: 0.7878
# Epoch 12/1000
# 237/237 - 1s - loss: 1.0015 - accuracy: 0.6137 - val_loss: 0.9855 - val_accuracy: 0.8168
# Epoch 13/1000
# 237/237 - 1s - loss: 0.9620 - accuracy: 0.6398 - val_loss: 0.9576 - val_accuracy: 0.8192
# Epoch 14/1000
# 237/237 - 1s - loss: 0.9217 - accuracy: 0.6750 - val_loss: 0.9298 - val_accuracy: 0.8260
# Epoch 15/1000
# 237/237 - 1s - loss: 0.8856 - accuracy: 0.6987 - val_loss: 0.9046 - val_accuracy: 0.8367
# Epoch 16/1000
# 237/237 - 1s - loss: 0.8425 - accuracy: 0.7320 - val_loss: 0.8770 - val_accuracy: 0.8435
# Epoch 17/1000
# 237/237 - 1s - loss: 0.8124 - accuracy: 0.7471 - val_loss: 0.8536 - val_accuracy: 0.8530
# Epoch 18/1000
# 237/237 - 1s - loss: 0.7742 - accuracy: 0.7777 - val_loss: 0.8269 - val_accuracy: 0.8725
# Epoch 19/1000
# 237/237 - 1s - loss: 0.7398 - accuracy: 0.8048 - val_loss: 0.8019 - val_accuracy: 0.8824
# Epoch 20/1000
# 237/237 - 1s - loss: 0.7108 - accuracy: 0.8274 - val_loss: 0.7797 - val_accuracy: 0.8947
# Epoch 21/1000
# 237/237 - 1s - loss: 0.6828 - accuracy: 0.8481 - val_loss: 0.7563 - val_accuracy: 0.8943
# Epoch 22/1000
# 237/237 - 1s - loss: 0.6527 - accuracy: 0.8641 - val_loss: 0.7348 - val_accuracy: 0.9090
# Epoch 23/1000
# 237/237 - 1s - loss: 0.6240 - accuracy: 0.8796 - val_loss: 0.7104 - val_accuracy: 0.9142
# Epoch 24/1000
# 237/237 - 1s - loss: 0.5964 - accuracy: 0.8936 - val_loss: 0.6916 - val_accuracy: 0.9289
# Epoch 25/1000
# 237/237 - 1s - loss: 0.5685 - accuracy: 0.9046 - val_loss: 0.6688 - val_accuracy: 0.9352
# Epoch 26/1000
# 237/237 - 1s - loss: 0.5442 - accuracy: 0.9174 - val_loss: 0.6514 - val_accuracy: 0.9376
# Epoch 27/1000
# 237/237 - 1s - loss: 0.5226 - accuracy: 0.9279 - val_loss: 0.6286 - val_accuracy: 0.9392
# Epoch 28/1000
# 237/237 - 1s - loss: 0.4951 - accuracy: 0.9377 - val_loss: 0.6054 - val_accuracy: 0.9468
# Epoch 29/1000
# 237/237 - 1s - loss: 0.4718 - accuracy: 0.9512 - val_loss: 0.5903 - val_accuracy: 0.9444
# Epoch 30/1000
# 237/237 - 1s - loss: 0.4552 - accuracy: 0.9496 - val_loss: 0.5712 - val_accuracy: 0.9551
# Epoch 31/1000
# 237/237 - 1s - loss: 0.4356 - accuracy: 0.9578 - val_loss: 0.5536 - val_accuracy: 0.9634
# Epoch 32/1000
# 237/237 - 1s - loss: 0.4161 - accuracy: 0.9633 - val_loss: 0.5364 - val_accuracy: 0.9674
# Epoch 33/1000
# 237/237 - 1s - loss: 0.3937 - accuracy: 0.9688 - val_loss: 0.5178 - val_accuracy: 0.9718
# Epoch 34/1000
# 237/237 - 1s - loss: 0.3819 - accuracy: 0.9718 - val_loss: 0.5023 - val_accuracy: 0.9730
# Epoch 35/1000
# 237/237 - 1s - loss: 0.3613 - accuracy: 0.9747 - val_loss: 0.4859 - val_accuracy: 0.9734
# Epoch 36/1000
# 237/237 - 1s - loss: 0.3459 - accuracy: 0.9776 - val_loss: 0.4710 - val_accuracy: 0.9758
# Epoch 37/1000
# 237/237 - 1s - loss: 0.3289 - accuracy: 0.9816 - val_loss: 0.4537 - val_accuracy: 0.9785
# Epoch 38/1000
# 237/237 - 1s - loss: 0.3167 - accuracy: 0.9794 - val_loss: 0.4426 - val_accuracy: 0.9789
# Epoch 39/1000
# 237/237 - 1s - loss: 0.3037 - accuracy: 0.9825 - val_loss: 0.4275 - val_accuracy: 0.9809
# Epoch 40/1000
# 237/237 - 1s - loss: 0.2901 - accuracy: 0.9844 - val_loss: 0.4186 - val_accuracy: 0.9837
# Epoch 41/1000
# 237/237 - 1s - loss: 0.2777 - accuracy: 0.9865 - val_loss: 0.4018 - val_accuracy: 0.9817
# Epoch 42/1000
# 237/237 - 1s - loss: 0.2655 - accuracy: 0.9882 - val_loss: 0.3914 - val_accuracy: 0.9865
# Epoch 43/1000
# 237/237 - 1s - loss: 0.2541 - accuracy: 0.9897 - val_loss: 0.3807 - val_accuracy: 0.9889
# Epoch 44/1000
# 237/237 - 1s - loss: 0.2442 - accuracy: 0.9894 - val_loss: 0.3641 - val_accuracy: 0.9897
# Epoch 45/1000
# 237/237 - 1s - loss: 0.2338 - accuracy: 0.9905 - val_loss: 0.3535 - val_accuracy: 0.9897
# Epoch 46/1000
# 237/237 - 1s - loss: 0.2247 - accuracy: 0.9918 - val_loss: 0.3413 - val_accuracy: 0.9897
# Epoch 47/1000
# 237/237 - 1s - loss: 0.2139 - accuracy: 0.9911 - val_loss: 0.3331 - val_accuracy: 0.9901
# Epoch 48/1000
# 237/237 - 1s - loss: 0.2069 - accuracy: 0.9922 - val_loss: 0.3208 - val_accuracy: 0.9901
# Epoch 49/1000
# 237/237 - 1s - loss: 0.1963 - accuracy: 0.9925 - val_loss: 0.3104 - val_accuracy: 0.9936
# Epoch 50/1000
# 237/237 - 1s - loss: 0.1867 - accuracy: 0.9940 - val_loss: 0.3027 - val_accuracy: 0.9932
# Epoch 51/1000
# 237/237 - 1s - loss: 0.1817 - accuracy: 0.9958 - val_loss: 0.2902 - val_accuracy: 0.9936
# Epoch 52/1000
# 237/237 - 1s - loss: 0.1734 - accuracy: 0.9946 - val_loss: 0.2812 - val_accuracy: 0.9940
# Epoch 53/1000
# 237/237 - 1s - loss: 0.1670 - accuracy: 0.9942 - val_loss: 0.2760 - val_accuracy: 0.9940
# Epoch 54/1000
# 237/237 - 1s - loss: 0.1617 - accuracy: 0.9944 - val_loss: 0.2668 - val_accuracy: 0.9944
# Epoch 55/1000
# 237/237 - 1s - loss: 0.1555 - accuracy: 0.9947 - val_loss: 0.2579 - val_accuracy: 0.9948
# Epoch 56/1000
# 237/237 - 1s - loss: 0.1495 - accuracy: 0.9944 - val_loss: 0.2479 - val_accuracy: 0.9948
# Epoch 57/1000
# 237/237 - 1s - loss: 0.1438 - accuracy: 0.9955 - val_loss: 0.2422 - val_accuracy: 0.9948
# Epoch 58/1000
# 237/237 - 1s - loss: 0.1369 - accuracy: 0.9966 - val_loss: 0.2379 - val_accuracy: 0.9952
# Epoch 59/1000
# 237/237 - 1s - loss: 0.1323 - accuracy: 0.9959 - val_loss: 0.2324 - val_accuracy: 0.9956
# Epoch 60/1000
# 237/237 - 1s - loss: 0.1289 - accuracy: 0.9958 - val_loss: 0.2216 - val_accuracy: 0.9952
# Epoch 61/1000
# 237/237 - 1s - loss: 0.1232 - accuracy: 0.9959 - val_loss: 0.2167 - val_accuracy: 0.9952
# Epoch 62/1000
# 237/237 - 1s - loss: 0.1184 - accuracy: 0.9971 - val_loss: 0.2110 - val_accuracy: 0.9960
# Epoch 63/1000
# 237/237 - 1s - loss: 0.1158 - accuracy: 0.9966 - val_loss: 0.2078 - val_accuracy: 0.9964
# Epoch 64/1000
# 237/237 - 1s - loss: 0.1110 - accuracy: 0.9972 - val_loss: 0.1980 - val_accuracy: 0.9964
# Epoch 65/1000
# 237/237 - 1s - loss: 0.1071 - accuracy: 0.9971 - val_loss: 0.1922 - val_accuracy: 0.9964
# Epoch 66/1000
# 237/237 - 1s - loss: 0.1042 - accuracy: 0.9968 - val_loss: 0.1868 - val_accuracy: 0.9968
# Epoch 67/1000
# 237/237 - 1s - loss: 0.1002 - accuracy: 0.9975 - val_loss: 0.1843 - val_accuracy: 0.9960
# Epoch 68/1000
# 237/237 - 1s - loss: 0.0957 - accuracy: 0.9968 - val_loss: 0.1779 - val_accuracy: 0.9960
# Epoch 69/1000
# 237/237 - 1s - loss: 0.0932 - accuracy: 0.9972 - val_loss: 0.1745 - val_accuracy: 0.9960
# Epoch 70/1000
# 237/237 - 1s - loss: 0.0900 - accuracy: 0.9979 - val_loss: 0.1705 - val_accuracy: 0.9960
# Epoch 71/1000
# 237/237 - 1s - loss: 0.0878 - accuracy: 0.9974 - val_loss: 0.1646 - val_accuracy: 0.9956
# Epoch 72/1000
# 237/237 - 1s - loss: 0.0848 - accuracy: 0.9976 - val_loss: 0.1599 - val_accuracy: 0.9960
# Epoch 73/1000
# 237/237 - 1s - loss: 0.0820 - accuracy: 0.9985 - val_loss: 0.1537 - val_accuracy: 0.9960
# Epoch 74/1000
# 237/237 - 1s - loss: 0.0791 - accuracy: 0.9980 - val_loss: 0.1519 - val_accuracy: 0.9956
# Epoch 75/1000
# 237/237 - 1s - loss: 0.0766 - accuracy: 0.9979 - val_loss: 0.1488 - val_accuracy: 0.9956
# Epoch 76/1000
# 237/237 - 1s - loss: 0.0748 - accuracy: 0.9988 - val_loss: 0.1418 - val_accuracy: 0.9956
# Epoch 77/1000
# 237/237 - 1s - loss: 0.0727 - accuracy: 0.9981 - val_loss: 0.1400 - val_accuracy: 0.9956
# Epoch 78/1000
# 237/237 - 1s - loss: 0.0700 - accuracy: 0.9981 - val_loss: 0.1364 - val_accuracy: 0.9952
# Epoch 79/1000
# 237/237 - 1s - loss: 0.0687 - accuracy: 0.9987 - val_loss: 0.1351 - val_accuracy: 0.9952
# Epoch 80/1000
# 237/237 - 1s - loss: 0.0673 - accuracy: 0.9985 - val_loss: 0.1322 - val_accuracy: 0.9960
# Epoch 81/1000
# 237/237 - 1s - loss: 0.0651 - accuracy: 0.9981 - val_loss: 0.1288 - val_accuracy: 0.9956
# Epoch 82/1000
# 237/237 - 1s - loss: 0.0633 - accuracy: 0.9984 - val_loss: 0.1237 - val_accuracy: 0.9960
# Epoch 83/1000
# 237/237 - 1s - loss: 0.0615 - accuracy: 0.9987 - val_loss: 0.1217 - val_accuracy: 0.9960
# Epoch 84/1000
# 237/237 - 1s - loss: 0.0598 - accuracy: 0.9985 - val_loss: 0.1189 - val_accuracy: 0.9956
# Epoch 85/1000
# 237/237 - 1s - loss: 0.0588 - accuracy: 0.9980 - val_loss: 0.1164 - val_accuracy: 0.9956
# Epoch 86/1000
# 237/237 - 1s - loss: 0.0579 - accuracy: 0.9980 - val_loss: 0.1140 - val_accuracy: 0.9960
# Epoch 87/1000
# 237/237 - 1s - loss: 0.0547 - accuracy: 0.9988 - val_loss: 0.1115 - val_accuracy: 0.9960
# Epoch 88/1000
# 237/237 - 1s - loss: 0.0539 - accuracy: 0.9984 - val_loss: 0.1098 - val_accuracy: 0.9956
# Epoch 89/1000
# 237/237 - 1s - loss: 0.0531 - accuracy: 0.9983 - val_loss: 0.1074 - val_accuracy: 0.9960
# Epoch 90/1000
# 237/237 - 1s - loss: 0.0506 - accuracy: 0.9992 - val_loss: 0.1062 - val_accuracy: 0.9952
# Epoch 91/1000
# 237/237 - 1s - loss: 0.0501 - accuracy: 0.9983 - val_loss: 0.1042 - val_accuracy: 0.9956
# Epoch 92/1000
# 237/237 - 1s - loss: 0.0496 - accuracy: 0.9985 - val_loss: 0.1002 - val_accuracy: 0.9960
# Epoch 93/1000
# 237/237 - 1s - loss: 0.0482 - accuracy: 0.9983 - val_loss: 0.0984 - val_accuracy: 0.9960
# Epoch 94/1000
# 237/237 - 1s - loss: 0.0469 - accuracy: 0.9985 - val_loss: 0.0976 - val_accuracy: 0.9956
# Epoch 95/1000
# 237/237 - 1s - loss: 0.0455 - accuracy: 0.9984 - val_loss: 0.0936 - val_accuracy: 0.9960
# Epoch 96/1000
# 237/237 - 1s - loss: 0.0451 - accuracy: 0.9988 - val_loss: 0.0922 - val_accuracy: 0.9960
# Epoch 97/1000
# 237/237 - 1s - loss: 0.0435 - accuracy: 0.9985 - val_loss: 0.0922 - val_accuracy: 0.9956
# Epoch 98/1000
# 237/237 - 1s - loss: 0.0428 - accuracy: 0.9988 - val_loss: 0.0895 - val_accuracy: 0.9956
# Epoch 99/1000
# 237/237 - 1s - loss: 0.0426 - accuracy: 0.9987 - val_loss: 0.0890 - val_accuracy: 0.9956
# Epoch 100/1000
# 237/237 - 1s - loss: 0.0412 - accuracy: 0.9987 - val_loss: 0.0853 - val_accuracy: 0.9956
# Epoch 101/1000
# 237/237 - 1s - loss: 0.0403 - accuracy: 0.9984 - val_loss: 0.0840 - val_accuracy: 0.9960
# Epoch 102/1000
# 237/237 - 1s - loss: 0.0390 - accuracy: 0.9991 - val_loss: 0.0849 - val_accuracy: 0.9960
# Epoch 103/1000
# 237/237 - 1s - loss: 0.0387 - accuracy: 0.9988 - val_loss: 0.0828 - val_accuracy: 0.9956
# Epoch 104/1000
# 237/237 - 1s - loss: 0.0382 - accuracy: 0.9983 - val_loss: 0.0822 - val_accuracy: 0.9956
# Epoch 105/1000
# 237/237 - 1s - loss: 0.0369 - accuracy: 0.9992 - val_loss: 0.0799 - val_accuracy: 0.9956
# Epoch 106/1000
# 237/237 - 1s - loss: 0.0366 - accuracy: 0.9992 - val_loss: 0.0786 - val_accuracy: 0.9956
# Epoch 107/1000
# 237/237 - 1s - loss: 0.0354 - accuracy: 0.9991 - val_loss: 0.0758 - val_accuracy: 0.9960
# Epoch 108/1000
# 237/237 - 1s - loss: 0.0355 - accuracy: 0.9988 - val_loss: 0.0755 - val_accuracy: 0.9960
# Epoch 109/1000
# 237/237 - 1s - loss: 0.0341 - accuracy: 0.9995 - val_loss: 0.0732 - val_accuracy: 0.9960
# Epoch 110/1000
# 237/237 - 1s - loss: 0.0337 - accuracy: 0.9992 - val_loss: 0.0735 - val_accuracy: 0.9956
# Epoch 111/1000
# 237/237 - 1s - loss: 0.0329 - accuracy: 0.9991 - val_loss: 0.0718 - val_accuracy: 0.9960
# Epoch 112/1000
# 237/237 - 1s - loss: 0.0321 - accuracy: 0.9993 - val_loss: 0.0693 - val_accuracy: 0.9960
# Epoch 113/1000
# 237/237 - 1s - loss: 0.0320 - accuracy: 0.9989 - val_loss: 0.0691 - val_accuracy: 0.9960
# Epoch 114/1000
# 237/237 - 1s - loss: 0.0315 - accuracy: 0.9991 - val_loss: 0.0671 - val_accuracy: 0.9960
# Epoch 115/1000
# 237/237 - 1s - loss: 0.0311 - accuracy: 0.9989 - val_loss: 0.0661 - val_accuracy: 0.9960
# Epoch 116/1000
# 237/237 - 1s - loss: 0.0302 - accuracy: 0.9995 - val_loss: 0.0670 - val_accuracy: 0.9960
# Epoch 117/1000
# 237/237 - 1s - loss: 0.0298 - accuracy: 0.9991 - val_loss: 0.0659 - val_accuracy: 0.9960
# Epoch 118/1000
# 237/237 - 1s - loss: 0.0295 - accuracy: 0.9987 - val_loss: 0.0648 - val_accuracy: 0.9960
# Epoch 119/1000
# 237/237 - 1s - loss: 0.0290 - accuracy: 0.9993 - val_loss: 0.0632 - val_accuracy: 0.9956
# Epoch 120/1000
# 237/237 - 1s - loss: 0.0284 - accuracy: 0.9991 - val_loss: 0.0626 - val_accuracy: 0.9960
# Epoch 121/1000
# 237/237 - 1s - loss: 0.0281 - accuracy: 0.9991 - val_loss: 0.0629 - val_accuracy: 0.9956
# Epoch 122/1000
# 237/237 - 1s - loss: 0.0277 - accuracy: 0.9992 - val_loss: 0.0618 - val_accuracy: 0.9960
# Epoch 123/1000
# 237/237 - 1s - loss: 0.0274 - accuracy: 0.9991 - val_loss: 0.0597 - val_accuracy: 0.9960
# Epoch 124/1000
# 237/237 - 1s - loss: 0.0271 - accuracy: 0.9992 - val_loss: 0.0597 - val_accuracy: 0.9956
# Epoch 125/1000
# 237/237 - 1s - loss: 0.0261 - accuracy: 0.9995 - val_loss: 0.0582 - val_accuracy: 0.9956
# Epoch 126/1000
# 237/237 - 1s - loss: 0.0262 - accuracy: 0.9993 - val_loss: 0.0587 - val_accuracy: 0.9956
# Epoch 127/1000
# 237/237 - 1s - loss: 0.0258 - accuracy: 0.9995 - val_loss: 0.0568 - val_accuracy: 0.9960
# Epoch 128/1000
# 237/237 - 1s - loss: 0.0256 - accuracy: 0.9993 - val_loss: 0.0562 - val_accuracy: 0.9960
# Epoch 129/1000
# 237/237 - 1s - loss: 0.0251 - accuracy: 0.9993 - val_loss: 0.0568 - val_accuracy: 0.9960
# Epoch 130/1000
# 237/237 - 1s - loss: 0.0245 - accuracy: 0.9992 - val_loss: 0.0535 - val_accuracy: 0.9960
# Epoch 131/1000
# 237/237 - 1s - loss: 0.0245 - accuracy: 0.9992 - val_loss: 0.0544 - val_accuracy: 0.9956
# Epoch 132/1000
# 237/237 - 1s - loss: 0.0238 - accuracy: 0.9993 - val_loss: 0.0536 - val_accuracy: 0.9956
# Epoch 133/1000
# 237/237 - 1s - loss: 0.0239 - accuracy: 0.9995 - val_loss: 0.0533 - val_accuracy: 0.9960
# Epoch 134/1000
# 237/237 - 1s - loss: 0.0235 - accuracy: 0.9992 - val_loss: 0.0521 - val_accuracy: 0.9960
# Epoch 135/1000
# 237/237 - 1s - loss: 0.0231 - accuracy: 0.9995 - val_loss: 0.0525 - val_accuracy: 0.9960
# Epoch 136/1000
# 237/237 - 1s - loss: 0.0228 - accuracy: 0.9993 - val_loss: 0.0509 - val_accuracy: 0.9960
# Epoch 137/1000
# 237/237 - 1s - loss: 0.0227 - accuracy: 0.9995 - val_loss: 0.0508 - val_accuracy: 0.9956
# Epoch 138/1000
# 237/237 - 1s - loss: 0.0219 - accuracy: 0.9993 - val_loss: 0.0505 - val_accuracy: 0.9956
# Epoch 139/1000
# 237/237 - 1s - loss: 0.0223 - accuracy: 0.9992 - val_loss: 0.0498 - val_accuracy: 0.9960
# Epoch 140/1000
# 237/237 - 1s - loss: 0.0218 - accuracy: 0.9992 - val_loss: 0.0487 - val_accuracy: 0.9960
# Epoch 141/1000
# 237/237 - 1s - loss: 0.0217 - accuracy: 0.9992 - val_loss: 0.0484 - val_accuracy: 0.9960
# Epoch 142/1000
# 237/237 - 1s - loss: 0.0214 - accuracy: 0.9995 - val_loss: 0.0478 - val_accuracy: 0.9956
# Epoch 143/1000
# 237/237 - 1s - loss: 0.0213 - accuracy: 0.9992 - val_loss: 0.0472 - val_accuracy: 0.9956
# Epoch 144/1000
# 237/237 - 1s - loss: 0.0210 - accuracy: 0.9992 - val_loss: 0.0465 - val_accuracy: 0.9960
# Epoch 145/1000
# 237/237 - 1s - loss: 0.0209 - accuracy: 0.9993 - val_loss: 0.0459 - val_accuracy: 0.9960
# Epoch 146/1000
# 237/237 - 1s - loss: 0.0204 - accuracy: 0.9996 - val_loss: 0.0460 - val_accuracy: 0.9956
# Epoch 147/1000
# 237/237 - 1s - loss: 0.0204 - accuracy: 0.9995 - val_loss: 0.0456 - val_accuracy: 0.9956
# Epoch 148/1000
# 237/237 - 1s - loss: 0.0203 - accuracy: 0.9993 - val_loss: 0.0459 - val_accuracy: 0.9956
# Epoch 149/1000
# 237/237 - 1s - loss: 0.0201 - accuracy: 0.9993 - val_loss: 0.0445 - val_accuracy: 0.9960
# Epoch 150/1000
# 237/237 - 1s - loss: 0.0199 - accuracy: 0.9995 - val_loss: 0.0458 - val_accuracy: 0.9960
# Epoch 151/1000
# 237/237 - 1s - loss: 0.0198 - accuracy: 0.9993 - val_loss: 0.0454 - val_accuracy: 0.9960
# Epoch 152/1000
# 237/237 - 1s - loss: 0.0195 - accuracy: 0.9995 - val_loss: 0.0436 - val_accuracy: 0.9960
# Epoch 153/1000
# 237/237 - 1s - loss: 0.0190 - accuracy: 0.9995 - val_loss: 0.0432 - val_accuracy: 0.9960
# Epoch 154/1000
# 237/237 - 1s - loss: 0.0189 - accuracy: 0.9993 - val_loss: 0.0427 - val_accuracy: 0.9960
# Epoch 155/1000
# 237/237 - 1s - loss: 0.0187 - accuracy: 0.9995 - val_loss: 0.0427 - val_accuracy: 0.9956
# Epoch 156/1000
# 237/237 - 1s - loss: 0.0186 - accuracy: 0.9993 - val_loss: 0.0416 - val_accuracy: 0.9960
# Epoch 157/1000
# 237/237 - 1s - loss: 0.0184 - accuracy: 0.9995 - val_loss: 0.0422 - val_accuracy: 0.9960
# Epoch 158/1000
# 237/237 - 1s - loss: 0.0184 - accuracy: 0.9992 - val_loss: 0.0410 - val_accuracy: 0.9960
# Epoch 159/1000
# 237/237 - 1s - loss: 0.0183 - accuracy: 0.9992 - val_loss: 0.0412 - val_accuracy: 0.9960
# Epoch 160/1000
# 237/237 - 1s - loss: 0.0181 - accuracy: 0.9995 - val_loss: 0.0404 - val_accuracy: 0.9960
# Epoch 161/1000
# 237/237 - 1s - loss: 0.0178 - accuracy: 0.9995 - val_loss: 0.0404 - val_accuracy: 0.9956
# Epoch 162/1000
# 237/237 - 1s - loss: 0.0177 - accuracy: 0.9993 - val_loss: 0.0406 - val_accuracy: 0.9956
# Epoch 163/1000
# 237/237 - 1s - loss: 0.0177 - accuracy: 0.9993 - val_loss: 0.0402 - val_accuracy: 0.9956
# Epoch 164/1000
# 237/237 - 1s - loss: 0.0175 - accuracy: 0.9995 - val_loss: 0.0397 - val_accuracy: 0.9956
# Epoch 165/1000
# 237/237 - 1s - loss: 0.0172 - accuracy: 0.9995 - val_loss: 0.0389 - val_accuracy: 0.9960
# Epoch 166/1000
# 237/237 - 1s - loss: 0.0175 - accuracy: 0.9992 - val_loss: 0.0393 - val_accuracy: 0.9956
# Epoch 167/1000
# 237/237 - 1s - loss: 0.0167 - accuracy: 0.9995 - val_loss: 0.0387 - val_accuracy: 0.9956
# Epoch 168/1000
# 237/237 - 1s - loss: 0.0168 - accuracy: 0.9993 - val_loss: 0.0384 - val_accuracy: 0.9960
# Epoch 169/1000
# 237/237 - 1s - loss: 0.0166 - accuracy: 0.9995 - val_loss: 0.0379 - val_accuracy: 0.9956
# Epoch 170/1000
# 237/237 - 1s - loss: 0.0167 - accuracy: 0.9995 - val_loss: 0.0369 - val_accuracy: 0.9960
# Epoch 171/1000
# 237/237 - 1s - loss: 0.0168 - accuracy: 0.9995 - val_loss: 0.0381 - val_accuracy: 0.9960
# Epoch 172/1000
# 237/237 - 1s - loss: 0.0165 - accuracy: 0.9995 - val_loss: 0.0381 - val_accuracy: 0.9960
# Epoch 173/1000
# 237/237 - 1s - loss: 0.0163 - accuracy: 0.9995 - val_loss: 0.0377 - val_accuracy: 0.9960
# Epoch 174/1000
# 237/237 - 1s - loss: 0.0163 - accuracy: 0.9993 - val_loss: 0.0366 - val_accuracy: 0.9960
# Epoch 175/1000
# 237/237 - 1s - loss: 0.0161 - accuracy: 0.9995 - val_loss: 0.0361 - val_accuracy: 0.9960
# Epoch 176/1000
# 237/237 - 1s - loss: 0.0158 - accuracy: 0.9995 - val_loss: 0.0370 - val_accuracy: 0.9960
# Epoch 177/1000
# 237/237 - 1s - loss: 0.0160 - accuracy: 0.9996 - val_loss: 0.0362 - val_accuracy: 0.9956
# Epoch 178/1000
# 237/237 - 1s - loss: 0.0158 - accuracy: 0.9995 - val_loss: 0.0358 - val_accuracy: 0.9956
# Epoch 179/1000
# 237/237 - 1s - loss: 0.0158 - accuracy: 0.9995 - val_loss: 0.0355 - val_accuracy: 0.9960
# Epoch 180/1000
# 237/237 - 1s - loss: 0.0157 - accuracy: 0.9995 - val_loss: 0.0366 - val_accuracy: 0.9964
# Epoch 181/1000
# 237/237 - 1s - loss: 0.0155 - accuracy: 0.9995 - val_loss: 0.0361 - val_accuracy: 0.9964
# Epoch 182/1000
# 237/237 - 1s - loss: 0.0156 - accuracy: 0.9995 - val_loss: 0.0351 - val_accuracy: 0.9956
# Epoch 183/1000
# 237/237 - 1s - loss: 0.0154 - accuracy: 0.9995 - val_loss: 0.0362 - val_accuracy: 0.9964
# Epoch 184/1000
# 237/237 - 1s - loss: 0.0153 - accuracy: 0.9995 - val_loss: 0.0347 - val_accuracy: 0.9960
# Epoch 185/1000
# 237/237 - 1s - loss: 0.0150 - accuracy: 0.9995 - val_loss: 0.0357 - val_accuracy: 0.9964
# Epoch 186/1000
# 237/237 - 1s - loss: 0.0149 - accuracy: 0.9993 - val_loss: 0.0347 - val_accuracy: 0.9960
# Epoch 187/1000
# 237/237 - 1s - loss: 0.0150 - accuracy: 0.9993 - val_loss: 0.0340 - val_accuracy: 0.9960
# Epoch 188/1000
# 237/237 - 1s - loss: 0.0150 - accuracy: 0.9995 - val_loss: 0.0339 - val_accuracy: 0.9960
# Epoch 189/1000
# 237/237 - 1s - loss: 0.0150 - accuracy: 0.9996 - val_loss: 0.0333 - val_accuracy: 0.9960
# Epoch 190/1000
# 237/237 - 1s - loss: 0.0150 - accuracy: 0.9995 - val_loss: 0.0339 - val_accuracy: 0.9964
# Epoch 191/1000
# 237/237 - 1s - loss: 0.0147 - accuracy: 0.9995 - val_loss: 0.0339 - val_accuracy: 0.9964
# Epoch 192/1000
# 237/237 - 1s - loss: 0.0146 - accuracy: 0.9995 - val_loss: 0.0340 - val_accuracy: 0.9964
# Epoch 193/1000
# 237/237 - 1s - loss: 0.0145 - accuracy: 0.9995 - val_loss: 0.0342 - val_accuracy: 0.9964
# Epoch 194/1000
# 237/237 - 1s - loss: 0.0147 - accuracy: 0.9995 - val_loss: 0.0341 - val_accuracy: 0.9964
# Epoch 195/1000
# 237/237 - 1s - loss: 0.0144 - accuracy: 0.9996 - val_loss: 0.0336 - val_accuracy: 0.9964
# Epoch 196/1000
# 237/237 - 1s - loss: 0.0143 - accuracy: 0.9995 - val_loss: 0.0329 - val_accuracy: 0.9960
# Epoch 197/1000
# 237/237 - 1s - loss: 0.0142 - accuracy: 0.9995 - val_loss: 0.0325 - val_accuracy: 0.9960
# Epoch 198/1000
# 237/237 - 1s - loss: 0.0143 - accuracy: 0.9995 - val_loss: 0.0330 - val_accuracy: 0.9964
# Epoch 199/1000
# 237/237 - 1s - loss: 0.0141 - accuracy: 0.9995 - val_loss: 0.0321 - val_accuracy: 0.9964
# Epoch 200/1000
# 237/237 - 1s - loss: 0.0143 - accuracy: 0.9995 - val_loss: 0.0327 - val_accuracy: 0.9964
# Epoch 201/1000
# 237/237 - 1s - loss: 0.0141 - accuracy: 0.9996 - val_loss: 0.0319 - val_accuracy: 0.9960
# Epoch 202/1000
# 237/237 - 1s - loss: 0.0139 - accuracy: 0.9995 - val_loss: 0.0322 - val_accuracy: 0.9964
# Epoch 203/1000
# 237/237 - 1s - loss: 0.0138 - accuracy: 0.9996 - val_loss: 0.0328 - val_accuracy: 0.9964
# Epoch 204/1000
# 237/237 - 1s - loss: 0.0139 - accuracy: 0.9995 - val_loss: 0.0319 - val_accuracy: 0.9960
# Epoch 205/1000
# 237/237 - 1s - loss: 0.0139 - accuracy: 0.9996 - val_loss: 0.0318 - val_accuracy: 0.9960
# Epoch 206/1000
# 237/237 - 1s - loss: 0.0139 - accuracy: 0.9995 - val_loss: 0.0316 - val_accuracy: 0.9964
# Epoch 207/1000
# 237/237 - 1s - loss: 0.0138 - accuracy: 0.9995 - val_loss: 0.0318 - val_accuracy: 0.9964
# Epoch 208/1000
# 237/237 - 1s - loss: 0.0137 - accuracy: 0.9995 - val_loss: 0.0310 - val_accuracy: 0.9960
# Epoch 209/1000
# 237/237 - 1s - loss: 0.0137 - accuracy: 0.9995 - val_loss: 0.0313 - val_accuracy: 0.9964
# Epoch 210/1000
# 237/237 - 1s - loss: 0.0137 - accuracy: 0.9995 - val_loss: 0.0314 - val_accuracy: 0.9964
# Epoch 211/1000
# 237/237 - 1s - loss: 0.0135 - accuracy: 0.9995 - val_loss: 0.0308 - val_accuracy: 0.9960
# Epoch 212/1000
# 237/237 - 1s - loss: 0.0135 - accuracy: 0.9995 - val_loss: 0.0308 - val_accuracy: 0.9964
# Epoch 213/1000
# 237/237 - 1s - loss: 0.0132 - accuracy: 0.9995 - val_loss: 0.0308 - val_accuracy: 0.9964
# Epoch 214/1000
# 237/237 - 1s - loss: 0.0133 - accuracy: 0.9995 - val_loss: 0.0302 - val_accuracy: 0.9960
# Epoch 215/1000
# 237/237 - 1s - loss: 0.0133 - accuracy: 0.9995 - val_loss: 0.0310 - val_accuracy: 0.9964
# Epoch 216/1000
# 237/237 - 1s - loss: 0.0133 - accuracy: 0.9996 - val_loss: 0.0300 - val_accuracy: 0.9960
# Epoch 217/1000
# 237/237 - 1s - loss: 0.0131 - accuracy: 0.9995 - val_loss: 0.0298 - val_accuracy: 0.9960
# Epoch 218/1000
# 237/237 - 1s - loss: 0.0132 - accuracy: 0.9995 - val_loss: 0.0305 - val_accuracy: 0.9964
# Epoch 219/1000
# 237/237 - 1s - loss: 0.0134 - accuracy: 0.9995 - val_loss: 0.0304 - val_accuracy: 0.9964
# Epoch 220/1000
# 237/237 - 1s - loss: 0.0132 - accuracy: 0.9995 - val_loss: 0.0296 - val_accuracy: 0.9964
# Epoch 221/1000
# 237/237 - 1s - loss: 0.0130 - accuracy: 0.9995 - val_loss: 0.0303 - val_accuracy: 0.9964
# Epoch 222/1000
# 237/237 - 1s - loss: 0.0130 - accuracy: 0.9995 - val_loss: 0.0293 - val_accuracy: 0.9960
# Epoch 223/1000
# 237/237 - 1s - loss: 0.0130 - accuracy: 0.9995 - val_loss: 0.0293 - val_accuracy: 0.9960
# Epoch 224/1000
# 237/237 - 1s - loss: 0.0128 - accuracy: 0.9996 - val_loss: 0.0297 - val_accuracy: 0.9964
# Epoch 225/1000
# 237/237 - 1s - loss: 0.0129 - accuracy: 0.9996 - val_loss: 0.0290 - val_accuracy: 0.9964
# Epoch 226/1000
# 237/237 - 1s - loss: 0.0127 - accuracy: 0.9996 - val_loss: 0.0294 - val_accuracy: 0.9964
# Epoch 227/1000
# 237/237 - 1s - loss: 0.0129 - accuracy: 0.9995 - val_loss: 0.0291 - val_accuracy: 0.9964
# Epoch 228/1000
# 237/237 - 1s - loss: 0.0127 - accuracy: 0.9996 - val_loss: 0.0294 - val_accuracy: 0.9964
# Epoch 229/1000
# 237/237 - 1s - loss: 0.0126 - accuracy: 0.9996 - val_loss: 0.0292 - val_accuracy: 0.9964
# Epoch 230/1000
# 237/237 - 1s - loss: 0.0124 - accuracy: 0.9995 - val_loss: 0.0294 - val_accuracy: 0.9964
# Epoch 231/1000
# 237/237 - 1s - loss: 0.0127 - accuracy: 0.9996 - val_loss: 0.0290 - val_accuracy: 0.9964
# Epoch 232/1000
# 237/237 - 1s - loss: 0.0125 - accuracy: 0.9996 - val_loss: 0.0286 - val_accuracy: 0.9964
# Epoch 233/1000
# 237/237 - 1s - loss: 0.0127 - accuracy: 0.9995 - val_loss: 0.0294 - val_accuracy: 0.9964
# Epoch 234/1000
# 237/237 - 1s - loss: 0.0125 - accuracy: 0.9995 - val_loss: 0.0289 - val_accuracy: 0.9964
# Epoch 235/1000
# 237/237 - 1s - loss: 0.0124 - accuracy: 0.9995 - val_loss: 0.0282 - val_accuracy: 0.9960
# Epoch 236/1000
# 237/237 - 1s - loss: 0.0124 - accuracy: 0.9995 - val_loss: 0.0282 - val_accuracy: 0.9964
# Epoch 237/1000
# 237/237 - 1s - loss: 0.0125 - accuracy: 0.9995 - val_loss: 0.0281 - val_accuracy: 0.9964
# Epoch 238/1000
# 237/237 - 1s - loss: 0.0124 - accuracy: 0.9995 - val_loss: 0.0277 - val_accuracy: 0.9964
# Epoch 239/1000
# 237/237 - 1s - loss: 0.0126 - accuracy: 0.9995 - val_loss: 0.0288 - val_accuracy: 0.9964
# Epoch 240/1000
# 237/237 - 1s - loss: 0.0123 - accuracy: 0.9996 - val_loss: 0.0282 - val_accuracy: 0.9964
# Epoch 241/1000
# 237/237 - 1s - loss: 0.0123 - accuracy: 0.9996 - val_loss: 0.0283 - val_accuracy: 0.9964
# Epoch 242/1000
# 237/237 - 1s - loss: 0.0119 - accuracy: 0.9996 - val_loss: 0.0276 - val_accuracy: 0.9964
# Epoch 243/1000
# 237/237 - 1s - loss: 0.0121 - accuracy: 0.9995 - val_loss: 0.0280 - val_accuracy: 0.9964
# Epoch 244/1000
# 237/237 - 1s - loss: 0.0121 - accuracy: 0.9996 - val_loss: 0.0276 - val_accuracy: 0.9964
# Epoch 245/1000
# 237/237 - 1s - loss: 0.0120 - accuracy: 0.9995 - val_loss: 0.0279 - val_accuracy: 0.9964
# Epoch 246/1000
# 237/237 - 1s - loss: 0.0121 - accuracy: 0.9995 - val_loss: 0.0276 - val_accuracy: 0.9964
# Epoch 247/1000
# 237/237 - 1s - loss: 0.0120 - accuracy: 0.9995 - val_loss: 0.0271 - val_accuracy: 0.9964
# Epoch 248/1000
# 237/237 - 1s - loss: 0.0121 - accuracy: 0.9995 - val_loss: 0.0280 - val_accuracy: 0.9960
# Epoch 249/1000
# 237/237 - 1s - loss: 0.0119 - accuracy: 0.9995 - val_loss: 0.0280 - val_accuracy: 0.9960
# Epoch 250/1000
# 237/237 - 1s - loss: 0.0117 - accuracy: 0.9996 - val_loss: 0.0277 - val_accuracy: 0.9960
# Epoch 251/1000
# 237/237 - 1s - loss: 0.0118 - accuracy: 0.9996 - val_loss: 0.0280 - val_accuracy: 0.9960
# Epoch 252/1000
# 237/237 - 1s - loss: 0.0119 - accuracy: 0.9995 - val_loss: 0.0268 - val_accuracy: 0.9964
# Epoch 253/1000
# 237/237 - 1s - loss: 0.0118 - accuracy: 0.9996 - val_loss: 0.0271 - val_accuracy: 0.9964
# Epoch 254/1000
# 237/237 - 1s - loss: 0.0118 - accuracy: 0.9996 - val_loss: 0.0272 - val_accuracy: 0.9964
# Epoch 255/1000
# 237/237 - 1s - loss: 0.0117 - accuracy: 0.9996 - val_loss: 0.0271 - val_accuracy: 0.9960
# Epoch 256/1000
# 237/237 - 1s - loss: 0.0116 - accuracy: 0.9995 - val_loss: 0.0271 - val_accuracy: 0.9960
# Epoch 257/1000
# 237/237 - 1s - loss: 0.0117 - accuracy: 0.9995 - val_loss: 0.0269 - val_accuracy: 0.9960
# Epoch 258/1000
# 237/237 - 1s - loss: 0.0117 - accuracy: 0.9996 - val_loss: 0.0273 - val_accuracy: 0.9960
# Epoch 259/1000
# 237/237 - 1s - loss: 0.0115 - accuracy: 0.9996 - val_loss: 0.0268 - val_accuracy: 0.9960
# Epoch 260/1000
# 237/237 - 1s - loss: 0.0115 - accuracy: 0.9995 - val_loss: 0.0267 - val_accuracy: 0.9960
# Epoch 261/1000
# 237/237 - 1s - loss: 0.0116 - accuracy: 0.9996 - val_loss: 0.0266 - val_accuracy: 0.9960
# Epoch 262/1000
# 237/237 - 1s - loss: 0.0115 - accuracy: 0.9995 - val_loss: 0.0263 - val_accuracy: 0.9960
# Epoch 263/1000
# 237/237 - 1s - loss: 0.0116 - accuracy: 0.9995 - val_loss: 0.0271 - val_accuracy: 0.9960
# Epoch 264/1000
# 237/237 - 1s - loss: 0.0116 - accuracy: 0.9993 - val_loss: 0.0267 - val_accuracy: 0.9960
# Epoch 265/1000
# 237/237 - 1s - loss: 0.0114 - accuracy: 0.9996 - val_loss: 0.0268 - val_accuracy: 0.9960
# Epoch 266/1000
# 237/237 - 1s - loss: 0.0115 - accuracy: 0.9995 - val_loss: 0.0271 - val_accuracy: 0.9960
# Epoch 267/1000
# 237/237 - 1s - loss: 0.0112 - accuracy: 0.9995 - val_loss: 0.0261 - val_accuracy: 0.9960
# Epoch 268/1000
# 237/237 - 1s - loss: 0.0113 - accuracy: 0.9996 - val_loss: 0.0271 - val_accuracy: 0.9960
# Epoch 269/1000
# 237/237 - 1s - loss: 0.0114 - accuracy: 0.9996 - val_loss: 0.0261 - val_accuracy: 0.9960
# Epoch 270/1000
# 237/237 - 1s - loss: 0.0113 - accuracy: 0.9995 - val_loss: 0.0267 - val_accuracy: 0.9960
# Epoch 271/1000
# 237/237 - 1s - loss: 0.0113 - accuracy: 0.9995 - val_loss: 0.0261 - val_accuracy: 0.9960
# Epoch 272/1000
# 237/237 - 1s - loss: 0.0114 - accuracy: 0.9996 - val_loss: 0.0253 - val_accuracy: 0.9964
# Epoch 273/1000
# 237/237 - 1s - loss: 0.0113 - accuracy: 0.9996 - val_loss: 0.0267 - val_accuracy: 0.9960
# Epoch 274/1000
# 237/237 - 1s - loss: 0.0112 - accuracy: 0.9995 - val_loss: 0.0263 - val_accuracy: 0.9960
# Epoch 275/1000
# 237/237 - 1s - loss: 0.0110 - accuracy: 0.9996 - val_loss: 0.0261 - val_accuracy: 0.9960
# Epoch 276/1000
# 237/237 - 1s - loss: 0.0110 - accuracy: 0.9996 - val_loss: 0.0260 - val_accuracy: 0.9960
# Epoch 277/1000
# 237/237 - 1s - loss: 0.0112 - accuracy: 0.9995 - val_loss: 0.0260 - val_accuracy: 0.9960
# Epoch 278/1000
# 237/237 - 1s - loss: 0.0110 - accuracy: 0.9995 - val_loss: 0.0261 - val_accuracy: 0.9960
# Epoch 279/1000
# 237/237 - 1s - loss: 0.0110 - accuracy: 0.9996 - val_loss: 0.0260 - val_accuracy: 0.9960
# Epoch 280/1000
# 237/237 - 1s - loss: 0.0109 - accuracy: 0.9996 - val_loss: 0.0258 - val_accuracy: 0.9960
# Epoch 281/1000
# 237/237 - 1s - loss: 0.0111 - accuracy: 0.9995 - val_loss: 0.0256 - val_accuracy: 0.9960
# Epoch 282/1000
# 237/237 - 1s - loss: 0.0111 - accuracy: 0.9996 - val_loss: 0.0256 - val_accuracy: 0.9960
# Epoch 283/1000
# 237/237 - 1s - loss: 0.0109 - accuracy: 0.9995 - val_loss: 0.0261 - val_accuracy: 0.9960
# Epoch 284/1000
# 237/237 - 1s - loss: 0.0110 - accuracy: 0.9996 - val_loss: 0.0257 - val_accuracy: 0.9960
# Epoch 285/1000
# 237/237 - 1s - loss: 0.0111 - accuracy: 0.9996 - val_loss: 0.0251 - val_accuracy: 0.9960
# Epoch 286/1000
# 237/237 - 1s - loss: 0.0108 - accuracy: 0.9995 - val_loss: 0.0250 - val_accuracy: 0.9960
# Epoch 287/1000
# 237/237 - 1s - loss: 0.0110 - accuracy: 0.9996 - val_loss: 0.0250 - val_accuracy: 0.9960
# Epoch 288/1000
# 237/237 - 1s - loss: 0.0108 - accuracy: 0.9996 - val_loss: 0.0248 - val_accuracy: 0.9960
# Epoch 289/1000
# 237/237 - 1s - loss: 0.0106 - accuracy: 0.9995 - val_loss: 0.0250 - val_accuracy: 0.9960
# Epoch 290/1000
# 237/237 - 1s - loss: 0.0109 - accuracy: 0.9995 - val_loss: 0.0252 - val_accuracy: 0.9960
# Epoch 291/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9996 - val_loss: 0.0256 - val_accuracy: 0.9960
# Epoch 292/1000
# 237/237 - 1s - loss: 0.0106 - accuracy: 0.9996 - val_loss: 0.0250 - val_accuracy: 0.9960
# Epoch 293/1000
# 237/237 - 1s - loss: 0.0108 - accuracy: 0.9995 - val_loss: 0.0252 - val_accuracy: 0.9960
# Epoch 294/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9996 - val_loss: 0.0251 - val_accuracy: 0.9960
# Epoch 295/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9995 - val_loss: 0.0254 - val_accuracy: 0.9960
# Epoch 296/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9996 - val_loss: 0.0252 - val_accuracy: 0.9960
# Epoch 297/1000
# 237/237 - 1s - loss: 0.0108 - accuracy: 0.9996 - val_loss: 0.0245 - val_accuracy: 0.9960
# Epoch 298/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9996 - val_loss: 0.0247 - val_accuracy: 0.9960
# Epoch 299/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9996 - val_loss: 0.0247 - val_accuracy: 0.9960
# Epoch 300/1000
# 237/237 - 1s - loss: 0.0107 - accuracy: 0.9996 - val_loss: 0.0254 - val_accuracy: 0.9960
# Epoch 301/1000
# 237/237 - 1s - loss: 0.0106 - accuracy: 0.9995 - val_loss: 0.0253 - val_accuracy: 0.9960
# Epoch 302/1000
# 237/237 - 1s - loss: 0.0106 - accuracy: 0.9996 - val_loss: 0.0244 - val_accuracy: 0.9960
# Epoch 303/1000
# 237/237 - 1s - loss: 0.0106 - accuracy: 0.9995 - val_loss: 0.0246 - val_accuracy: 0.9960
# Epoch 304/1000
# 237/237 - 1s - loss: 0.0104 - accuracy: 0.9996 - val_loss: 0.0246 - val_accuracy: 0.9960
# Epoch 305/1000
# 237/237 - 1s - loss: 0.0104 - accuracy: 0.9995 - val_loss: 0.0245 - val_accuracy: 0.9960
# Epoch 306/1000
# 237/237 - 1s - loss: 0.0105 - accuracy: 0.9995 - val_loss: 0.0243 - val_accuracy: 0.9960
# Epoch 307/1000
# 237/237 - 1s - loss: 0.0104 - accuracy: 0.9996 - val_loss: 0.0244 - val_accuracy: 0.9960
# Epoch 308/1000
# 237/237 - 1s - loss: 0.0103 - accuracy: 0.9997 - val_loss: 0.0241 - val_accuracy: 0.9960
# Epoch 309/1000
# 237/237 - 1s - loss: 0.0103 - accuracy: 0.9995 - val_loss: 0.0251 - val_accuracy: 0.9960
# Epoch 310/1000
# 237/237 - 1s - loss: 0.0104 - accuracy: 0.9995 - val_loss: 0.0253 - val_accuracy: 0.9960
# Epoch 311/1000
# 237/237 - 1s - loss: 0.0102 - accuracy: 0.9996 - val_loss: 0.0240 - val_accuracy: 0.9960
# Epoch 312/1000
# 237/237 - 1s - loss: 0.0104 - accuracy: 0.9996 - val_loss: 0.0239 - val_accuracy: 0.9960
# Epoch 313/1000
# 237/237 - 1s - loss: 0.0102 - accuracy: 0.9996 - val_loss: 0.0248 - val_accuracy: 0.9960
# Epoch 314/1000
# 237/237 - 1s - loss: 0.0102 - accuracy: 0.9996 - val_loss: 0.0239 - val_accuracy: 0.9960
# Epoch 315/1000
# 237/237 - 1s - loss: 0.0103 - accuracy: 0.9996 - val_loss: 0.0239 - val_accuracy: 0.9960
# Epoch 316/1000
# 237/237 - 1s - loss: 0.0103 - accuracy: 0.9996 - val_loss: 0.0244 - val_accuracy: 0.9960
# Epoch 317/1000
# 237/237 - 1s - loss: 0.0103 - accuracy: 0.9996 - val_loss: 0.0244 - val_accuracy: 0.9960
# Epoch 318/1000
# 237/237 - 1s - loss: 0.0103 - accuracy: 0.9996 - val_loss: 0.0243 - val_accuracy: 0.9960
# Epoch 319/1000
# 237/237 - 1s - loss: 0.0103 - accuracy: 0.9996 - val_loss: 0.0244 - val_accuracy: 0.9960
# Epoch 320/1000
# 237/237 - 1s - loss: 0.0101 - accuracy: 0.9996 - val_loss: 0.0239 - val_accuracy: 0.9960
# Epoch 321/1000
# 237/237 - 1s - loss: 0.0102 - accuracy: 0.9996 - val_loss: 0.0240 - val_accuracy: 0.9960
# Epoch 322/1000
# 237/237 - 1s - loss: 0.0101 - accuracy: 0.9995 - val_loss: 0.0236 - val_accuracy: 0.9960
# Epoch 323/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9996 - val_loss: 0.0232 - val_accuracy: 0.9960
# Epoch 324/1000
# 237/237 - 1s - loss: 0.0102 - accuracy: 0.9996 - val_loss: 0.0236 - val_accuracy: 0.9960
# Epoch 325/1000
# 237/237 - 1s - loss: 0.0101 - accuracy: 0.9996 - val_loss: 0.0239 - val_accuracy: 0.9960
# Epoch 326/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9996 - val_loss: 0.0238 - val_accuracy: 0.9960
# Epoch 327/1000
# 237/237 - 1s - loss: 0.0101 - accuracy: 0.9995 - val_loss: 0.0234 - val_accuracy: 0.9960
# Epoch 328/1000
# 237/237 - 1s - loss: 0.0101 - accuracy: 0.9996 - val_loss: 0.0238 - val_accuracy: 0.9960
# Epoch 329/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9995 - val_loss: 0.0241 - val_accuracy: 0.9960
# Epoch 330/1000
# 237/237 - 1s - loss: 0.0102 - accuracy: 0.9995 - val_loss: 0.0239 - val_accuracy: 0.9960
# Epoch 331/1000
# 237/237 - 1s - loss: 0.0101 - accuracy: 0.9996 - val_loss: 0.0237 - val_accuracy: 0.9960
# Epoch 332/1000
# 237/237 - 1s - loss: 0.0099 - accuracy: 0.9997 - val_loss: 0.0236 - val_accuracy: 0.9960
# Epoch 333/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9995 - val_loss: 0.0233 - val_accuracy: 0.9960
# Epoch 334/1000
# 237/237 - 1s - loss: 0.0098 - accuracy: 0.9996 - val_loss: 0.0235 - val_accuracy: 0.9960
# Epoch 335/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9996 - val_loss: 0.0234 - val_accuracy: 0.9960
# Epoch 336/1000
# 237/237 - 1s - loss: 0.0100 - accuracy: 0.9996 - val_loss: 0.0230 - val_accuracy: 0.9960
# Epoch 337/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9996 - val_loss: 0.0235 - val_accuracy: 0.9960
# Epoch 338/1000
# 237/237 - 1s - loss: 0.0099 - accuracy: 0.9996 - val_loss: 0.0230 - val_accuracy: 0.9960
# Epoch 339/1000
# 237/237 - 1s - loss: 0.0098 - accuracy: 0.9996 - val_loss: 0.0230 - val_accuracy: 0.9960
# Epoch 340/1000
# 237/237 - 1s - loss: 0.0096 - accuracy: 0.9996 - val_loss: 0.0234 - val_accuracy: 0.9960
# Epoch 341/1000
# 237/237 - 1s - loss: 0.0098 - accuracy: 0.9996 - val_loss: 0.0234 - val_accuracy: 0.9960
# Epoch 342/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9996 - val_loss: 0.0233 - val_accuracy: 0.9960
# Epoch 343/1000
# 237/237 - 1s - loss: 0.0099 - accuracy: 0.9996 - val_loss: 0.0236 - val_accuracy: 0.9960
# Epoch 344/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9996 - val_loss: 0.0231 - val_accuracy: 0.9960
# Epoch 345/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.0232 - val_accuracy: 0.9960
# Epoch 346/1000
# 237/237 - 1s - loss: 0.0099 - accuracy: 0.9995 - val_loss: 0.0230 - val_accuracy: 0.9960
# Epoch 347/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9996 - val_loss: 0.0227 - val_accuracy: 0.9960
# Epoch 348/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9996 - val_loss: 0.0227 - val_accuracy: 0.9960
# Epoch 349/1000
# 237/237 - 1s - loss: 0.0098 - accuracy: 0.9995 - val_loss: 0.0230 - val_accuracy: 0.9960
# Epoch 350/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.0232 - val_accuracy: 0.9960
# Epoch 351/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9996 - val_loss: 0.0225 - val_accuracy: 0.9960
# Epoch 352/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9996 - val_loss: 0.0230 - val_accuracy: 0.9960
# Epoch 353/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9996 - val_loss: 0.0231 - val_accuracy: 0.9960
# Epoch 354/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9996 - val_loss: 0.0222 - val_accuracy: 0.9964
# Epoch 355/1000
# 237/237 - 1s - loss: 0.0096 - accuracy: 0.9997 - val_loss: 0.0228 - val_accuracy: 0.9960
# Epoch 356/1000
# 237/237 - 1s - loss: 0.0097 - accuracy: 0.9996 - val_loss: 0.0226 - val_accuracy: 0.9960
# Epoch 357/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9996 - val_loss: 0.0229 - val_accuracy: 0.9960
# Epoch 358/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.0224 - val_accuracy: 0.9960
# Epoch 359/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.0223 - val_accuracy: 0.9960
# Epoch 360/1000
# 237/237 - 1s - loss: 0.0096 - accuracy: 0.9995 - val_loss: 0.0221 - val_accuracy: 0.9968
# Epoch 361/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9996 - val_loss: 0.0223 - val_accuracy: 0.9960
# Epoch 362/1000
# 237/237 - 1s - loss: 0.0094 - accuracy: 0.9996 - val_loss: 0.0223 - val_accuracy: 0.9960
# Epoch 363/1000
# 237/237 - 1s - loss: 0.0094 - accuracy: 0.9996 - val_loss: 0.0228 - val_accuracy: 0.9964
# Epoch 364/1000
# 237/237 - 1s - loss: 0.0096 - accuracy: 0.9995 - val_loss: 0.0219 - val_accuracy: 0.9968
# Epoch 365/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9996 - val_loss: 0.0222 - val_accuracy: 0.9960
# Epoch 366/1000
# 237/237 - 1s - loss: 0.0095 - accuracy: 0.9996 - val_loss: 0.0223 - val_accuracy: 0.9960
# Epoch 367/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9996 - val_loss: 0.0218 - val_accuracy: 0.9964
# Epoch 368/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9996 - val_loss: 0.0220 - val_accuracy: 0.9964
# Epoch 369/1000
# 237/237 - 1s - loss: 0.0094 - accuracy: 0.9996 - val_loss: 0.0219 - val_accuracy: 0.9960
# Epoch 370/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9996 - val_loss: 0.0222 - val_accuracy: 0.9960
# Epoch 371/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9996 - val_loss: 0.0222 - val_accuracy: 0.9960
# Epoch 372/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9996 - val_loss: 0.0216 - val_accuracy: 0.9968
# Epoch 373/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9996 - val_loss: 0.0221 - val_accuracy: 0.9960
# Epoch 374/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9996 - val_loss: 0.0217 - val_accuracy: 0.9964
# Epoch 375/1000
# 237/237 - 1s - loss: 0.0094 - accuracy: 0.9996 - val_loss: 0.0221 - val_accuracy: 0.9960
# Epoch 376/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9996 - val_loss: 0.0223 - val_accuracy: 0.9960
# Epoch 377/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9997 - val_loss: 0.0218 - val_accuracy: 0.9960
# Epoch 378/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9996 - val_loss: 0.0219 - val_accuracy: 0.9960
# Epoch 379/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9995 - val_loss: 0.0217 - val_accuracy: 0.9968
# Epoch 380/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9996 - val_loss: 0.0220 - val_accuracy: 0.9960
# Epoch 381/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9996 - val_loss: 0.0221 - val_accuracy: 0.9960
# Epoch 382/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9997 - val_loss: 0.0216 - val_accuracy: 0.9968
# Epoch 383/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9997 - val_loss: 0.0222 - val_accuracy: 0.9964
# Epoch 384/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9996 - val_loss: 0.0220 - val_accuracy: 0.9964
# Epoch 385/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9996 - val_loss: 0.0216 - val_accuracy: 0.9968
# Epoch 386/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9996 - val_loss: 0.0220 - val_accuracy: 0.9964
# Epoch 387/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9996 - val_loss: 0.0218 - val_accuracy: 0.9960
# Epoch 388/1000
# 237/237 - 1s - loss: 0.0093 - accuracy: 0.9996 - val_loss: 0.0219 - val_accuracy: 0.9960
# Epoch 389/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9996 - val_loss: 0.0216 - val_accuracy: 0.9964
# Epoch 390/1000
# 237/237 - 1s - loss: 0.0092 - accuracy: 0.9996 - val_loss: 0.0217 - val_accuracy: 0.9960
# Epoch 391/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9996 - val_loss: 0.0216 - val_accuracy: 0.9960
# Epoch 392/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9997 - val_loss: 0.0218 - val_accuracy: 0.9964
# Epoch 393/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9996 - val_loss: 0.0214 - val_accuracy: 0.9968
# Epoch 394/1000
# 237/237 - 1s - loss: 0.0089 - accuracy: 0.9996 - val_loss: 0.0214 - val_accuracy: 0.9968
# Epoch 395/1000
# 237/237 - 1s - loss: 0.0089 - accuracy: 0.9997 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 396/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9996 - val_loss: 0.0220 - val_accuracy: 0.9964
# Epoch 397/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9997 - val_loss: 0.0214 - val_accuracy: 0.9968
# Epoch 398/1000
# 237/237 - 1s - loss: 0.0089 - accuracy: 0.9996 - val_loss: 0.0216 - val_accuracy: 0.9964
# Epoch 399/1000
# 237/237 - 1s - loss: 0.0089 - accuracy: 0.9997 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 400/1000
# 237/237 - 1s - loss: 0.0091 - accuracy: 0.9997 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 401/1000
# 237/237 - 1s - loss: 0.0089 - accuracy: 0.9996 - val_loss: 0.0216 - val_accuracy: 0.9964
# Epoch 402/1000
# 237/237 - 1s - loss: 0.0088 - accuracy: 0.9996 - val_loss: 0.0220 - val_accuracy: 0.9964
# Epoch 403/1000
# 237/237 - 1s - loss: 0.0088 - accuracy: 0.9997 - val_loss: 0.0209 - val_accuracy: 0.9968
# Epoch 404/1000
# 237/237 - 1s - loss: 0.0089 - accuracy: 0.9996 - val_loss: 0.0209 - val_accuracy: 0.9968
# Epoch 405/1000
# 237/237 - 1s - loss: 0.0088 - accuracy: 0.9997 - val_loss: 0.0209 - val_accuracy: 0.9968
# Epoch 406/1000
# 237/237 - 1s - loss: 0.0088 - accuracy: 0.9997 - val_loss: 0.0208 - val_accuracy: 0.9968
# Epoch 407/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9996 - val_loss: 0.0208 - val_accuracy: 0.9968
# Epoch 408/1000
# 237/237 - 1s - loss: 0.0087 - accuracy: 0.9997 - val_loss: 0.0211 - val_accuracy: 0.9968
# Epoch 409/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9996 - val_loss: 0.0209 - val_accuracy: 0.9968
# Epoch 410/1000
# 237/237 - 1s - loss: 0.0090 - accuracy: 0.9997 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 411/1000
# 237/237 - 1s - loss: 0.0087 - accuracy: 0.9997 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 412/1000
# 237/237 - 1s - loss: 0.0087 - accuracy: 0.9996 - val_loss: 0.0214 - val_accuracy: 0.9964
# Epoch 413/1000
# 237/237 - 1s - loss: 0.0088 - accuracy: 0.9996 - val_loss: 0.0212 - val_accuracy: 0.9968
# Epoch 414/1000
# 237/237 - 1s - loss: 0.0087 - accuracy: 0.9997 - val_loss: 0.0212 - val_accuracy: 0.9968
# Epoch 415/1000
# 237/237 - 1s - loss: 0.0088 - accuracy: 0.9997 - val_loss: 0.0212 - val_accuracy: 0.9968
# Epoch 416/1000
# 237/237 - 1s - loss: 0.0088 - accuracy: 0.9996 - val_loss: 0.0211 - val_accuracy: 0.9972
# Epoch 417/1000
# 237/237 - 1s - loss: 0.0087 - accuracy: 0.9997 - val_loss: 0.0206 - val_accuracy: 0.9968
# Epoch 418/1000
# 237/237 - 1s - loss: 0.0088 - accuracy: 0.9997 - val_loss: 0.0212 - val_accuracy: 0.9968
# Epoch 419/1000
# 237/237 - 1s - loss: 0.0088 - accuracy: 0.9997 - val_loss: 0.0208 - val_accuracy: 0.9968
# Epoch 420/1000
# 237/237 - 1s - loss: 0.0087 - accuracy: 0.9996 - val_loss: 0.0208 - val_accuracy: 0.9968
# Epoch 421/1000
# 237/237 - 1s - loss: 0.0088 - accuracy: 0.9997 - val_loss: 0.0206 - val_accuracy: 0.9968
# Epoch 422/1000
# 237/237 - 1s - loss: 0.0088 - accuracy: 0.9997 - val_loss: 0.0206 - val_accuracy: 0.9968
# Epoch 423/1000
# 237/237 - 1s - loss: 0.0089 - accuracy: 0.9996 - val_loss: 0.0211 - val_accuracy: 0.9968
# Epoch 424/1000
# 237/237 - 1s - loss: 0.0086 - accuracy: 0.9997 - val_loss: 0.0205 - val_accuracy: 0.9968
# Epoch 425/1000
# 237/237 - 1s - loss: 0.0086 - accuracy: 0.9996 - val_loss: 0.0206 - val_accuracy: 0.9972
# Epoch 426/1000
# 237/237 - 1s - loss: 0.0087 - accuracy: 0.9997 - val_loss: 0.0206 - val_accuracy: 0.9968
# Epoch 427/1000
# 237/237 - 1s - loss: 0.0087 - accuracy: 0.9996 - val_loss: 0.0202 - val_accuracy: 0.9968
# Epoch 428/1000
# 237/237 - 1s - loss: 0.0085 - accuracy: 0.9996 - val_loss: 0.0210 - val_accuracy: 0.9972
# Epoch 429/1000
# 237/237 - 1s - loss: 0.0085 - accuracy: 0.9997 - val_loss: 0.0206 - val_accuracy: 0.9968
# Epoch 430/1000
# 237/237 - 1s - loss: 0.0084 - accuracy: 0.9997 - val_loss: 0.0207 - val_accuracy: 0.9968
# Epoch 431/1000
# 237/237 - 1s - loss: 0.0087 - accuracy: 0.9996 - val_loss: 0.0207 - val_accuracy: 0.9972
# Epoch 432/1000
# 237/237 - 1s - loss: 0.0085 - accuracy: 0.9996 - val_loss: 0.0204 - val_accuracy: 0.9968
# Epoch 433/1000
# 237/237 - 1s - loss: 0.0086 - accuracy: 0.9997 - val_loss: 0.0206 - val_accuracy: 0.9972
# Epoch 434/1000
# 237/237 - 1s - loss: 0.0085 - accuracy: 0.9996 - val_loss: 0.0209 - val_accuracy: 0.9972
# Epoch 435/1000
# 237/237 - 1s - loss: 0.0085 - accuracy: 0.9996 - val_loss: 0.0203 - val_accuracy: 0.9968
# Epoch 436/1000
# 237/237 - 1s - loss: 0.0085 - accuracy: 0.9997 - val_loss: 0.0202 - val_accuracy: 0.9968
# Epoch 437/1000
# 237/237 - 1s - loss: 0.0085 - accuracy: 0.9996 - val_loss: 0.0205 - val_accuracy: 0.9972
# Epoch 438/1000
# 237/237 - 1s - loss: 0.0084 - accuracy: 0.9996 - val_loss: 0.0202 - val_accuracy: 0.9968
# Epoch 439/1000
# 237/237 - 1s - loss: 0.0084 - accuracy: 0.9997 - val_loss: 0.0201 - val_accuracy: 0.9968
# Epoch 440/1000
# 237/237 - 1s - loss: 0.0085 - accuracy: 0.9996 - val_loss: 0.0203 - val_accuracy: 0.9972
# Epoch 441/1000
# 237/237 - 1s - loss: 0.0084 - accuracy: 0.9997 - val_loss: 0.0204 - val_accuracy: 0.9972
# Epoch 442/1000
# 237/237 - 1s - loss: 0.0084 - accuracy: 0.9997 - val_loss: 0.0202 - val_accuracy: 0.9968
# Epoch 443/1000
# 237/237 - 1s - loss: 0.0083 - accuracy: 0.9996 - val_loss: 0.0208 - val_accuracy: 0.9972
# Epoch 444/1000
# 237/237 - 1s - loss: 0.0085 - accuracy: 0.9997 - val_loss: 0.0201 - val_accuracy: 0.9968
# Epoch 445/1000
# 237/237 - 1s - loss: 0.0085 - accuracy: 0.9997 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 446/1000
# 237/237 - 1s - loss: 0.0086 - accuracy: 0.9996 - val_loss: 0.0200 - val_accuracy: 0.9968
# Epoch 447/1000
# 237/237 - 1s - loss: 0.0083 - accuracy: 0.9996 - val_loss: 0.0204 - val_accuracy: 0.9972
# Epoch 448/1000
# 237/237 - 1s - loss: 0.0084 - accuracy: 0.9996 - val_loss: 0.0204 - val_accuracy: 0.9972
# Epoch 449/1000
# 237/237 - 1s - loss: 0.0083 - accuracy: 0.9997 - val_loss: 0.0197 - val_accuracy: 0.9968
# Epoch 450/1000
# 237/237 - 1s - loss: 0.0085 - accuracy: 0.9995 - val_loss: 0.0201 - val_accuracy: 0.9968
# Epoch 451/1000
# 237/237 - 1s - loss: 0.0083 - accuracy: 0.9996 - val_loss: 0.0201 - val_accuracy: 0.9972
# Epoch 452/1000
# 237/237 - 1s - loss: 0.0082 - accuracy: 0.9997 - val_loss: 0.0199 - val_accuracy: 0.9968
# Epoch 453/1000
# 237/237 - 1s - loss: 0.0084 - accuracy: 0.9996 - val_loss: 0.0203 - val_accuracy: 0.9972
# Epoch 454/1000
# 237/237 - 1s - loss: 0.0082 - accuracy: 0.9996 - val_loss: 0.0204 - val_accuracy: 0.9972
# Epoch 455/1000
# 237/237 - 1s - loss: 0.0085 - accuracy: 0.9996 - val_loss: 0.0201 - val_accuracy: 0.9972
# Epoch 456/1000
# 237/237 - 1s - loss: 0.0083 - accuracy: 0.9997 - val_loss: 0.0198 - val_accuracy: 0.9968
# Epoch 457/1000
# 237/237 - 1s - loss: 0.0084 - accuracy: 0.9996 - val_loss: 0.0199 - val_accuracy: 0.9968
# Epoch 458/1000
# 237/237 - 1s - loss: 0.0083 - accuracy: 0.9997 - val_loss: 0.0196 - val_accuracy: 0.9968
# Epoch 459/1000
# 237/237 - 1s - loss: 0.0084 - accuracy: 0.9996 - val_loss: 0.0198 - val_accuracy: 0.9972
# Epoch 460/1000
# 237/237 - 1s - loss: 0.0082 - accuracy: 0.9997 - val_loss: 0.0198 - val_accuracy: 0.9968
# Epoch 461/1000
# 237/237 - 1s - loss: 0.0082 - accuracy: 0.9996 - val_loss: 0.0199 - val_accuracy: 0.9972
# Epoch 462/1000
# 237/237 - 1s - loss: 0.0084 - accuracy: 0.9996 - val_loss: 0.0202 - val_accuracy: 0.9972
# Epoch 463/1000
# ...
# Epoch 848/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9999 - val_loss: 0.0161 - val_accuracy: 0.9976
# Epoch 849/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0162 - val_accuracy: 0.9976
# Epoch 850/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 851/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 0.9997 - val_loss: 0.0162 - val_accuracy: 0.9976
# Epoch 852/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 0.9997 - val_loss: 0.0161 - val_accuracy: 0.9976
# Epoch 853/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 0.9999 - val_loss: 0.0162 - val_accuracy: 0.9976
# Epoch 854/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0162 - val_accuracy: 0.9976
# Epoch 855/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0160 - val_accuracy: 0.9976
# Epoch 856/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0160 - val_accuracy: 0.9976
# Epoch 857/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9999 - val_loss: 0.0161 - val_accuracy: 0.9976
# Epoch 858/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0160 - val_accuracy: 0.9976
# Epoch 859/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0162 - val_accuracy: 0.9976
# Epoch 860/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 861/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0159 - val_accuracy: 0.9976
# Epoch 862/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9999 - val_loss: 0.0164 - val_accuracy: 0.9976
# Epoch 863/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 0.9996 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 864/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0162 - val_accuracy: 0.9976
# Epoch 865/1000
# 237/237 - 1s - loss: 0.0059 - accuracy: 0.9997 - val_loss: 0.0161 - val_accuracy: 0.9976
# Epoch 866/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0159 - val_accuracy: 0.9976
# Epoch 867/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 868/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9999 - val_loss: 0.0162 - val_accuracy: 0.9976
# Epoch 869/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9996 - val_loss: 0.0163 - val_accuracy: 0.9976
# Epoch 870/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9999 - val_loss: 0.0164 - val_accuracy: 0.9976
# Epoch 871/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9999 - val_loss: 0.0161 - val_accuracy: 0.9976
# Epoch 872/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9999 - val_loss: 0.0160 - val_accuracy: 0.9976
# Epoch 873/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9999 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 874/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0159 - val_accuracy: 0.9976
# Epoch 875/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 876/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0160 - val_accuracy: 0.9976
# Epoch 877/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9999 - val_loss: 0.0164 - val_accuracy: 0.9976
# Epoch 878/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9999 - val_loss: 0.0160 - val_accuracy: 0.9976
# Epoch 879/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0162 - val_accuracy: 0.9976
# Epoch 880/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 881/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0161 - val_accuracy: 0.9976
# Epoch 882/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0159 - val_accuracy: 0.9976
# Epoch 883/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9999 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 884/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 885/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0160 - val_accuracy: 0.9976
# Epoch 886/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0161 - val_accuracy: 0.9976
# Epoch 887/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 888/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 889/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0162 - val_accuracy: 0.9976
# Epoch 890/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0159 - val_accuracy: 0.9976
# Epoch 891/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 892/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0159 - val_accuracy: 0.9976
# Epoch 893/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 894/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 895/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9999 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 896/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0159 - val_accuracy: 0.9976
# Epoch 897/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 898/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0159 - val_accuracy: 0.9976
# Epoch 899/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 900/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0161 - val_accuracy: 0.9976
# Epoch 901/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 902/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 903/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 904/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 905/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0162 - val_accuracy: 0.9976
# Epoch 906/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 907/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 908/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 909/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0162 - val_accuracy: 0.9976
# Epoch 910/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 911/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0159 - val_accuracy: 0.9976
# Epoch 912/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0159 - val_accuracy: 0.9976
# Epoch 913/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 914/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 915/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 916/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 917/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0160 - val_accuracy: 0.9976
# Epoch 918/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0160 - val_accuracy: 0.9976
# Epoch 919/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 920/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0161 - val_accuracy: 0.9976
# Epoch 921/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0160 - val_accuracy: 0.9976
# Epoch 922/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0161 - val_accuracy: 0.9976
# Epoch 923/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 924/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 925/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 926/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 927/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0159 - val_accuracy: 0.9976
# Epoch 928/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 929/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 930/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0153 - val_accuracy: 0.9976
# Epoch 931/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 932/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0161 - val_accuracy: 0.9976
# Epoch 933/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 934/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 935/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 936/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 937/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 938/1000
# 237/237 - 1s - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 939/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 940/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 941/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 942/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 943/1000
# 237/237 - 1s - loss: 0.0057 - accuracy: 0.9996 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 944/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 945/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0154 - val_accuracy: 0.9976
# Epoch 946/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 947/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 948/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0159 - val_accuracy: 0.9976
# Epoch 949/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0160 - val_accuracy: 0.9976
# Epoch 950/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 951/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 952/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 953/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 954/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0153 - val_accuracy: 0.9976
# Epoch 955/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 956/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 957/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0159 - val_accuracy: 0.9976
# Epoch 958/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 959/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 960/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0154 - val_accuracy: 0.9976
# Epoch 961/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 962/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 963/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0154 - val_accuracy: 0.9976
# Epoch 964/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0154 - val_accuracy: 0.9976
# Epoch 965/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0153 - val_accuracy: 0.9976
# Epoch 966/1000
# 237/237 - 1s - loss: 0.0053 - accuracy: 0.9999 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 967/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 968/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0158 - val_accuracy: 0.9976
# Epoch 969/1000
# 237/237 - 1s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 970/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 971/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 972/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 973/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 974/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 975/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 976/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 977/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0152 - val_accuracy: 0.9976
# Epoch 978/1000
# 237/237 - 1s - loss: 0.0053 - accuracy: 0.9997 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 979/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0154 - val_accuracy: 0.9976
# Epoch 980/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 981/1000
# 237/237 - 2s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0154 - val_accuracy: 0.9976
# Epoch 982/1000
# 237/237 - 1s - loss: 0.0053 - accuracy: 0.9997 - val_loss: 0.0152 - val_accuracy: 0.9976
# Epoch 983/1000
# 237/237 - 1s - loss: 0.0053 - accuracy: 0.9999 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 984/1000
# 237/237 - 1s - loss: 0.0053 - accuracy: 0.9999 - val_loss: 0.0154 - val_accuracy: 0.9976
# Epoch 985/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 986/1000
# 237/237 - 1s - loss: 0.0053 - accuracy: 0.9997 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 987/1000
# 237/237 - 1s - loss: 0.0053 - accuracy: 0.9999 - val_loss: 0.0152 - val_accuracy: 0.9976
# Epoch 988/1000
# 237/237 - 1s - loss: 0.0053 - accuracy: 0.9999 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 989/1000
# 237/237 - 1s - loss: 0.0052 - accuracy: 0.9997 - val_loss: 0.0152 - val_accuracy: 0.9976
# Epoch 990/1000
# 237/237 - 1s - loss: 0.0053 - accuracy: 0.9999 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 991/1000
# 237/237 - 1s - loss: 0.0053 - accuracy: 0.9999 - val_loss: 0.0154 - val_accuracy: 0.9976
# Epoch 992/1000
# 237/237 - 1s - loss: 0.0051 - accuracy: 0.9999 - val_loss: 0.0153 - val_accuracy: 0.9976
# Epoch 993/1000
# 237/237 - 1s - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 994/1000
# 237/237 - 1s - loss: 0.0052 - accuracy: 0.9999 - val_loss: 0.0154 - val_accuracy: 0.9976
# Epoch 995/1000
# 237/237 - 1s - loss: 0.0053 - accuracy: 0.9999 - val_loss: 0.0152 - val_accuracy: 0.9976
# Epoch 996/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0153 - val_accuracy: 0.9976
# Epoch 997/1000
# 237/237 - 1s - loss: 0.0053 - accuracy: 0.9999 - val_loss: 0.0156 - val_accuracy: 0.9976
# Epoch 998/1000
# 237/237 - 1s - loss: 0.0052 - accuracy: 0.9999 - val_loss: 0.0155 - val_accuracy: 0.9976
# Epoch 999/1000
# 237/237 - 1s - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0157 - val_accuracy: 0.9976
# Epoch 1000/1000
# 237/237 - 1s - loss: 0.0053 - accuracy: 0.9997 - val_loss: 0.0153 - val_accuracy: 0.9976

# %%
import seaborn
plt.style.use('seaborn-white')
plt.figure(figsize=(8,4))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training Acc', 'Test Acc'], loc='lower right')
plt.show()

# summarize history for loss
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], 'o-')
plt.plot(history.history['val_loss'], 'x-')
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training Loss', 'Test Loss'], loc='upper right')

plt.show()

plt.figure()
plt.figure(figsize=(8,4))
N = epochs
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="center right")

# %%
(eval_loss, eval_accuracy) = model.evaluate(validation_data, validation_labels, batch_size= batch_size, verbose=1)

print("Validation Accuracy: {:.4f}%".format(eval_accuracy * 100))
print("Validation Loss: {}".format(eval_loss))
# Out:
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 0.9976
# Validation Accuracy: 99.7616%
# Validation Loss: 0.015269399620592594

# %%
from sklearn.metrics import accuracy_score,roc_curve, confusion_matrix, roc_auc_score, auc, f1_score

preds = model.predict(test_data)

predictions = [i.argmax() for i in preds]
y_true = [i.argmax() for i in test_labels]
cm = confusion_matrix(y_pred=predictions, y_true=y_true)

print('Accuracy {}'.format(accuracy_score(y_true=y_true, y_pred=predictions)))
# Out:
# Accuracy 0.9977477477477478

# %%
plt.rcParams["axes.grid"] = False
plt.rcParams.update({'font.size': 20})

labels = []

label = test_generator.class_indices
indexlabel = dict((value, key) for key, value in label.items())

for k,v in indexlabel.items():
    labels.append(v)

from sklearn.metrics import confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion Matrix')

    print(cm)
#     fig = plt.figure()
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
#     plt.title(title)
#     plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
#     plt.savefig('plots/3.InceptionV3-2-Private-DataSet-CM.png', bbox_inches='tight', dpi = 100) 


plt.figure(figsize=(10,10))
plot_confusion_matrix(cm, classes=labels, title=' ')
# Out:
# Confusion Matrix
# [[354   0   0   0]
#  [  0 410   0   2]
#  [  1   1 653   0]
#  [  0   0   0 355]]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
y_pred=predictions
y_pred_probabilities=y_pred

# y_pred = np.argmax(y_pred,axis = 1) 
y_actual = y_true

classnames=[]
for classname in test_generator.class_indices:
    classnames.append(classname)

confusion_mtx = confusion_matrix(y_actual, y_pred) 
print(confusion_mtx)
target_names = classnames
print(classification_report(y_actual, y_pred, target_names=target_names))
# Out:
# [[354   0   0   0]
#  [  0 410   0   2]
#  [  1   1 653   0]
#  [  0   0   0 355]]
#               precision    recall  f1-score   support
#
#         left       1.00      1.00      1.00       354
#        right       1.00      1.00      1.00       412
#      sitting       1.00      1.00      1.00       655
#     standing       0.99      1.00      1.00       355
#
#     accuracy                           1.00      1776
#    macro avg       1.00      1.00      1.00      1776
# weighted avg       1.00      1.00      1.00      1776

# %%
total=sum(sum(cm))

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity*100 )

Specificity = cm[1,1]/(cm[1,1]+cm[0,1])
print('Specificity : ', Specificity*100 )
# Out:
# Sensitivity :  100.0
# Specificity :  100.0

# %%
y_pred_class = model.predict(test_data, verbose=1)

y_pred_class = [np.argmax(r) for r in y_pred_class]
test_y = [np.argmax(r) for r in test_labels]


from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, cohen_kappa_score, roc_auc_score, roc_curve

# Precision
print('Precision = ', precision_score(test_y, y_pred_class, average='weighted'))
# (None, 'micro', 'macro', 'weighted', 'samples')

# Recall
print('Recall = ', recall_score(test_y, y_pred_class, average='weighted'))

# f1_score
print('f1_score = ', f1_score(test_y, y_pred_class, average='weighted'))
# Out:
# 56/56 [==============================] - 0s 1ms/step
# Precision =  0.9977542726875995
# Recall =  0.9977477477477478
# f1_score =  0.9977478392765492

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelBinarizer

def multiclass_roc_auc_score(y_test, y_pred, average="weighted"):
    label_binarizer = LabelBinarizer()
    label_binarizer.fit(y_test)

    truth = label_binarizer.transform(y_test)
    pred = label_binarizer.transform(y_pred)
    return roc_auc_score(truth, pred, average=average)
# roc_auc_score
print('roc_auc_score = ', multiclass_roc_auc_score(test_y, y_pred_class))
# Out:
# roc_auc_score =  0.9985780838770497

# %%
predict = model.predict_proba(test_data, batch_size=batch_size, verbose=1)
# Out:
# 56/56 [==============================] - 0s 1ms/step

# %%
from sklearn.preprocessing import label_binarize

lw = 2
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
y = label_binarize(test_labels, classes=[0, 1, 2, 3])
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y[:, i], predict[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y.ravel(), predict.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

from scipy import interp
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(num_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= num_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams["axes.grid"] = False
plt.rcParams.update({'font.size': 15})

from itertools import cycle
classnames=[]
for classname in test_generator.class_indices:
    classnames.append(classname)
    

plt.figure(figsize=(10, 10))
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),linewidth=2)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         linewidth=2)
plot_name = 'no variation'
colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])

for i, color in zip(range(num_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()

# %%
# Zoom in view of the upper left corner.
plt.figure(figsize=(12,10))
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)


plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=1)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=1)

colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(num_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")

plt.show()

# %%
from sklearn.manifold.t_sne import TSNE

model_predictions = np.vstack(preds)
classes = np.hstack(y_pred)

tsne = TSNE(n_components=2)
tsne_data = tsne.fit_transform(model_predictions)

seaborn.scatterplot(tsne_data[:,0], tsne_data[:,1], hue=classes)

# %%
output_filename = "Pig_DenseNet201"
dir_name = "/kaggle/working"

import shutil
shutil.make_archive(output_filename, "zip", dir_name)
# Out:
# '/kaggle/working/Pig_DenseNet201.zip'

# %%
print("Done!!!")
