# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 17676138377070383602, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 9221160305
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1845201536179160067
#  physical_device_desc: "device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1", name: "/device:GPU:1"
#  device_type: "GPU"
#  memory_limit: 6683898676
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 7938582069855863373
#  physical_device_desc: "device: 1, name: GeForce GTX 1070 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1"]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
AlexNet  = [0.83, 0.81, 0.81, 0.80]
ResNet50 = [0.93, 0.92, 0.92, 0.92]
VGGNet16 = [0.90, 0.90, 0.90, 0.90]
VGGNet19 = [0.88, 0.88, 0.88, 0.88]
Xception = [0.90, 0.90, 0.90, 0.90]

index = ['Precision','Recall', 'F1-Score', 'Accuracy']


df = pd.DataFrame({'AlexNet': AlexNet, 'ResNet50': ResNet50, 'F1-VGGNet16': VGGNet16,
                   'VGGNet19': VGGNet19, 'Xception': Xception}, index=index)

ax = df.plot.bar(rot=0)

# ax = df.plot.bar(rot=0, width = 0.6, figsize=(6,5))
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#           ncol=3, fancybox=True, shadow=True)

# plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig('plot-acc-with-aug.png', bbox_inches='tight', dpi = 100)

# %%
AlexNet  = [0.83, 0.81, 0.81, 0.80]
ResNet50 = [0.86, 0.86, 0.85, 0.86]
VGGNet16 = [0.84, 0.84, 0.84, 0.84]
VGGNet19 = [0.84, 0.84, 0.84, 0.84]
Xception = [0.44, 0.66, 0.53, 0.66]

index = ['Precision','Recall', 'F1-Score', 'Accuracy']


df = pd.DataFrame({'AlexNet': AlexNet, 'ResNet50': ResNet50, 'F1-VGGNet16': VGGNet16,
                   'VGGNet19': VGGNet19, 'Xception': Xception}, index=index)

ax = df.plot.bar(rot=0)

# ax = df.plot.bar(rot=0, width = 0.6, figsize=(6,5))
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#           ncol=3, fancybox=True, shadow=True)

# plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig('plot-acc-without-aug.png', bbox_inches='tight', dpi = 100)

# %%
AlexNet=  [0.95,0.97,0.67,0.83,0.92, 0.80,0.68]
VGGNet16= [0.97,0.88,0.75,0.99,0.94,0.78,1.00]
VGGNet19= [0.87,0.96,0.82,1.00,0.87,0.76,1.00]
ResNet50= [0.97,0.92,0.77,0.99,0.94,0.92,1.00]
Xception= [0.96,0.91,0.76,1.00,0.89,0.84,1.00]

index = ['AKIEC','BCC','BKL','DF','MEL','NV','VASC']


df = pd.DataFrame({'AlexNet': AlexNet, 'ResNet50': ResNet50, 'F1-VGGNet16': VGGNet16,
                   'VGGNet19': VGGNet19, 'Xception': Xception}, index=index)

ax = df.plot.bar(rot=0)

# ax = df.plot.bar(rot=0, width = 0.6, figsize=(6,5))
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#           ncol=3, fancybox=True, shadow=True)

# plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig('plot-class-acc.png', bbox_inches='tight', dpi = 100)
