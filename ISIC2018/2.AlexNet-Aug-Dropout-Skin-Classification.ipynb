# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
print(tf.test.gpu_device_name())
# See https://www.tensorflow.org/tutorials/using_gpu#allowing_gpu_memory_growth
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
# Out:
# /device:GPU:0

# %%
from keras import backend as K
K.clear_session()

with tf.Session() as sess:
        sess = tf.Session()
        K.set_session(sess)
# Out:
# Using TensorFlow backend.

# %%
init_op = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init_op)

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 15864049579566174685, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 9202108990
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 15147508993348176073
#  physical_device_desc: "device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"]

# %%
import os
import pandas as pd

import numpy as np
from glob import glob
import cv2
import skimage
from skimage.transform import resize

from keras import layers
from keras import models
from keras import optimizers
from keras.models import load_model
import keras.callbacks as kcall
from keras.optimizers import Adam
from keras.models import Model
from keras.models import Sequential
from keras.layers import Flatten, Dense, Activation, Dropout, Conv2D, MaxPooling2D, BatchNormalization, ZeroPadding2D
from keras.applications.xception import Xception, preprocess_input
from keras.regularizers import l2
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
train_dir = 'data-w/train'
validation_dir = 'data/validation'

# %%
for root,dirs,files in os.walk(train_dir):
    print (root, len(files))
# Out:
# data/train 0
# data/train\AKIEC 3856
# data/train\BCC 4773
# data/train\BKL 3275
# data/train\DF 4152
# data/train\MEL 3308
# data/train\NV 4975
# data/train\VASC 3488

# %%
for root,dirs,files in os.walk(validation_dir):
    print (root, len(files))
# Out:
# data/validation 0
# data/validation\AKIEC 1552
# data/validation\BCC 1692
# data/validation\BKL 1479
# data/validation\DF 1632
# data/validation\MEL 1664
# data/validation\NV 1730
# data/validation\VASC 1484

# %%
## Intilizing variables
output_classes = 7

batch_size = 64
epochs = 50
adam_opt = Adam(lr=1e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=1e-5)

# %%
from keras.preprocessing.image import ImageDataGenerator

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True)


# target_size = (height, width)
target_size = (448, 448)


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size = target_size,       
        class_mode = 'categorical',
        shuffle = True)

validation_generator = train_datagen.flow_from_directory(
        validation_dir,
        target_size = target_size,        
        class_mode = 'categorical',
        shuffle = True)
# Out:
# Found 27827 images belonging to 7 classes.
# Found 11233 images belonging to 7 classes.

# %%
import keras.backend as K

def precision(y_true, y_pred):
    # Calculates the precision
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision


def recall(y_true, y_pred):
    # Calculates the recall
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def fbeta_score(y_true, y_pred, beta=1):
    # Calculates the F score, the weighted harmonic mean of precision and recall.

    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
        
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score

def fmeasure(y_true, y_pred):
    # Calculates the f-measure, the harmonic mean of precision and recall.
    return fbeta_score(y_true, y_pred, beta=1)

# %%
model = Sequential()

## Architecture
model.add(Conv2D( filters = 96, kernel_size = (11,11), strides = 4, padding = 'same', activation = 'relu', 
                 input_shape = (448, 448, 3), kernel_initializer = 'he_normal'))
model.add(MaxPooling2D( pool_size = (3,3), strides = (2,2), padding= 'same', data_format = None)) # overlapping pooling

model.add(Conv2D( filters = 256, kernel_size = (5,5), strides = 1, padding = 'same', activation = 'relu', kernel_initializer = 'he_normal'))
model.add(MaxPooling2D( pool_size = (3,3), strides = (2,2), padding= 'same', data_format = None)) 

model.add(Conv2D( filters = 384, kernel_size = (3,3), strides = 1, padding = 'same', activation = 'relu', kernel_initializer = 'he_normal'))
model.add(Conv2D( filters = 384, kernel_size = (3,3), strides = 1, padding = 'same', activation = 'relu', kernel_initializer = 'he_normal'))
model.add(Conv2D( filters = 256, kernel_size = (3,3), strides = 1, padding = 'same', activation = 'relu', kernel_initializer = 'he_normal'))
model.add(MaxPooling2D( pool_size = (3,3), strides = (2,2), padding= 'same', data_format = None))

model.add(Flatten())
model.add(Dense( units = 4096, activation = 'relu'))
model.add(Dense( units = 4096, activation = 'relu'))

model.add(Dense( units = 7, activation = 'softmax'))
# model.summary()

## Optimizer
adam = optimizers.adam(lr=0.00005, beta_1 = 0.9, beta_2 = 0.999, epsilon = None, decay= 0, amsgrad = False)
momentum = optimizers.SGD(lr=0.01, momentum = 0.9, decay=1e-6)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 112, 112, 96)      34944
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 96)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 256)       614656
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 384)       885120
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 384)       1327488
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 256)       884992
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              205524992
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 28679
# =================================================================
# Total params: 226,082,183
# Trainable params: 226,082,183
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import losses, metrics, regularizers
model.compile(optimizer = adam, loss='categorical_crossentropy',   metrics = ["categorical_accuracy", fmeasure, recall, precision])

# %%
history = model.fit_generator(train_generator,
    steps_per_epoch=2048,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps=1024)
# Out:
# Epoch 1/50
# 2048/2048 [==============================] - 601s 294ms/step - loss: 0.8198 - categorical_accuracy: 0.6913 - fmeasure: 0.6500 - recall: 0.5774 - precision: 0.7964 - val_loss: 0.9173 - val_categorical_accuracy: 0.7177 - val_fmeasure: 0.7137 - val_recall: 0.6749 - val_precision: 0.7588
# Epoch 2/50
# 2048/2048 [==============================] - 569s 278ms/step - loss: 0.2348 - categorical_accuracy: 0.9115 - fmeasure: 0.9107 - recall: 0.8938 - precision: 0.9290 - val_loss: 1.0390 - val_categorical_accuracy: 0.7705 - val_fmeasure: 0.7722 - val_recall: 0.7542 - val_precision: 0.7916
# Epoch 3/50
# 2048/2048 [==============================] - 576s 281ms/step - loss: 0.0964 - categorical_accuracy: 0.9659 - fmeasure: 0.9660 - recall: 0.9622 - precision: 0.9699 - val_loss: 1.1271 - val_categorical_accuracy: 0.7928 - val_fmeasure: 0.7959 - val_recall: 0.7855 - val_precision: 0.8070
# Epoch 4/50
# 2048/2048 [==============================] - 581s 284ms/step - loss: 0.0517 - categorical_accuracy: 0.9830 - fmeasure: 0.9830 - recall: 0.9818 - precision: 0.9842 - val_loss: 1.4405 - val_categorical_accuracy: 0.7863 - val_fmeasure: 0.7870 - val_recall: 0.7834 - val_precision: 0.7907552 - categorical_accuracy: 0.9819 - fmeasure: 0.9819 - recall: 0.9806 - precision: 0 - ETA: 46s - loss: 0.0551 - categorical_accuracy: 0.9820 - fmeasure: 0.9820 - re - ETA: 40s - loss: 0.0547 - categorical_accuracy: 0.9821 - fmeasure: 0.9821 - recall: 0.9808 - precis - ETA: 38s - loss: 0.0546 - categorical_accuracy: 0.9821 - fmeasure: 0. - ETA: 30s - loss: 0.0540 - categorical_accuracy: 0.9822 - fmeasure: 0.9822 - recal - ETA: 24s - loss: 0.0535 - categorical_accuracy: 0
# Epoch 5/50
# 2048/2048 [==============================] - 577s 282ms/step - loss: 0.0382 - categorical_accuracy: 0.9884 - fmeasure: 0.9883 - recall: 0.9877 - precision: 0.9890 - val_loss: 1.4716 - val_categorical_accuracy: 0.7700 - val_fmeasure: 0.7723 - val_recall: 0.7662 - val_precision: 0.7787 0.0550 - categorical_accuracy: 0.9841 - fmeasure: 0.9840 - recall: 0.98 - ETA: 4:40 - loss: 0.0544 - categorical_accuracy: 0.9843 - fme - ETA: 4:24 - loss: 0.0491 - categorical_accuracy: 0.9859 - - ETA: 4:19 - loss: 0.0475 - cate - ETA: 2:32 - loss: 0.0377 - categorical_ac - ETA: 2:26 - loss: 0.0 - ETA: 1:11 - loss: 0.0425 - categorical_accuracy: 0.9872 - fmeasure: 0.9871 - recall: 0.9864 - pr - ETA: 36s - loss: 0.0398 - categorical_accuracy: 0. - ETA: 24s - loss: 0.0395 - categorical_accuracy: 0.9880 - fmeasure:  - ETA: 2s - loss: 0.0383 - categorical_accuracy: 0.9884 - fmeasure: 0.9883 - recall: 0.
# Epoch 6/50
# 2048/2048 [==============================] - 583s 285ms/step - loss: 0.0257 - categorical_accuracy: 0.9921 - fmeasure: 0.9921 - recall: 0.9918 - precision: 0.9923 - val_loss: 1.3132 - val_categorical_accuracy: 0.7931 - val_fmeasure: 0.7962 - val_recall: 0.7891 - val_precision: 0.8037
# Epoch 7/50
# 2048/2048 [==============================] - 583s 284ms/step - loss: 0.0230 - categorical_accuracy: 0.9932 - fmeasure: 0.9931 - recall: 0.9929 - precision: 0.9934 - val_loss: 1.2691 - val_categorical_accuracy: 0.7930 - val_fmeasure: 0.7946 - val_recall: 0.7889 - val_precision: 0.8006s: 0.0249 - categorical_ - ETA: 1:23 - l - ETA: 1:13 - loss: 0 - ETA: 1:04 - loss: 0.0242 - categorical_accuracy:  - ETA: 57s - loss: 0.0238 - categorical_accur - ETA: 45s - loss: 0.0237 - categori - ETA: 9s - los
# Epoch 8/50
# 2048/2048 [==============================] - 584s 285ms/step - loss: 0.0172 - categorical_accuracy: 0.9947 - fmeasure: 0.9948 - recall: 0.9946 - precision: 0.9950 - val_loss: 1.3001 - val_categorical_accuracy: 0.7889 - val_fmeasure: 0.7901 - val_recall: 0.7851 - val_precision: 0.7953oss: 0.0170 - categorical_accuracy: 0.9948 - fmeasure: 0.9948 - recall: 0.9946 - pr - ETA: 49s - loss: 0.0158 - categorical_accuracy: 0.9952 - fmeasure: 0.9952 - recall: 0.9950 - p - ETA: 46s - loss: 0.0160 - categorical_a - ETA: 32s - loss: 0.0161 - categorical_accuracy: 0.9951 - fmeasure: 0.9951 - recall - ETA: 26s - loss: 0.0163 - categorical_accuracy:  - ETA: 14s - loss: 0.0170 - categorical_accuracy: 0.9948 -  - ETA: 7s - loss: 0.0172 - categorical_accuracy: 0.9947 - fmeasure: 0.9948 - recall: 0.9946 - precision: 0.99 - ETA: 6s - loss: 0.0171 - categorical_ac
# Epoch 9/50
# 2048/2048 [==============================] - 578s 282ms/step - loss: 0.0188 - categorical_accuracy: 0.9943 - fmeasure: 0.9943 - recall: 0.9940 - precision: 0.9945 - val_loss: 1.3679 - val_categorical_accuracy: 0.8014 - val_fmeasure: 0.8032 - val_recall: 0.7986 - val_precision: 0.8079
# Epoch 10/50
# 2048/2048 [==============================] - 564s 275ms/step - loss: 0.0102 - categorical_accuracy: 0.9968 - fmeasure: 0.9968 - recall: 0.9967 - precision: 0.9969 - val_loss: 1.5423 - val_categorical_accuracy: 0.7992 - val_fmeasure: 0.8005 - val_recall: 0.7970 - val_precision: 0.8042
# Epoch 11/50
# 2048/2048 [==============================] - 584s 285ms/step - loss: 0.0187 - categorical_accuracy: 0.9949 - fmeasure: 0.9949 - recall: 0.9947 - precision: 0.9951 - val_loss: 1.3605 - val_categorical_accuracy: 0.7921 - val_fmeasure: 0.7936 - val_recall: 0.7882 - val_precision: 0.799440 -
# Epoch 12/50
# 2048/2048 [==============================] - 581s 284ms/step - loss: 0.0110 - categorical_accuracy: 0.9969 - fmeasure: 0.9969 - recall: 0.9968 - precision: 0.9969 - val_loss: 1.4118 - val_categorical_accuracy: 0.7973 - val_fmeasure: 0.7989 - val_recall: 0.7952 - val_precision: 0.8028 - fmeasure: 0.9965 - recall: 0.9963 - precision - ETA: 45s - loss: 0.0123 - categorical_accuracy: 0.9965 - fmeasure: 0.9965 - recall: 0.9964 - precision - ETA: 43s - loss: 0.0122 - categorical_accuracy: 0.9965 - fm
# Epoch 13/50
# 2048/2048 [==============================] - 583s 284ms/step - loss: 0.0106 - categorical_accuracy: 0.9972 - fmeasure: 0.9972 - recall: 0.9971 - precision: 0.9973 - val_loss: 1.6086 - val_categorical_accuracy: 0.7909 - val_fmeasure: 0.7917 - val_recall: 0.7879 - val_precision: 0.7956categorical_ac - ETA: 2:39 - loss: 0.0153 - categorical_accuracy: 0.9962 - fmeasure: - ETA: 1:51 - loss: 0.0132 - categorical_accuracy: 0.9968 - fmeasure: 0.9967 - recall: 0.9966 - precisi - ETA: 1:50 - loss: 0.0131 - categorical_accuracy: 0.9968 - f - ETA: 1:45 - loss: 0.0130 - categorical_accuracy: 0.9967 - fmeasure: 0.9967 - recall:  - ETA: 1:42 - loss: 0.0129 - categorical_accuracy: 0.9967 - fmeasure: 0.9967 - recall: 0.9966 - precision: 0. - ETA: 1:42 - loss: 0.0130 - categorical_accuracy: 0.9967 - fmeasure: 0.9967 - recall: 0.9966 - precision: 0. - ETA: 1:41 - loss: 0.0130 - cate - ETA: 3s - loss: 0.0107 - categorical_accuracy: 0.9972 - fmeasure: 0.9972 - recall: 0. - ETA: 0s - loss: 0.0106 - categorical_accuracy: 0.9972 - fmeasure: 0.9972 - recall: 0.9971 - precisi
# Epoch 14/50
# 2048/2048 [==============================] - 586s 286ms/step - loss: 6.8669e-05 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.5841 - val_categorical_accuracy: 0.8054 - val_fmeasure: 0.8069 - val_recall: 0.8041 - val_precision: 0.8098- ETA: 57s - loss: 7.9826e-05 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.00 - ETA: 53s - loss: 7.8906e-05 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - re - ETA: 47s - loss: 7.7586e-05 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.00 - ETA: 20s - loss: 7.2241e-05 - categorical_accuracy: 1.0000 - fmeasur - E
# Epoch 15/50
# 2048/2048 [==============================] - 587s 286ms/step - loss: 1.6808e-06 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.6971 - val_categorical_accuracy: 0.8071 - val_fmeasure: 0.8094 - val_recall: 0.8062 - val_precision: 0.81276s  - ETA: 14s - loss: 1.7151e-06 - categorical_accuracy: 1.0000 - fmeasure: 1. - ETA: 8s - loss: 1.7032e-06 -
# Epoch 16/50
# 2048/2048 [==============================] - 586s 286ms/step - loss: 4.1911e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.7824 - val_categorical_accuracy: 0.8076 - val_fmeasure: 0.8089 - val_recall: 0.8060 - val_precision: 0.8118oss: 4.927 - ETA: 1:45 - loss: 4.6819e-07 - categorical_accuracy: 1.0000 - fmeasure: - ETA: 1:41 - loss: 4.6618e-07 - categorical_accuracy - ETA: 1:23 - loss: 4.5968e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0 - ETA: 1:20 - loss: 4.5789e-07 - categorical_accuracy: 1.0000 - fmeasure:  - ETA: 46s - loss: 4.4197e-07 - - ETA: 30s - loss: 4.3475e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.00 - ETA: 22s - loss: 4.3119 - ETA: 7s - loss: 4.2303e-07 - cate
# Epoch 17/50
# 2048/2048 [==============================] - 579s 283ms/step - loss: 2.0962e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.8581 - val_categorical_accuracy: 0.8044 - val_fmeasure: 0.8056 - val_recall: 0.8031 - val_precision: 0.8082-07 - catego - ETA: 1:11 - loss: 2.1827e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precisi - ETA: 1:10 - loss: 2.1807e-07 - categorical_accuracy: 1.0000 - fmeasure: 1 - ETA: 50s - loss: 2.1486e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.000 - ETA: 50s - loss: 2.1481e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision - ETA: 48s - ETA: 28s - loss: 2.1240e-07 - categorical_accuracy: 1.0000 - fmeas - ETA: 3s - loss: 2.0987e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1. - ETA: 1s - loss: 2.0968e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - preci
# Epoch 18/50
# 2048/2048 [==============================] - 593s 289ms/step - loss: 1.5197e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.9059 - val_categorical_accuracy: 0.8066 - val_fmeasure: 0.8077 - val_recall: 0.8054 - val_precision: 0.81024e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - pre - ETA: 1:14 - loss: 1.5457e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - reca
# Epoch 19/50
# 2048/2048 [==============================] - 592s 289ms/step - loss: 1.3153e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.9222 - val_categorical_accuracy: 0.8084 - val_fmeasure: 0.8094 - val_recall: 0.8073 - val_precision: 0.8114oss: 1.3158e-07 - categorical_accuracy: 1.0000 - fmeasure: 1
# Epoch 20/50
# 2048/2048 [==============================] - 590s 288ms/step - loss: 1.2367e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.9898 - val_categorical_accuracy: 0.8059 - val_fmeasure: 0.8069 - val_recall: 0.8051 - val_precision: 0.8088rical_acc - ETA: 4s - loss: 1.2366e-07 - categorical_accuracy: 1.0000 - fme
# Epoch 21/50
# 2048/2048 [==============================] - 584s 285ms/step - loss: 1.2043e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0148 - val_categorical_accuracy: 0.8062 - val_fmeasure: 0.8074 - val_recall: 0.8055 - val_precision: 0.8093call: 1.0000 - pre - ETA - ETA: 3: - ETA: 2:51 - loss: 1.2076e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 -  - ETA: 2:25 - loss: 1.2069e-07 - categorical_accuracy - ETA: 2:18 - loss: 1.2068e - ETA: 1:58 - loss: 1.2063e-07 - categorical_accuracy: 1.0000 - fmeasure: 1 - ETA: 1:54 - loss: 1.2062e-07 - categorical_accuracy: 1.0000 - - ETA: 1:37 - loss: 1.2059e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision:  - ETA: 1:36 - loss: 1.2059e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0 - ETA: 1:32 - loss: 1.2058e-07 - cate - ETA: 1:24 - loss: 1.2060e-07 - categori - ETA: 1:17 - loss: 1.2058e-07 - categorical_accuracy: 1. - ETA: 1:11 - loss: 1.2060e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precisi - ETA: 1:10 - loss: 1.2059e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - reca - ETA: 1:07 - loss: 1.2058e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.00 - ETA: 1:07 - loss: 1.2058e-07 - categ - ETA: 59s - loss: 1.2056e-07 - categorical_accuracy: 1.0000 - fmeasure - ETA: 50 - ETA: 29s - loss: 1.2049e-07 - ca
# Epoch 22/50
# 2048/2048 [==============================] - 577s 282ms/step - loss: 1.1955e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0313 - val_categorical_accuracy: 0.8071 - val_fmeasure: 0.8080 - val_recall: 0.8064 - val_precision: 0.8096.0000 - precision: 1.000 - ETA: 38s - loss: 1.1 - ETA: 3s - loss: 1.1956e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000
# Epoch 23/50
# 2048/2048 [==============================] - 577s 282ms/step - loss: 1.1927e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0427 - val_categorical_accuracy: 0.8073 - val_fmeasure: 0.8080 - val_recall: 0.8065 - val_precision: 0.8096-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision - ETA: 5:39 - loss: 1.1939e-07 - categorical_accuracy: 1.0000 - fmeas - ETA: 5:00 - loss: 1.1934e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.00 - ETA: 5:00 - loss: 1.1934e-07 - catego - ETA: 4:52 - loss: 1.1933e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision:  - ETA: 4:52 - loss: 1.1933e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - preci - ETA: 4:50 - loss: 1.1933e-07 - categorical_accura - ETA: 1:16 - loss: 1.1929e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 -  - ETA: 1:12 - loss: 1.1928e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precisi - ETA: 1:11 - loss: 1.1928e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision:  - ETA: 1:11 - loss: 1.1928e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.00 - ETA: 1:11 - loss: 1.1928e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall:  - ETA: 1:08 - loss: 1.192 - ETA: 59s - loss: 1.1928e-07 - categorical_accuracy: 1.0000 - fmeasu - ETA: 49s - loss: 1.1928e-07 - categorical_accurac - ETA: 37s - loss: 1.1928e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - r - ETA: 30s - loss: 1.1928e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - preci - ETA: 28s - loss: 1.1928e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.000 - ETA: 24s - loss: 1.1928e-07 - categorical_accuracy: - ETA:
# Epoch 24/50
# 2048/2048 [==============================] - 578s 282ms/step - loss: 1.1922e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0673 - val_categorical_accuracy: 0.8070 - val_fmeasure: 0.8071 - val_recall: 0.8057 - val_precision: 0.8087: 1.0000 - precision - ETA: 6:09 - ETA: 4:16 - loss: 1.1923e-07  - ETA: 3:33 - loss: 1.192 - ETA: 3:24 - loss: 1.1922e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision:  - ETA: 3:23 - loss: 1.1922e-07 - categorical_accuracy: 1.0000 - fmeasur - ETA: 2:10 - loss: 1.1922e-07 - cate - ETA: 1:39 - loss: 1.1922e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - pre - ETA: 1:37 - loss: 1.1922e-07 - categorical_accuracy: 1.0000 - f - ETA: 1:32 - loss: 1.1922e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - re - ETA: 1:29 - loss: 1.1922e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1. - ETA: 1:29 - loss: 1.1922e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - p - ETA: 1:27 - loss: 1.1922e-07 - categorical_accura -  - ETA: 56s - loss: 1.1922e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000  - ETA: 53s - loss:  - ETA: 34s - loss: 1.1922e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - p - ETA: 31s - loss: 1.1922e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall:  - ETA: 25s - loss: 1.1922e-07 - categorical_accuracy
# Epoch 25/50
# 2048/2048 [==============================] - 578s 282ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0689 - val_categorical_accuracy: 0.8072 - val_fmeasure: 0.8071 - val_recall: 0.8057 - val_precision: 0.8086 loss: 1.1921e-07 - categori - ETA: 6:22 - loss: 1.1921e-07 - categorical_accuracy - ETA: 5:53 - loss: 1.1922e-07 - categorical_accuracy - ETA: 5:47 - loss: 1.1922e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1. - ETA: 5:33 - loss - ETA: 11s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure - ETA: 6s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.00 - ETA: 4s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure:
# Epoch 26/50
# 2048/2048 [==============================] - 579s 283ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0868 - val_categorical_accuracy: 0.8065 - val_fmeasure: 0.8069 - val_recall: 0.8056 - val_precision: 0.8084 fmeasure: - ETA: 1:57 - loss: 1.1921e-07 - categorical_accuracy:  - ETA: 1:16 - loss: 1.1921e-07 - categorical_accuracy: 1
# Epoch 27/50
# 2048/2048 [==============================] - 578s 282ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0714 - val_categorical_accuracy: 0.8066 - val_fmeasure: 0.8071 - val_recall: 0.8055 - val_precision: 0.8087racy: 1.0000 - fmeas - ETA: 2:27 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall:  - ETA: 2:25 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasur - ETA: 1: - ETA: 1:24 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precisi - ETA: 1:23 - loss: 1.1921e-07 - categorical_accura - ETA: 1:16 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fme - ETA: 1:00 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precisio - ETA: 58s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - reca - ETA: 52s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.00 - ETA: 45s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1 - ETA: 37s - loss: 1.1921e-07 - cat - ETA: 21s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall - ETA: 15s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision:  - ETA: 14s - loss: 1.1921e-07 - categorical_accu - ETA: 5s - loss: 1.1921e-07 - categorical_accuracy: 1.00
# Epoch 28/50
# 2048/2048 [==============================] - 581s 284ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0732 - val_categorical_accuracy: 0.8069 - val_fmeasure: 0.8072 - val_recall: 0.8058 - val_precision: 0.8086l_accuracy: 1.0000 - f - ETA: 2:31 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 -  - ETA: 2:28 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision - ETA: 2:15 - - ETA: 1:30 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.000 - ETA: 44s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1. - ETA: 43s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1. - ETA: 35s - loss: 1.1921e-07 - categorical_accur - ETA: 22s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 -  - ETA: 15s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall - ETA: 10s -
# Epoch 29/50
# 2048/2048 [==============================] - 578s 282ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0594 - val_categorical_accuracy: 0.8083 - val_fmeasure: 0.8086 - val_recall: 0.8072 - val_precision: 0.8101TA: 29s - loss: 1.1921e-07 - c
# Epoch 30/50
# 2048/2048 [==============================] - 577s 282ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0637 - val_categorical_accuracy: 0.8075 - val_fmeasure: 0.8078 - val_recall: 0.8064 - val_precision: 0.809307 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision - ETA: 3:07 - loss: 1.1921e-07 - categorical_accuracy:  - ETA: 2:03 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasur - ETA: 1:58 - loss: 1.1 - ETA: 1:37 - loss: 1.1921e-07 - ETA: 49s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - - ETA: 45s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.000 - ETA: 38s - loss: 1.1921e-07 - categorical_accu - ETA: 24s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 -  - ETA: 18s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - re - ETA: 11s - loss: 1.1921e - ETA: 1s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000
# Epoch 31/50
# 2048/2048 [==============================] - 577s 282ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0906 - val_categorical_accuracy: 0.8058 - val_fmeasure: 0.8061 - val_recall: 0.8047 - val_precision: 0.8075categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision - ETA: 1:43 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.00 - ETA: 1:43 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.00 - ETA: 1:43 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - pre - ETA: 1:41 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall - ETA: 1:38 - loss: 1.1921e-07 - catego - ETA: 1:08 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.000 - ETA: 1:04 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeas - ETA: 59s - loss: 1.1921e-07 - categoric - ETA: 44s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0 - ETA: 37s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000  - ETA: 33s - loss: 1.1921e-07 - categorical_accuracy:  - ETA: 21s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0 - ETA: 16s - loss: 1.1921e-07 - categorica - ETA: 6s - loss: 1.1921e-07 - categorical_accuracy:
# Epoch 32/50
# 2048/2048 [==============================] - 577s 282ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0753 - val_categorical_accuracy: 0.8068 - val_fmeasure: 0.8073 - val_recall: 0.8058 - val_precision: 0.8088 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - ETA: 5:43 - loss: 1.1921e-07 - categorical_accuracy: 1. - ETA - ETA: 5:03 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1 - ETA: 4:59 - loss: 1.1921e-07 -  - - ETA: 4:39 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: - ETA: 4:35 - loss: 1.192 - ETA: 1:3
# Epoch 33/50
# 2048/2048 [==============================] - 578s 282ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0762 - val_categorical_accuracy: 0.8071 - val_fmeasure: 0.8074 - val_recall: 0.8061 - val_precision: 0.8088 loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision:  - ETA: 6:07 - l - ETA: 2: - ETA: 1:56 - loss: 1.1921e-07 - categorical_accuracy: 1. - ETA: 1:50 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - p - ETA: 1:48 - - ETA: 44s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - - ETA: 38s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.00 - ETA: 33s - loss: 1.1921e-07 - categorical_accuracy: 1. - ETA: 21s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precisio - ETA - ETA: 4s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1
# Epoch 34/50
# 2048/2048 [==============================] - 579s 283ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0787 - val_categorical_accuracy: 0.8065 - val_fmeasure: 0.8069 - val_recall: 0.8055 - val_precision: 0.8083- loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasu - ETA: 18s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1 - ETA: 10s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fme - ETA: 5s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - f
# Epoch 35/50
# 2048/2048 [==============================] - 579s 283ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0612 - val_categorical_accuracy: 0.8082 - val_fmeasure: 0.8086 - val_recall: 0.8071 - val_precision: 0.8101s: 1.1921e-07 - categorical_accuracy - ETA: 2:29 - loss: 1.1921e-07 - categorical_accu - ETA: 2:22 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - ETA: 2:20 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precisi - ETA: 2:19 - loss: 1.1921e-07 - categorical_ - ETA - ETA: 1:15 - loss: 1.1921e-07 - categorical_accuracy: 1.00 - ETA: 1:09 - loss: 1.1 - ETA: 1:00 - loss: 1.1921e-07 - catego - ETA: 23s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - pre - ETA: 20s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0 - ETA: 19s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1. - ETA: 19s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: - ETA: 13s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - ETA: 6s - loss: 1.1921e-07 - categorical_accuracy
# Epoch 36/50
# 2048/2048 [==============================] - 581s 284ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0738 - val_categorical_accuracy: 0.8065 - val_fmeasure: 0.8068 - val_recall: 0.8054 - val_precision: 0.80830000 - fmeasure: 1.0000 - reca - ETA: 5:45 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeas - ETA: 5:40 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1. - ETA: 5:38 - loss: 1.1921e-07 - categorica - ETA: 5:31 - loss: 1.1921e-07  - ETA: 4:47 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision - ETA:  - ETA: 1:19 - loss:  - ETA: 57s - loss: 1.1921e-07 - categorical_accuracy: 1.00 - ETA: 45s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.000 - ETA: 45s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision - ETA: 44s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure - E
# Epoch 37/50
# 2048/2048 [==============================] - 583s 284ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0769 - val_categorical_accuracy: 0.8074 - val_fmeasure: 0.8078 - val_recall: 0.8064 - val_precision: 0.8092l_accuracy: 1.0000 - fme - ETA: 10
# Epoch 38/50
# 2048/2048 [==============================] - 585s 286ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0857 - val_categorical_accuracy: 0.8065 - val_fmeasure: 0.8069 - val_recall: 0.8055 - val_precision: 0.8083 loss: 1.192 - ETA: 3:21 - loss: 1.1921e - ETA: 3:00 - ETA: 1:52 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - f - ETA: 1:24 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0
# Epoch 39/50
# 2048/2048 [==============================] - 583s 285ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0822 - val_categorical_accuracy: 0.8057 - val_fmeasure: 0.8060 - val_recall: 0.8045 - val_precision: 0.8076gorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - p - ETA:  - ETA: 2:10 - loss: 1.1921e-07 - categorical_accura - ETA: 2:04 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - pre - ETA: 2:03 - loss: 1.1921e-07 - categorica - ETA: 1:55 - loss: 1.1921e-07 - cate - ETA: 1:48 - los - ETA: 21s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0 - ETA: 21s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmea - ETA: 11s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1 - ETA: 6s - loss: 1.1921e-07 - categorical_accu
# Epoch 40/50
# 2048/2048 [==============================] - 581s 284ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0619 - val_categorical_accuracy: 0.8077 - val_fmeasure: 0.8081 - val_recall: 0.8067 - val_precision: 0.80961:36 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0 - ETA: 1:32 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.000  - ETA: 49s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1 - ETA: 48s - loss: 1.1921e-07 - categ - ETA: 32s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.000 - ETA: 25s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1 - ETA: 24s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000  - ETA: 20s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000  - ETA: 13s - loss: 1.1921e-07 - categorical_ - ETA: 4s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasur
# Epoch 41/50
# 2048/2048 [==============================] - 576s 281ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0725 - val_categorical_accuracy: 0.8076 - val_fmeasure: 0.8078 - val_recall: 0.8064 - val_precision: 0.8094 37s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - - ETA: 30s - loss: 1.1921e-07 - categorical_acc - ETA: 1s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 -
# Epoch 42/50
# 2048/2048 [==============================] - 578s 282ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0684 - val_categorical_accuracy: 0.8071 - val_fmeasure: 0.8075 - val_recall: 0.8062 - val_precision: 0.8089s: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 -  - ETA: 3:09 - loss: 1.1921e-07 - categorical_accura - ETA: 2:40 - loss: 1.1921e- - ETA: 10s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000  - ETA: 8s - loss: 1.1921e-07
# Epoch 43/50
# 2048/2048 [==============================] - 578s 282ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0789 - val_categorical_accuracy: 0.8069 - val_fmeasure: 0.8072 - val_recall: 0.8058 - val_precision: 0.8087.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.00 - ETA: 5:56 - loss: 1.1921e-07 - categorica - ETA: 5: - ETA: 5:27 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.00 - ETA: 5:14 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - preci - ETA: 5:13 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1. - ETA: 5:12 - loss: 1.1921e-07 - catego - ETA: 5:05 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasur - ETA: 5:00 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.000 - ETA: 4:22 - los - ETA: 4:12 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - reca - ETA: 4:09 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeas - ETA: 4:04 - loss: 1.1921e-07 - cate - ETA: 3:10 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - p - ETA:  - ETA: 2:46 - loss: 1.1 - ETA: 2:26 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - p - ETA: 2:24 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.00
# Epoch 44/50
# 2048/2048 [==============================] - 573s 280ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0743 - val_categorical_accuracy: 0.8069 - val_fmeasure: 0.8072 - val_recall: 0.8058 - val_precision: 0.8086
# Epoch 45/50
# 2048/2048 [==============================] - 577s 282ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0699 - val_categorical_accuracy: 0.8077 - val_fmeasure: 0.8080 - val_recall: 0.8066 - val_precision: 0.8095 - categorical_accuracy: 1.0000 - fmeasure: 1 - ETA: 48s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1 - ETA: 47s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1 - ETA: 46s - loss: 1.1921e-07 - categori - ETA: 32s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision - ETA: 30s - loss: 1.1921e-0
# Epoch 46/50
# 2048/2048 [==============================] - 575s 281ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0902 - val_categorical_accuracy: 0.8058 - val_fmeasure: 0.8061 - val_recall: 0.8047 - val_precision: 0.8076000 - recall: 1.0000 - p - ETA: 2:02 - loss:  - ETA: 27s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1 - ETA: 26s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000  - ETA: 3s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - re
# Epoch 47/50
# 2048/2048 [==============================] - 577s 282ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0744 - val_categorical_accuracy: 0.8064 - val_fmeasure: 0.8068 - val_recall: 0.8053 - val_precision: 0.80831e-07  - ETA: 1:33 - - ETA: 1:12 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeas - ETA: 1:07 - loss: 1.1921e-07 - categorical_ac - ETA: 1:00 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1. - ETA: 56s - loss: 1.1921e-07 - categorical_accurac - ETA: 43s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.000 - ETA: 39s -  - ETA: 19s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.000 - ET
# Epoch 48/50
# 2048/2048 [==============================] - 580s 283ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0514 - val_categorical_accuracy: 0.8088 - val_fmeasure: 0.8091 - val_recall: 0.8078 - val_precision: 0.81051e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - preci - ETA: 1:37 - loss: 1.1921e-07 - categorical_accuracy: 1. - ETA: 1:31 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - re - ETA: 1:16 - loss: 1.1921e-07 - categorical_accuracy: 1 - ETA: 57s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: - ETA: 52s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure - ETA: 43s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.00 - ETA: 16s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 -
# Epoch 49/50
# 2048/2048 [==============================] - 580s 283ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0835 - val_categorical_accuracy: 0.8065 - val_fmeasure: 0.8069 - val_recall: 0.8054 - val_precision: 0.8084meas - ETA: 2:40 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - pre - ETA: 2:39 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - - ETA: 2:11 - loss: 1.1 - ETA: 2:01 - loss: 1.1921e-07 - categorical_accuracy: 1.00 - ETA: 1:10 - loss: 1.1921e-07 - categorical_accuracy - ETA: 1:03 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fm - ETA: 57s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure:  - ETA: 49s - loss: 1.1921e-07 - categorica - ETA: 34s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 -  - ETA: 31s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.00 - ETA: 27s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: - ETA: 22s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasu
# Epoch 50/50
# 2048/2048 [==============================] - 580s 283ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0834 - val_categorical_accuracy: 0.8066 - val_fmeasure: 0.8069 - val_recall: 0.8055 - val_precision: 0.8084l_accuracy: 1. - ETA: 3:13 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 -  - ETA: 3:09 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: - ETA: 3:05 - loss: 1.1921e-07  - ETA: 2:45 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - re - ETA: 2:42 - ETA: 2:32 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - - ETA: 1:32 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.000 - - ETA: 1:06 - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - ETA: 1:04 - loss: 1.1921e-07 - categorical_ - ETA: 55s - lo - ETA: 35s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 -  - ETA: 25s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precis - ETA: 22s - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fm

# %%
score = model.evaluate_generator(validation_generator, steps=50)

print ('Test Score: ', score[0])
print ('Test Accuracy: ',score[1])
print ('fmeasure: ', score[2])
print ('Recall: ', score[3])
print ('Precision: ', score[4])
# Out:
# Test Score:  2.059846431463957
# Test Accuracy:  0.805625
# fmeasure:  0.8046924006938935
# Recall:  0.803125
# Precision:  0.8063104820251464

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["categorical_accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_categorical_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")

# %%
from keras.preprocessing.image import ImageDataGenerator

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True)


# target_size = (height, width)
target_size = (448, 448)


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size = target_size,       
        class_mode = 'categorical',
        shuffle = False)

validation_generator = train_datagen.flow_from_directory(
        validation_dir,
        target_size = target_size,        
        class_mode = 'categorical',
        shuffle = False)
# Out:
# Found 27827 images belonging to 7 classes.
# Found 11233 images belonging to 7 classes.

# %%
filename = validation_generator.filenames
truth = validation_generator.classes
label = validation_generator.class_indices
indexlabel = dict((value, key) for key, value in label.items())

predicts = model.predict_generator(validation_generator, steps=validation_generator.samples/validation_generator.batch_size, verbose=1)
predict_class = np.argmax(predicts, axis=1)
errors = np.where(predict_class != truth)[0]
print("No of errors = {}/{}".format(len(errors),validation_generator.samples))
# Out:
# 352/351 [==============================] - 62s 177ms/step
# No of errors = 2168/11233

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(truth,predict_class)

labels = []
for k,v in indexlabel.items():
    labels.append(v)
    
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion Matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))    

plt.figure(figsize=(10,10))


plot_confusion_matrix(cm, classes=labels,
                      title='Confusion Matrix')
# Out:
# Confusion Matrix
# [[1168   66  204    2   74   38    0]
#  [  14 1467   87    0   49   61   14]
#  [  19   20 1295    1   69   75    0]
#  [  46  124   77 1174   32  169   10]
#  [  12   11   93    1 1397  143    7]
#  [   5   18   88    4  123 1486    6]
#  [   1   52   84   48   12  209 1078]]

# %%
#ROC Curve for each class
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
import matplotlib.pyplot as plt
# %matplotlib inline  
from scipy import interp
from itertools import cycle




y_pred = predicts
y_pred_probabilities=y_pred

y_pred = np.argmax(y_pred,axis = 1) 
y_actual = validation_generator.classes

classnames=[]
for classname in validation_generator.class_indices:
    classnames.append(classname)

y_actual_binary = label_binarize(y_actual, classes=[0, 1, 2, 3, 4,5,6])
y_pred_binary = y_pred_probabilities#label_binarize(y_pred_probabilities, classes=[0, 1, 2, 3, 4])
n_classes=7
lw=2

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_actual_binary[:, i], y_pred_binary[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_actual_binary.ravel(), y_pred_binary.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(figsize=(7, 7))


colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="best")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c9db9af2f902> in <module>
#      11
#      12
# ---> 13 y_pred = predicts
#      14 y_pred_probabilities=y_pred
#      15
#
# NameError: name 'predicts' is not defined

# %%
# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=6)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=6)


colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

    
    
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-classs')
plt.legend(loc="lower right")
plt.savefig('plots/2.AlexNet-ROC.png', dpi = 100)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report

confusion_mtx = confusion_matrix(y_actual, y_pred) 
print(confusion_mtx)
target_names = classnames
print(classification_report(y_actual, y_pred, target_names=target_names))
# Out:
# [[1168   66  204    2   74   38    0]
#  [  14 1467   87    0   49   61   14]
#  [  19   20 1295    1   69   75    0]
#  [  46  124   77 1174   32  169   10]
#  [  12   11   93    1 1397  143    7]
#  [   5   18   88    4  123 1486    6]
#  [   1   52   84   48   12  209 1078]]
#               precision    recall  f1-score   support
#
#          MEL       0.92      0.75      0.83      1552
#           DF       0.83      0.87      0.85      1692
#          BKL       0.67      0.88      0.76      1479
#        AKIEC       0.95      0.72      0.82      1632
#           NV       0.80      0.84      0.82      1664
#         VASC       0.68      0.86      0.76      1730
#          BCC       0.97      0.73      0.83      1484
#
#    micro avg       0.81      0.81      0.81     11233
#    macro avg       0.83      0.81      0.81     11233
# weighted avg       0.83      0.81      0.81     11233

# %%
model.save('models/2.AlexNet-Aug-Adam-Dropout-Model.h5')
model.save_weights('models/2.AlexNet-Aug-Adam-Dropout-Weights.h5')
