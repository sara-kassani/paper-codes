# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
print(tf.test.gpu_device_name())
# See https://www.tensorflow.org/tutorials/using_gpu#allowing_gpu_memory_growth
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
# Out:
# /device:GPU:0

# %%
from keras import backend as K
K.clear_session()

with tf.Session() as sess:
        sess = tf.Session()
        K.set_session(sess)
# Out:
# Using TensorFlow backend.

# %%
init_op = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init_op)

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 1559877053424827368, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 9221160305
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 9350370140378465084
#  physical_device_desc: "device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1", name: "/device:GPU:1"
#  device_type: "GPU"
#  memory_limit: 6683898676
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 9722060264004199057
#  physical_device_desc: "device: 1, name: GeForce GTX 1070 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1"]

# %%
import os
import pandas as pd

import numpy as np
from glob import glob
import cv2
import skimage
from skimage.transform import resize

from keras import layers
from keras import models
from keras import optimizers
from keras.models import load_model
import keras.callbacks as kcall
from keras.optimizers import Adam
from keras.models import Model
from keras.models import Sequential
from keras.layers import Flatten, Dense, Activation, Dropout, Conv2D, MaxPooling2D, BatchNormalization, ZeroPadding2D
from keras.applications.xception import Xception, preprocess_input
from keras.regularizers import l2
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
train_dir = 'data/train'
validation_dir = 'data/validation'

# %%
for root,dirs,files in os.walk(train_dir):
    print (root, len(files))
# Out:
# data/train 0
# data/train\AKIEC 3856
# data/train\BCC 4773
# data/train\BKL 3275
# data/train\DF 4152
# data/train\MEL 3308
# data/train\NV 4975
# data/train\VASC 3488

# %%
for root,dirs,files in os.walk(validation_dir):
    print (root, len(files))
# Out:
# data/validation 0
# data/validation\AKIEC 1552
# data/validation\BCC 1692
# data/validation\BKL 1479
# data/validation\DF 1632
# data/validation\MEL 1664
# data/validation\NV 1730
# data/validation\VASC 1484

# %%
## Intilizing variables
output_classes = 7

batch_size = 64
epochs = 50
adam_opt = Adam(lr=1e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=1e-5)

# %%
from keras.preprocessing.image import ImageDataGenerator

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True)


# target_size = (height, width)
target_size = (224, 224)


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size = target_size,       
        class_mode = 'categorical',
        shuffle = True)

validation_generator = train_datagen.flow_from_directory(
        validation_dir,
        target_size = target_size,        
        class_mode = 'categorical',
        shuffle = True)
# Out:
# Found 27827 images belonging to 7 classes.
# Found 11233 images belonging to 7 classes.

# %%
import keras.backend as K

def precision(y_true, y_pred):
    # Calculates the precision
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision


def recall(y_true, y_pred):
    # Calculates the recall
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def fbeta_score(y_true, y_pred, beta=1):
    # Calculates the F score, the weighted harmonic mean of precision and recall.

    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
        
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score

def fmeasure(y_true, y_pred):
    # Calculates the f-measure, the harmonic mean of precision and recall.
    return fbeta_score(y_true, y_pred, beta=1)

# %%
model = Sequential()

## Architecture
model.add(Conv2D( filters = 96, kernel_size = (11,11), strides = 4, padding = 'same', activation = 'relu', 
                 input_shape = (224, 224, 3), kernel_initializer = 'he_normal'))
model.add(MaxPooling2D( pool_size = (3,3), strides = (2,2), padding= 'same', data_format = None)) # overlapping pooling

model.add(Conv2D( filters = 256, kernel_size = (5,5), strides = 1, padding = 'same', activation = 'relu', kernel_initializer = 'he_normal'))
model.add(MaxPooling2D( pool_size = (3,3), strides = (2,2), padding= 'same', data_format = None)) 

model.add(Conv2D( filters = 384, kernel_size = (3,3), strides = 1, padding = 'same', activation = 'relu', kernel_initializer = 'he_normal'))
model.add(Conv2D( filters = 384, kernel_size = (3,3), strides = 1, padding = 'same', activation = 'relu', kernel_initializer = 'he_normal'))
model.add(Conv2D( filters = 256, kernel_size = (3,3), strides = 1, padding = 'same', activation = 'relu', kernel_initializer = 'he_normal'))
model.add(MaxPooling2D( pool_size = (3,3), strides = (2,2), padding= 'same', data_format = None))

model.add(Flatten())
model.add(Dense( units = 4096, activation = 'relu'))
model.add(Dense( units = 4096, activation = 'relu'))

model.add(Dense( units = 7, activation = 'softmax'))
# model.summary()

## Optimizer
adam = optimizers.adam(lr=0.00005, beta_1 = 0.9, beta_2 = 0.999, epsilon = None, decay= 0, amsgrad = False)
momentum = optimizers.SGD(lr=0.01, momentum = 0.9, decay=1e-6)

# %%
from keras import losses, metrics, regularizers
model.compile(optimizer = adam, loss='categorical_crossentropy',   metrics = ["categorical_accuracy", fmeasure, recall, precision])

# %%
history = model.fit_generator(train_generator,
    steps_per_epoch=2048,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps=1024)
# Out:
# Epoch 1/50
# 2048/2048 [==============================] - 482s 235ms/step - loss: 0.8862 - categorical_accuracy: 0.6582 - fmeasure: 0.6101 - recall: 0.5266 - precision: 0.7793 - val_loss: 0.9837 - val_categorical_accuracy: 0.6878 - val_fmeasure: 0.6785 - val_recall: 0.6279 - val_precision: 0.7401
# Epoch 2/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 0.3303 - categorical_accuracy: 0.8744 - fmeasure: 0.8735 - recall: 0.8460 - precision: 0.9042 - val_loss: 1.0174 - val_categorical_accuracy: 0.7811 - val_fmeasure: 0.7796 - val_recall: 0.7593 - val_precision: 0.8017
# Epoch 3/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 0.1609 - categorical_accuracy: 0.9396 - fmeasure: 0.9394 - recall: 0.9303 - precision: 0.9490 - val_loss: 1.0900 - val_categorical_accuracy: 0.7861 - val_fmeasure: 0.7878 - val_recall: 0.7731 - val_precision: 0.8035
# Epoch 4/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 0.0817 - categorical_accuracy: 0.9705 - fmeasure: 0.9705 - recall: 0.9677 - precision: 0.9734 - val_loss: 1.1315 - val_categorical_accuracy: 0.8025 - val_fmeasure: 0.8047 - val_recall: 0.7986 - val_precision: 0.8110
# Epoch 5/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 0.0545 - categorical_accuracy: 0.9814 - fmeasure: 0.9813 - recall: 0.9801 - precision: 0.9826 - val_loss: 1.2849 - val_categorical_accuracy: 0.7899 - val_fmeasure: 0.7905 - val_recall: 0.7841 - val_precision: 0.7972
# Epoch 6/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 0.0415 - categorical_accuracy: 0.9866 - fmeasure: 0.9867 - recall: 0.9859 - precision: 0.9875 - val_loss: 1.2951 - val_categorical_accuracy: 0.8179 - val_fmeasure: 0.8194 - val_recall: 0.8151 - val_precision: 0.8238
# Epoch 7/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 0.0311 - categorical_accuracy: 0.9901 - fmeasure: 0.9902 - recall: 0.9897 - precision: 0.9907 - val_loss: 1.4647 - val_categorical_accuracy: 0.7986 - val_fmeasure: 0.8002 - val_recall: 0.7952 - val_precision: 0.8053
# Epoch 8/50
# 2048/2048 [==============================] - 441s 215ms/step - loss: 0.0268 - categorical_accuracy: 0.9916 - fmeasure: 0.9916 - recall: 0.9913 - precision: 0.9919 - val_loss: 1.1891 - val_categorical_accuracy: 0.8265 - val_fmeasure: 0.8274 - val_recall: 0.8227 - val_precision: 0.8324
# Epoch 9/50
# 2048/2048 [==============================] - 441s 215ms/step - loss: 0.0229 - categorical_accuracy: 0.9930 - fmeasure: 0.9930 - recall: 0.9928 - precision: 0.9932 - val_loss: 1.4998 - val_categorical_accuracy: 0.8021 - val_fmeasure: 0.8037 - val_recall: 0.7999 - val_precision: 0.8075
# Epoch 10/50
# 2048/2048 [==============================] - 441s 215ms/step - loss: 0.0202 - categorical_accuracy: 0.9942 - fmeasure: 0.9942 - recall: 0.9940 - precision: 0.9945 - val_loss: 1.3242 - val_categorical_accuracy: 0.8113 - val_fmeasure: 0.8136 - val_recall: 0.8093 - val_precision: 0.8180
# Epoch 11/50
# 2048/2048 [==============================] - 441s 215ms/step - loss: 0.0170 - categorical_accuracy: 0.9947 - fmeasure: 0.9947 - recall: 0.9946 - precision: 0.9949 - val_loss: 1.6888 - val_categorical_accuracy: 0.7709 - val_fmeasure: 0.7710 - val_recall: 0.7679 - val_precision: 0.7743
# Epoch 12/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 0.0169 - categorical_accuracy: 0.9946 - fmeasure: 0.9947 - recall: 0.9945 - precision: 0.9949 - val_loss: 1.4459 - val_categorical_accuracy: 0.8201 - val_fmeasure: 0.8209 - val_recall: 0.8180 - val_precision: 0.8239
# Epoch 13/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 0.0109 - categorical_accuracy: 0.9963 - fmeasure: 0.9963 - recall: 0.9962 - precision: 0.9965 - val_loss: 1.5969 - val_categorical_accuracy: 0.8197 - val_fmeasure: 0.8204 - val_recall: 0.8184 - val_precision: 0.8224
# Epoch 14/50
# 2048/2048 [==============================] - 441s 215ms/step - loss: 0.0188 - categorical_accuracy: 0.9944 - fmeasure: 0.9944 - recall: 0.9943 - precision: 0.9946 - val_loss: 1.3752 - val_categorical_accuracy: 0.8234 - val_fmeasure: 0.8244 - val_recall: 0.8208 - val_precision: 0.8283
# Epoch 15/50
# 2048/2048 [==============================] - 444s 217ms/step - loss: 0.0111 - categorical_accuracy: 0.9964 - fmeasure: 0.9964 - recall: 0.9963 - precision: 0.9965 - val_loss: 1.5974 - val_categorical_accuracy: 0.8026 - val_fmeasure: 0.8042 - val_recall: 0.8009 - val_precision: 0.8077
# Epoch 16/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 0.0136 - categorical_accuracy: 0.9964 - fmeasure: 0.9963 - recall: 0.9962 - precision: 0.9964 - val_loss: 1.4256 - val_categorical_accuracy: 0.8154 - val_fmeasure: 0.8162 - val_recall: 0.8128 - val_precision: 0.8197
# Epoch 17/50
# 2048/2048 [==============================] - 441s 215ms/step - loss: 0.0133 - categorical_accuracy: 0.9960 - fmeasure: 0.9960 - recall: 0.9959 - precision: 0.9961 - val_loss: 1.4274 - val_categorical_accuracy: 0.7918 - val_fmeasure: 0.7946 - val_recall: 0.7887 - val_precision: 0.8008
# Epoch 18/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 0.0098 - categorical_accuracy: 0.9972 - fmeasure: 0.9972 - recall: 0.9972 - precision: 0.9973 - val_loss: 1.6432 - val_categorical_accuracy: 0.8016 - val_fmeasure: 0.8038 - val_recall: 0.8001 - val_precision: 0.8078
# Epoch 19/50
# 2048/2048 [==============================] - 441s 215ms/step - loss: 0.0096 - categorical_accuracy: 0.9973 - fmeasure: 0.9974 - recall: 0.9973 - precision: 0.9974 - val_loss: 1.5435 - val_categorical_accuracy: 0.8006 - val_fmeasure: 0.8020 - val_recall: 0.7978 - val_precision: 0.8063
# Epoch 20/50
# 2048/2048 [==============================] - 441s 215ms/step - loss: 0.0098 - categorical_accuracy: 0.9975 - fmeasure: 0.9975 - recall: 0.9974 - precision: 0.9976 - val_loss: 1.5121 - val_categorical_accuracy: 0.8120 - val_fmeasure: 0.8131 - val_recall: 0.8107 - val_precision: 0.8155
# Epoch 21/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 2.0722e-05 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.6306 - val_categorical_accuracy: 0.8112 - val_fmeasure: 0.8116 - val_recall: 0.8106 - val_precision: 0.8127
# Epoch 22/50
# 2048/2048 [==============================] - 441s 215ms/step - loss: 2.3491e-06 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.7292 - val_categorical_accuracy: 0.8124 - val_fmeasure: 0.8129 - val_recall: 0.8120 - val_precision: 0.8139
# Epoch 23/50
# 2048/2048 [==============================] - 443s 216ms/step - loss: 6.1776e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.7920 - val_categorical_accuracy: 0.8128 - val_fmeasure: 0.8130 - val_recall: 0.8122 - val_precision: 0.8139
# Epoch 24/50
# 2048/2048 [==============================] - 443s 216ms/step - loss: 2.7491e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.8502 - val_categorical_accuracy: 0.8139 - val_fmeasure: 0.8138 - val_recall: 0.8129 - val_precision: 0.8147
# Epoch 25/50
# 2048/2048 [==============================] - 441s 215ms/step - loss: 1.7482e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.8799 - val_categorical_accuracy: 0.8132 - val_fmeasure: 0.8133 - val_recall: 0.8125 - val_precision: 0.8141
# Epoch 26/50
# 2048/2048 [==============================] - 443s 216ms/step - loss: 1.4003e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.9184 - val_categorical_accuracy: 0.8137 - val_fmeasure: 0.8137 - val_recall: 0.8129 - val_precision: 0.8144
# Epoch 27/50
# 2048/2048 [==============================] - 443s 216ms/step - loss: 1.2669e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.9453 - val_categorical_accuracy: 0.8138 - val_fmeasure: 0.8140 - val_recall: 0.8133 - val_precision: 0.8147
# Epoch 28/50
# 2048/2048 [==============================] - 443s 216ms/step - loss: 1.2140e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.9786 - val_categorical_accuracy: 0.8124 - val_fmeasure: 0.8125 - val_recall: 0.8117 - val_precision: 0.8133
# Epoch 29/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 1.1970e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.9902 - val_categorical_accuracy: 0.8139 - val_fmeasure: 0.8137 - val_recall: 0.8130 - val_precision: 0.8144
# Epoch 30/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 1.1928e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0141 - val_categorical_accuracy: 0.8135 - val_fmeasure: 0.8132 - val_recall: 0.8125 - val_precision: 0.8140
# Epoch 31/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 1.1922e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0211 - val_categorical_accuracy: 0.8130 - val_fmeasure: 0.8127 - val_recall: 0.8120 - val_precision: 0.8135
# Epoch 32/50
# 2048/2048 [==============================] - 443s 216ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0178 - val_categorical_accuracy: 0.8130 - val_fmeasure: 0.8130 - val_recall: 0.8123 - val_precision: 0.8136
# Epoch 33/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0297 - val_categorical_accuracy: 0.8132 - val_fmeasure: 0.8130 - val_recall: 0.8124 - val_precision: 0.8136
# Epoch 34/50
# 2048/2048 [==============================] - 443s 216ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0160 - val_categorical_accuracy: 0.8138 - val_fmeasure: 0.8136 - val_recall: 0.8128 - val_precision: 0.8144
# Epoch 35/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0235 - val_categorical_accuracy: 0.8133 - val_fmeasure: 0.8131 - val_recall: 0.8123 - val_precision: 0.8139
# Epoch 36/50
# 2048/2048 [==============================] - 443s 216ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0232 - val_categorical_accuracy: 0.8136 - val_fmeasure: 0.8133 - val_recall: 0.8125 - val_precision: 0.8141
# Epoch 37/50
# 2048/2048 [==============================] - 443s 216ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0082 - val_categorical_accuracy: 0.8146 - val_fmeasure: 0.8143 - val_recall: 0.8136 - val_precision: 0.8151
# Epoch 38/50
# 2048/2048 [==============================] - 443s 216ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0161 - val_categorical_accuracy: 0.8143 - val_fmeasure: 0.8141 - val_recall: 0.8134 - val_precision: 0.8149
# Epoch 39/50
# 2048/2048 [==============================] - 445s 217ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0224 - val_categorical_accuracy: 0.8137 - val_fmeasure: 0.8134 - val_recall: 0.8127 - val_precision: 0.8142
# Epoch 40/50
# 2048/2048 [==============================] - 442s 216ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0161 - val_categorical_accuracy: 0.8142 - val_fmeasure: 0.8140 - val_recall: 0.8132 - val_precision: 0.8147
# Epoch 41/50
# 2048/2048 [==============================] - 441s 215ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0155 - val_categorical_accuracy: 0.8142 - val_fmeasure: 0.8139 - val_recall: 0.8132 - val_precision: 0.8147
# Epoch 42/50
# 2048/2048 [==============================] - 441s 215ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0145 - val_categorical_accuracy: 0.8143 - val_fmeasure: 0.8141 - val_recall: 0.8134 - val_precision: 0.8149
# Epoch 43/50
# 2048/2048 [==============================] - 450s 220ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0140 - val_categorical_accuracy: 0.8143 - val_fmeasure: 0.8141 - val_recall: 0.8134 - val_precision: 0.8148
# Epoch 44/50
# 2048/2048 [==============================] - 466s 227ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0226 - val_categorical_accuracy: 0.8138 - val_fmeasure: 0.8135 - val_recall: 0.8128 - val_precision: 0.8143
# Epoch 45/50
# 2048/2048 [==============================] - 509s 248ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0212 - val_categorical_accuracy: 0.8138 - val_fmeasure: 0.8136 - val_recall: 0.8128 - val_precision: 0.8143
# Epoch 46/50
# 2048/2048 [==============================] - 514s 251ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0219 - val_categorical_accuracy: 0.8134 - val_fmeasure: 0.8132 - val_recall: 0.8125 - val_precision: 0.8140
# Epoch 47/50
# 2048/2048 [==============================] - 475s 232ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0159 - val_categorical_accuracy: 0.8141 - val_fmeasure: 0.8139 - val_recall: 0.8131 - val_precision: 0.8146
# Epoch 48/50
# 2048/2048 [==============================] - 473s 231ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0204 - val_categorical_accuracy: 0.8139 - val_fmeasure: 0.8136 - val_recall: 0.8129 - val_precision: 0.8144
# Epoch 49/50
# 2048/2048 [==============================] - 473s 231ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0266 - val_categorical_accuracy: 0.8134 - val_fmeasure: 0.8131 - val_recall: 0.8124 - val_precision: 0.8139
# Epoch 50/50
# 2048/2048 [==============================] - 445s 217ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000 - fmeasure: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0157 - val_categorical_accuracy: 0.8140 - val_fmeasure: 0.8138 - val_recall: 0.8130 - val_precision: 0.8145

# %%
score = model.evaluate_generator(validation_generator, steps=50)

print ('Test Score: ', score[0])
print ('Test Accuracy: ',score[1])
print ('fmeasure: ', score[2])
print ('Recall: ', score[3])
print ('Precision: ', score[4])
# Out:
# Test Score:  2.242692073583603
# Test Accuracy:  0.804375
# fmeasure:  0.8049106538295746
# Recall:  0.804375
# Precision:  0.8054637086391448

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["categorical_accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_categorical_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")

# %%
from keras.preprocessing.image import ImageDataGenerator

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True)


# target_size = (height, width)
target_size = (224, 224)


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size = target_size,       
        class_mode = 'categorical',
        shuffle = False)

validation_generator = train_datagen.flow_from_directory(
        validation_dir,
        target_size = target_size,        
        class_mode = 'categorical',
        shuffle = False)
# Out:
# Found 27827 images belonging to 7 classes.
# Found 11233 images belonging to 7 classes.

# %%
filename = validation_generator.filenames
truth = validation_generator.classes
label = validation_generator.class_indices
indexlabel = dict((value, key) for key, value in label.items())

predicts = model.predict_generator(validation_generator, steps=validation_generator.samples/validation_generator.batch_size, verbose=1)
predict_class = np.argmax(predicts, axis=1)
errors = np.where(predict_class != truth)[0]
print("No of errors = {}/{}".format(len(errors),validation_generator.samples))
# Out:
# 352/351 [==============================] - 49s 140ms/step
# No of errors = 2092/11233

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(truth,predict_class)

labels = []
for k,v in indexlabel.items():
    labels.append(v)
    
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion Matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.savefig('plots/2.AlexNet-CM.png', bbox_inches='tight', dpi = 100)

plt.figure(figsize=(10,10))


plot_confusion_matrix(cm, classes=labels,
                      title='Confusion Matrix')
# Out:
# Confusion Matrix
# [[1164   81  178   14   80   35    0]
#  [  22 1491   68    3   42   39   27]
#  [  25   20 1300    1   54   79    0]
#  [  53  125   94 1236   31   86    7]
#  [   6   12   80    0 1431  133    2]
#  [   6   14   91   10  120 1484    5]
#  [   0   23   50    1   42  333 1035]]

# %%
#ROC Curve for each class
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
import matplotlib.pyplot as plt
# %matplotlib inline  
from scipy import interp
from itertools import cycle




y_pred = predicts
y_pred_probabilities=y_pred

y_pred = np.argmax(y_pred,axis = 1) 
y_actual = validation_generator.classes

classnames=[]
for classname in validation_generator.class_indices:
    classnames.append(classname)

y_actual_binary = label_binarize(y_actual, classes=[0, 1, 2, 3, 4,5,6])
y_pred_binary = y_pred_probabilities#label_binarize(y_pred_probabilities, classes=[0, 1, 2, 3, 4])
n_classes=7
lw=2

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_actual_binary[:, i], y_pred_binary[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_actual_binary.ravel(), y_pred_binary.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(figsize=(7, 7))


colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="best")
plt.show()

# %%
# Zoom in view of the upper left corner.
fig = plt.figure()
fig.patch.set_facecolor('white')

plt.xlim(0, 0.2)
plt.ylim(0.8, 1)

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=6)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=6)


colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

    
    
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-classs')
plt.legend(loc="lower right")
# plt.axis('off')

legend = plt.legend(frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('white')


plt.rcParams['figure.facecolor'] = 'white'
fig = plt.figure()
fig.patch.set_facecolor('white')
plt.savefig('plots/2.AlexNet-ROC.png', dpi = 100)
plt.show()

# %%
# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=6)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=6)


colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

    
    
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-classs')
plt.legend(loc="lower right")


legend = plt.legend(frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('white')




plt.rcParams['axes.facecolor'] = 'white'


plt.savefig('plots/2.AlexNet-ROC.png', dpi = 100)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report

confusion_mtx = confusion_matrix(y_actual, y_pred) 
print(confusion_mtx)
target_names = classnames
print(classification_report(y_actual, y_pred, target_names=target_names))
# Out:
# [[1164   81  178   14   80   35    0]
#  [  22 1491   68    3   42   39   27]
#  [  25   20 1300    1   54   79    0]
#  [  53  125   94 1236   31   86    7]
#  [   6   12   80    0 1431  133    2]
#  [   6   14   91   10  120 1484    5]
#  [   0   23   50    1   42  333 1035]]
#              precision    recall  f1-score   support
#
#       AKIEC       0.91      0.75      0.82      1552
#         BCC       0.84      0.88      0.86      1692
#         BKL       0.70      0.88      0.78      1479
#          DF       0.98      0.76      0.85      1632
#         MEL       0.80      0.86      0.83      1664
#          NV       0.68      0.86      0.76      1730
#        VASC       0.96      0.70      0.81      1484
#
# avg / total       0.84      0.81      0.82     11233

# %%
model.save('models/2.AlexNet-Aug-Adam-Dropout-Model.h5')
model.save_weights('models/2.AlexNet-Aug-Adam-Dropout-Weights.h5')
