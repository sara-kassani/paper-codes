# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
print(tf.test.gpu_device_name())
# See https://www.tensorflow.org/tutorials/using_gpu#allowing_gpu_memory_growth
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
# Out:
# /device:GPU:0

# %%
import os
import pandas as pd

import numpy as np
from glob import glob
import cv2
import skimage
from skimage.transform import resize

from keras import layers
from keras import models
from keras import optimizers
from keras.models import load_model
import keras.callbacks as kcall
from keras.optimizers import Adam
from keras.models import Model
from keras.models import Sequential
from keras.layers import Flatten, Dense, Activation, Dropout, Conv2D, MaxPooling2D, BatchNormalization
from keras.applications.xception import Xception, preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
train_dir = 'data-without-aug/train'
validation_dir = 'data-without-aug/validation'

# %%
for root,dirs,files in os.walk(train_dir):
    print (root, len(files))
# Out:
# data-without-aug/train 0
# data-without-aug/train\AKIEC 253
# data-without-aug/train\BCC 247
# data-without-aug/train\BKL 815
# data-without-aug/train\DF 85
# data-without-aug/train\MEL 801
# data-without-aug/train\NV 4975
# data-without-aug/train\VASC 109

# %%
for root,dirs,files in os.walk(validation_dir):
    print (root, len(files))
# Out:
# data-without-aug/validation 0
# data-without-aug/validation\AKIEC 74
# data-without-aug/validation\BCC 139
# data-without-aug/validation\BKL 284
# data-without-aug/validation\DF 30
# data-without-aug/validation\MEL 312
# data-without-aug/validation\NV 1730
# data-without-aug/validation\VASC 33

# %%
from keras.preprocessing.image import ImageDataGenerator

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True)


# target_size = (height, width)
target_size = (225, 300)


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size = target_size,       
        class_mode = 'categorical',
        shuffle = False)

validation_generator = train_datagen.flow_from_directory(
        validation_dir,
        target_size = target_size,        
        class_mode = 'categorical',
        shuffle = False)
# Out:
# Found 7285 images belonging to 7 classes.
# Found 2602 images belonging to 7 classes.

# %%
plt.hist(train_generator.classes, bins='auto') 
plt.title("Histogram of training dataset")
plt.show()

# %%
plt.hist(validation_generator.classes, bins='auto') 
plt.title("Histogram of training dataset")
plt.show()

# %%
import keras.backend as K

def precision(y_true, y_pred):
    # Calculates the precision
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision


def recall(y_true, y_pred):
    # Calculates the recall
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def fbeta_score(y_true, y_pred, beta=1):
    # Calculates the F score, the weighted harmonic mean of precision and recall.

    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
        
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score

def fmeasure(y_true, y_pred):
    # Calculates the f-measure, the harmonic mean of precision and recall.
    return fbeta_score(y_true, y_pred, beta=1)

# %%
## Intilizing variables
output_classes = 7

batch_size = 32 
epochs = 50
droput_rate= 0.5

adam_opt = Adam(lr=1e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=1e-5)
vgg16_weights= 'pretrained-models/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5'

# %%
from keras.applications.vgg16 import VGG16
from keras.layers import Flatten, Dense, Dropout, BatchNormalization
from keras.regularizers import l2

model = (VGG16(include_top=False, pooling='avg', weights=vgg16_weights))
x = model.output
# x = Flatten()(x)
x = Dense(1024, activation="relu", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation="relu", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
predictions = Dense(7, activation="softmax", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
model = Model(input = model.input, output = predictions)


model.compile(loss='categorical_crossentropy',
              optimizer= adam_opt,
              metrics = ["categorical_accuracy", fmeasure, recall, precision])

# %%
history = model.fit_generator(train_generator,
    steps_per_epoch=2048,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps=1024)
# Out:
# Epoch 1/50
# 2048/2048 [==============================] - 894s 436ms/step - loss: 2.5045 - categorical_accuracy: 0.2947 - fmeasure: 0.0489 - recall: 0.0337 - precision: 0.1149 - val_loss: 2.9509 - val_categorical_accuracy: 0.0792 - val_fmeasure: 7.7566e-04 - val_recall: 3.9995e-04 - val_precision: 0.0128
# Epoch 2/50
# 2048/2048 [==============================] - 887s 433ms/step - loss: 1.7104 - categorical_accuracy: 0.6566 - fmeasure: 0.0020 - recall: 0.0010 - precision: 0.0320 - val_loss: 2.0525 - val_categorical_accuracy: 0.6781 - val_fmeasure: 0.6781 - val_recall: 0.6781 - val_precision: 0.6781
# Epoch 3/50
# 2048/2048 [==============================] - 887s 433ms/step - loss: 1.4792 - categorical_accuracy: 0.6788 - fmeasure: 0.0393 - recall: 0.0216 - precision: 0.3294 - val_loss: 3.3489 - val_categorical_accuracy: 0.0556 - val_fmeasure: 0.0556 - val_recall: 0.0556 - val_precision: 0.0556
# Epoch 4/50
# 2048/2048 [==============================] - 888s 433ms/step - loss: 1.3239 - categorical_accuracy: 0.6810 - fmeasure: 0.5607 - recall: 0.5102 - precision: 0.6814 - val_loss: 2.7198 - val_categorical_accuracy: 0.1152 - val_fmeasure: 0.0626 - val_recall: 0.0443 - val_precision: 0.1112
# Epoch 5/50
# 2048/2048 [==============================] - 886s 433ms/step - loss: 1.2676 - categorical_accuracy: 0.6809 - fmeasure: 0.6765 - recall: 0.6721 - precision: 0.6812 - val_loss: 3.9805 - val_categorical_accuracy: 0.1137 - val_fmeasure: 0.1137 - val_recall: 0.1137 - val_precision: 0.1137
# Epoch 6/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.2456 - categorical_accuracy: 0.6811 - fmeasure: 0.6802 - recall: 0.6791 - precision: 0.6813 - val_loss: 14.4408 - val_categorical_accuracy: 0.0513 - val_fmeasure: 0.0513 - val_recall: 0.0513 - val_precision: 0.0513
# Epoch 7/50
# 2048/2048 [==============================] - 886s 432ms/step - loss: 1.2330 - categorical_accuracy: 0.6811 - fmeasure: 0.6803 - recall: 0.6793 - precision: 0.6812 - val_loss: 12.7411 - val_categorical_accuracy: 0.0556 - val_fmeasure: 0.0556 - val_recall: 0.0556 - val_precision: 0.0556
# Epoch 8/50
# 2048/2048 [==============================] - 886s 433ms/step - loss: 1.2227 - categorical_accuracy: 0.6812 - fmeasure: 0.6807 - recall: 0.6802 - precision: 0.6812 - val_loss: 1.7152 - val_categorical_accuracy: 0.6781 - val_fmeasure: 0.6781 - val_recall: 0.6781 - val_precision: 0.6781
# Epoch 9/50
# 2048/2048 [==============================] - 888s 434ms/step - loss: 1.2150 - categorical_accuracy: 0.6812 - fmeasure: 0.6810 - recall: 0.6807 - precision: 0.6812 - val_loss: 5.9847 - val_categorical_accuracy: 0.0556 - val_fmeasure: 0.0556 - val_recall: 0.0556 - val_precision: 0.0556
# Epoch 10/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.2077 - categorical_accuracy: 0.6812 - fmeasure: 0.6811 - recall: 0.6809 - precision: 0.6813 - val_loss: 1.7312 - val_categorical_accuracy: 0.6781 - val_fmeasure: 0.6781 - val_recall: 0.6781 - val_precision: 0.6781
# Epoch 11/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.2029 - categorical_accuracy: 0.6812 - fmeasure: 0.6809 - recall: 0.6807 - precision: 0.6812 - val_loss: 5.1932 - val_categorical_accuracy: 0.0917 - val_fmeasure: 0.0877 - val_recall: 0.0796 - val_precision: 0.0980
# Epoch 12/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.1971 - categorical_accuracy: 0.6813 - fmeasure: 0.6812 - recall: 0.6810 - precision: 0.6813 - val_loss: 2.1888 - val_categorical_accuracy: 0.0513 - val_fmeasure: 0.0513 - val_recall: 0.0513 - val_precision: 0.0513
# Epoch 13/50
# 2048/2048 [==============================] - 882s 431ms/step - loss: 1.1922 - categorical_accuracy: 0.6812 - fmeasure: 0.6812 - recall: 0.6812 - precision: 0.6812 - val_loss: 3.1655 - val_categorical_accuracy: 0.0552 - val_fmeasure: 0.0550 - val_recall: 0.0544 - val_precision: 0.0556
# Epoch 14/50
# 2048/2048 [==============================] - 882s 431ms/step - loss: 1.1876 - categorical_accuracy: 0.6813 - fmeasure: 0.6812 - recall: 0.6811 - precision: 0.6813 - val_loss: 5.2675 - val_categorical_accuracy: 0.6781 - val_fmeasure: 0.6781 - val_recall: 0.6781 - val_precision: 0.6781
# Epoch 15/50
# 2048/2048 [==============================] - 884s 431ms/step - loss: 1.1837 - categorical_accuracy: 0.6813 - fmeasure: 0.6812 - recall: 0.6812 - precision: 0.6813 - val_loss: 1.3728 - val_categorical_accuracy: 0.6512 - val_fmeasure: 0.6512 - val_recall: 0.6512 - val_precision: 0.6512
# Epoch 16/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.1791 - categorical_accuracy: 0.6813 - fmeasure: 0.6812 - recall: 0.6811 - precision: 0.6813 - val_loss: 7.7413 - val_categorical_accuracy: 0.0111 - val_fmeasure: 0.0111 - val_recall: 0.0111 - val_precision: 0.0111
# Epoch 17/50
# 2048/2048 [==============================] - 884s 432ms/step - loss: 1.1756 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6812 - precision: 0.6813 - val_loss: 4.6363 - val_categorical_accuracy: 0.0296 - val_fmeasure: 0.0296 - val_recall: 0.0296 - val_precision: 0.0296
# Epoch 18/50
# 2048/2048 [==============================] - 883s 431ms/step - loss: 1.1719 - categorical_accuracy: 0.6812 - fmeasure: 0.6812 - recall: 0.6812 - precision: 0.6813 - val_loss: 2.0502 - val_categorical_accuracy: 0.0273 - val_fmeasure: 0.0000e+00 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 19/50
# 2048/2048 [==============================] - 883s 431ms/step - loss: 1.1680 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6812 - precision: 0.6813 - val_loss: 1.3283 - val_categorical_accuracy: 0.6552 - val_fmeasure: 0.6552 - val_recall: 0.6552 - val_precision: 0.6552
# Epoch 20/50
# 2048/2048 [==============================] - 883s 431ms/step - loss: 1.1653 - categorical_accuracy: 0.6813 - fmeasure: 0.6812 - recall: 0.6812 - precision: 0.6813 - val_loss: 3.7900 - val_categorical_accuracy: 0.0513 - val_fmeasure: 0.0027 - val_recall: 0.0015 - val_precision: 0.0177
# Epoch 21/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.1623 - categorical_accuracy: 0.6812 - fmeasure: 0.6812 - recall: 0.6812 - precision: 0.6812 - val_loss: 2.1619 - val_categorical_accuracy: 0.1137 - val_fmeasure: 0.1113 - val_recall: 0.1097 - val_precision: 0.1130
# Epoch 22/50
# 2048/2048 [==============================] - 886s 432ms/step - loss: 1.1596 - categorical_accuracy: 0.6813 - fmeasure: 0.6812 - recall: 0.6812 - precision: 0.6813 - val_loss: 2.1193 - val_categorical_accuracy: 0.6719 - val_fmeasure: 0.6719 - val_recall: 0.6719 - val_precision: 0.6719
# Epoch 23/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.1572 - categorical_accuracy: 0.6813 - fmeasure: 0.6812 - recall: 0.6812 - precision: 0.6813 - val_loss: 12.6622 - val_categorical_accuracy: 0.0556 - val_fmeasure: 0.0556 - val_recall: 0.0556 - val_precision: 0.0556
# Epoch 24/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.1550 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6812 - precision: 0.6813 - val_loss: 2.8384 - val_categorical_accuracy: 0.6700 - val_fmeasure: 0.6700 - val_recall: 0.6700 - val_precision: 0.6700
# Epoch 25/50
# 2048/2048 [==============================] - 884s 432ms/step - loss: 1.1524 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6812 - precision: 0.6813 - val_loss: 1.8429 - val_categorical_accuracy: 0.6611 - val_fmeasure: 0.6611 - val_recall: 0.6611 - val_precision: 0.6611
# Epoch 26/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.1508 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6813 - precision: 0.6813 - val_loss: 1.1802 - val_categorical_accuracy: 0.6680 - val_fmeasure: 0.6680 - val_recall: 0.6680 - val_precision: 0.6680
# Epoch 27/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.1490 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6812 - precision: 0.6813 - val_loss: 1.5995 - val_categorical_accuracy: 0.6630 - val_fmeasure: 0.6625 - val_recall: 0.6619 - val_precision: 0.6630
# Epoch 28/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.1468 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6813 - precision: 0.6813 - val_loss: 2.5375 - val_categorical_accuracy: 0.6660 - val_fmeasure: 0.6660 - val_recall: 0.6660 - val_precision: 0.6660
# Epoch 29/50
# 2048/2048 [==============================] - 884s 431ms/step - loss: 1.1449 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6812 - precision: 0.6813 - val_loss: 1.9989 - val_categorical_accuracy: 0.1153 - val_fmeasure: 0.1153 - val_recall: 0.1153 - val_precision: 0.1153
# Epoch 30/50
# 2048/2048 [==============================] - 886s 433ms/step - loss: 1.1436 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6812 - precision: 0.6813 - val_loss: 3.1839 - val_categorical_accuracy: 0.6641 - val_fmeasure: 0.6641 - val_recall: 0.6641 - val_precision: 0.6641
# Epoch 31/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.1421 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6812 - precision: 0.6813 - val_loss: 1.9028 - val_categorical_accuracy: 0.6670 - val_fmeasure: 0.6670 - val_recall: 0.6670 - val_precision: 0.6670
# Epoch 32/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.1408 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6812 - precision: 0.6813 - val_loss: 1.2289 - val_categorical_accuracy: 0.6621 - val_fmeasure: 0.6621 - val_recall: 0.6621 - val_precision: 0.6621
# Epoch 33/50
# 2048/2048 [==============================] - 879s 429ms/step - loss: 1.1391 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6813 - precision: 0.6813 - val_loss: 3.5374 - val_categorical_accuracy: 0.0296 - val_fmeasure: 0.0296 - val_recall: 0.0296 - val_precision: 0.0296
# Epoch 34/50
# 2048/2048 [==============================] - 878s 429ms/step - loss: 1.1380 - categorical_accuracy: 0.6812 - fmeasure: 0.6812 - recall: 0.6812 - precision: 0.6813 - val_loss: 2.5798 - val_categorical_accuracy: 0.1248 - val_fmeasure: 0.1248 - val_recall: 0.1248 - val_precision: 0.1248
# Epoch 35/50
# 2048/2048 [==============================] - 877s 428ms/step - loss: 1.1369 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6813 - precision: 0.6813 - val_loss: 3.6704 - val_categorical_accuracy: 0.0550 - val_fmeasure: 0.0550 - val_recall: 0.0550 - val_precision: 0.0550
# Epoch 36/50
# 2048/2048 [==============================] - 874s 427ms/step - loss: 1.1355 - categorical_accuracy: 0.6813 - fmeasure: 0.6813 - recall: 0.6813 - precision: 0.6813 - val_loss: 1.8340 - val_categorical_accuracy: 0.6582 - val_fmeasure: 0.6582 - val_recall: 0.6582 - val_precision: 0.6582
# Epoch 37/50
# 2048/2048 [==============================] - 880s 429ms/step - loss: 1.1338 - categorical_accuracy: 0.6813 - fmeasure: 0.6812 - recall: 0.6812 - precision: 0.6813 - val_loss: 2.5546 - val_categorical_accuracy: 0.6729 - val_fmeasure: 0.6729 - val_recall: 0.6729 - val_precision: 0.6729
# Epoch 38/50
# 2048/2048 [==============================] - 883s 431ms/step - loss: 1.1312 - categorical_accuracy: 0.6813 - fmeasure: 0.6812 - recall: 0.6812 - precision: 0.6813 - val_loss: 3.0043 - val_categorical_accuracy: 0.6562 - val_fmeasure: 0.6562 - val_recall: 0.6562 - val_precision: 0.6562
# Epoch 39/50
# 2048/2048 [==============================] - 884s 431ms/step - loss: 1.1270 - categorical_accuracy: 0.6813 - fmeasure: 0.6812 - recall: 0.6812 - precision: 0.6813 - val_loss: 1.3796 - val_categorical_accuracy: 0.6749 - val_fmeasure: 0.6749 - val_recall: 0.6749 - val_precision: 0.6749
# Epoch 40/50
# 2048/2048 [==============================] - 884s 432ms/step - loss: 1.1206 - categorical_accuracy: 0.6821 - fmeasure: 0.6817 - recall: 0.6816 - precision: 0.6819 - val_loss: 15.9155 - val_categorical_accuracy: 0.0120 - val_fmeasure: 0.0120 - val_recall: 0.0120 - val_precision: 0.0120
# Epoch 41/50
# 2048/2048 [==============================] - 882s 431ms/step - loss: 1.1103 - categorical_accuracy: 0.6853 - fmeasure: 0.6842 - recall: 0.6839 - precision: 0.6849 - val_loss: 15.9623 - val_categorical_accuracy: 0.0115 - val_fmeasure: 0.0115 - val_recall: 0.0115 - val_precision: 0.0115
# Epoch 42/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.1062 - categorical_accuracy: 0.6875 - fmeasure: 0.6862 - recall: 0.6855 - precision: 0.6879 - val_loss: 10.6848 - val_categorical_accuracy: 0.0296 - val_fmeasure: 0.0296 - val_recall: 0.0296 - val_precision: 0.0296
# Epoch 43/50
# 2048/2048 [==============================] - 884s 432ms/step - loss: 1.1033 - categorical_accuracy: 0.6881 - fmeasure: 0.6875 - recall: 0.6867 - precision: 0.6888 - val_loss: 2.5420 - val_categorical_accuracy: 0.6781 - val_fmeasure: 0.6781 - val_recall: 0.6781 - val_precision: 0.6781
# Epoch 44/50
# 2048/2048 [==============================] - 884s 432ms/step - loss: 1.1012 - categorical_accuracy: 0.6891 - fmeasure: 0.6885 - recall: 0.6876 - precision: 0.6901 - val_loss: 2.0420 - val_categorical_accuracy: 0.6510 - val_fmeasure: 0.6510 - val_recall: 0.6510 - val_precision: 0.6510
# Epoch 45/50
# 2048/2048 [==============================] - 883s 431ms/step - loss: 1.0991 - categorical_accuracy: 0.6892 - fmeasure: 0.6887 - recall: 0.6879 - precision: 0.6901 - val_loss: 2.7899 - val_categorical_accuracy: 0.6781 - val_fmeasure: 0.6781 - val_recall: 0.6781 - val_precision: 0.6781
# Epoch 46/50
# 2048/2048 [==============================] - 885s 432ms/step - loss: 1.0974 - categorical_accuracy: 0.6897 - fmeasure: 0.6893 - recall: 0.6886 - precision: 0.6904 - val_loss: 2.9480 - val_categorical_accuracy: 0.6510 - val_fmeasure: 0.6510 - val_recall: 0.6510 - val_precision: 0.6510
# Epoch 47/50
# 2048/2048 [==============================] - 883s 431ms/step - loss: 1.0963 - categorical_accuracy: 0.6895 - fmeasure: 0.6892 - recall: 0.6885 - precision: 0.6902 - val_loss: 15.9666 - val_categorical_accuracy: 0.0111 - val_fmeasure: 0.0111 - val_recall: 0.0111 - val_precision: 0.0111
# Epoch 48/50
# 2048/2048 [==============================] - 881s 430ms/step - loss: 1.0940 - categorical_accuracy: 0.6904 - fmeasure: 0.6902 - recall: 0.6895 - precision: 0.6912 - val_loss: 3.7867 - val_categorical_accuracy: 0.6510 - val_fmeasure: 0.6510 - val_recall: 0.6510 - val_precision: 0.6510
# Epoch 49/50
# 2048/2048 [==============================] - 884s 432ms/step - loss: 1.0934 - categorical_accuracy: 0.6906 - fmeasure: 0.6903 - recall: 0.6897 - precision: 0.6912 - val_loss: 2.7878 - val_categorical_accuracy: 0.6781 - val_fmeasure: 0.6781 - val_recall: 0.6781 - val_precision: 0.6781
# Epoch 50/50
# 2048/2048 [==============================] - 879s 429ms/step - loss: 1.0914 - categorical_accuracy: 0.6907 - fmeasure: 0.6904 - recall: 0.6898 - precision: 0.6912 - val_loss: 3.2545 - val_categorical_accuracy: 0.1137 - val_fmeasure: 0.1137 - val_recall: 0.1137 - val_precision: 0.1137

# %%
score = model.evaluate_generator(validation_generator, steps=50)

print ('Test Score: ', score[0])
print ('Test Accuracy: ',score[1])
print ('fmeasure: ', score[2])
print ('Recall: ', score[3])
print ('Precision: ', score[4])
# Out:
# Test Score:  1.6152464101523047
# Test Accuracy:  0.0
# fmeasure:  0.0
# Recall:  0.0
# Precision:  0.0

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["categorical_accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_categorical_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()

# %%
filename = validation_generator.filenames
truth = validation_generator.classes
label = validation_generator.class_indices
indexlabel = dict((value, key) for key, value in label.items())

predicts = model.predict_generator(validation_generator, steps=validation_generator.samples/validation_generator.batch_size, verbose=1)
predict_class = np.argmax(predicts, axis=1)
errors = np.where(predict_class != truth)[0]
print("No of errors = {}/{}".format(len(errors),validation_generator.samples))
# Out:
# 82/81 [==============================] - 15s 184ms/step
# No of errors = 2318/2602

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(truth,predict_class)

labels = []
for k,v in indexlabel.items():
    labels.append(v)
    
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion Matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))    

plt.figure(figsize=(10,10))


plot_confusion_matrix(cm, classes=labels,
                      title='Confusion Matrix')
# Out:
# Confusion Matrix
# [[   0    0   74    0    0    0    0]
#  [   0    0  139    0    0    0    0]
#  [   0    0  284    0    0    0    0]
#  [   0    0   30    0    0    0    0]
#  [   0    0  312    0    0    0    0]
#  [   0    0 1730    0    0    0    0]
#  [   0    0   33    0    0    0    0]]

# %%
#ROC Curve for each class
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
import matplotlib.pyplot as plt
# %matplotlib inline  
from scipy import interp
from itertools import cycle


y_pred = predicts
y_pred_probabilities=y_pred

y_pred = np.argmax(y_pred,axis = 1) 
y_actual = validation_generator.classes

classnames=[]
for classname in validation_generator.class_indices:
    classnames.append(classname)

y_actual_binary = label_binarize(y_actual, classes=[0, 1, 2, 3, 4, 5, 6])
y_pred_binary = y_pred_probabilities#label_binarize(y_pred_probabilities, classes=[0, 1, 2, 3, 4])
n_classes=7
lw=2

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_actual_binary[:, i], y_pred_binary[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_actual_binary.ravel(), y_pred_binary.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(figsize=(7, 7))


colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="best")
plt.show()

# %%
# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=6)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=6)


colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

    
    
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-classs')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report

confusion_mtx = confusion_matrix(y_actual, y_pred) 
print(confusion_mtx)
target_names = classnames
print(classification_report(y_actual, y_pred, target_names=target_names))
# Out:
# [[   0    0   74    0    0    0    0]
#  [   0    0  139    0    0    0    0]
#  [   0    0  284    0    0    0    0]
#  [   0    0   30    0    0    0    0]
#  [   0    0  312    0    0    0    0]
#  [   0    0 1730    0    0    0    0]
#  [   0    0   33    0    0    0    0]]
#               precision    recall  f1-score   support
#
#          BCC       0.00      0.00      0.00        74
#          MEL       0.00      0.00      0.00       139
#           DF       0.11      1.00      0.20       284
#        AKIEC       0.00      0.00      0.00        30
#         VASC       0.00      0.00      0.00       312
#           NV       0.00      0.00      0.00      1730
#          BKL       0.00      0.00      0.00        33
#
#    micro avg       0.11      0.11      0.11      2602
#    macro avg       0.02      0.14      0.03      2602
# weighted avg       0.01      0.11      0.02      2602

# %%
model.save('models/5.VGG16-Skin-Classification-without-Aug-Model.h5')
model.save_weights('models/5.VGG16-Skin-Classification-without-Aug-Weights.h5')

# %% [markdown]
# ___

# %%
from keras.models import load_model
model = load_model("models/5.VGG16-Skin-Classification-without-Aug-Model.h5", custom_objects={'fmeasure': fmeasure,  'recall': recall, 'precision': precision })
model.load_weights("models/5.VGG16-Skin-Classification-without-Aug-Weights.h5")
