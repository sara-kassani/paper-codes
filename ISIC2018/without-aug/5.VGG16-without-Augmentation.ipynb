# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
import keras
import os
os.environ["CUDA_VISIBLE_DEVICES"]="4,5,6"

config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
keras.backend.set_session(sess)

def _get_available_devices():
    from tensorflow.python.client import device_lib
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]

print( _get_available_devices())
# Out:
# Using TensorFlow backend.
# ['/device:CPU:0', '/device:GPU:0', '/device:GPU:1', '/device:GPU:2']

# %%
import os
import pandas as pd

import numpy as np
from glob import glob

from keras import layers
from keras import models
from keras import optimizers
from keras.models import load_model
import keras.callbacks as kcall
from keras.optimizers import Adam
from keras.models import Model
from keras.models import Sequential
from keras.layers import Flatten, Dense, Activation, Dropout, Conv2D, MaxPooling2D, BatchNormalization
from keras.applications.xception import Xception, preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
train_dir = 'data-without-aug/train'
validation_dir = 'data-without-aug/validation'

# %%
for root,dirs,files in os.walk(train_dir):
    print (root, len(files))
# Out:
# data-without-aug/train 0
# data-without-aug/train/DF 85
# data-without-aug/train/VASC 109
# data-without-aug/train/MEL 801
# data-without-aug/train/AKIEC 253
# data-without-aug/train/BKL 815
# data-without-aug/train/BCC 247
# data-without-aug/train/NV 4975

# %%
for root,dirs,files in os.walk(validation_dir):
    print (root, len(files))
# Out:
# data-without-aug/validation 0
# data-without-aug/validation/DF 30
# data-without-aug/validation/VASC 33
# data-without-aug/validation/MEL 312
# data-without-aug/validation/AKIEC 74
# data-without-aug/validation/BKL 284
# data-without-aug/validation/BCC 139
# data-without-aug/validation/NV 1730

# %%
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True)


# target_size = (height, width)
target_size = (225, 300)


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size = target_size,       
        class_mode = 'categorical',
        shuffle = True)

validation_generator = train_datagen.flow_from_directory(
        validation_dir,
        target_size = target_size,        
        class_mode = 'categorical',
        shuffle = True)
# Out:
# Found 7285 images belonging to 7 classes.
# Found 2602 images belonging to 7 classes.

# %%
import keras.backend as K

def precision(y_true, y_pred):
    # Calculates the precision
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision


def recall(y_true, y_pred):
    # Calculates the recall
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def fbeta_score(y_true, y_pred, beta=1):
    # Calculates the F score, the weighted harmonic mean of precision and recall.

    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
        
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score

def fmeasure(y_true, y_pred):
    # Calculates the f-measure, the harmonic mean of precision and recall.
    return fbeta_score(y_true, y_pred, beta=1)

# %%
output_classes = 7

batch_size = 32 
epochs = 50
droput_rate= 0.5

adam_opt = Adam(lr=1e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=1e-5)
vgg16_weights= 'pretrained-models/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5'

# %%
from keras.applications.vgg16 import VGG16
from keras.layers import Flatten, Dense, Dropout, BatchNormalization
from keras.regularizers import l2

model = (VGG16(include_top=False, pooling='avg', weights="imagenet"))
x = model.output
# x = Flatten()(x)
x = Dense(1024, activation="relu", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation="relu", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

predictions = Dense(7, activation="softmax", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
model = Model(input = model.input, output = predictions)


model.compile(loss='categorical_crossentropy',
              optimizer= adam_opt,
              metrics = ["categorical_accuracy", fmeasure, recall, precision])
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58728448/58889256 [============================>.] - ETA: 0s

# %%
history = model.fit_generator(train_generator,
    steps_per_epoch=2048,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps=1024)
# Out:
# Epoch 1/50
# 2048/2048 [==============================] - 1985s - loss: 1.8868 - categorical_accuracy: 0.5811 - fmeasure: 0.5603 - recall: 0.4931 - precision: 0.6585 - val_loss: 1.1062 - val_categorical_accuracy: 0.7288 - val_fmeasure: 0.7306 - val_recall: 0.6634 - val_precision: 0.8163
# Epoch 2/50
# 2048/2048 [==============================] - 1756s - loss: 1.2037 - categorical_accuracy: 0.7313 - fmeasure: 0.7277 - recall: 0.6811 - precision: 0.7841 - val_loss: 0.9432 - val_categorical_accuracy: 0.7892 - val_fmeasure: 0.7896 - val_recall: 0.7546 - val_precision: 0.8294
# Epoch 3/50
# 2048/2048 [==============================] - 1543s - loss: 0.7148 - categorical_accuracy: 0.8370 - fmeasure: 0.8379 - recall: 0.8116 - precision: 0.8672 - val_loss: 0.8168 - val_categorical_accuracy: 0.8201 - val_fmeasure: 0.8173 - val_recall: 0.7946 - val_precision: 0.8422
# Epoch 4/50
# 2048/2048 [==============================] - 1620s - loss: 0.4139 - categorical_accuracy: 0.9127 - fmeasure: 0.9144 - recall: 0.9007 - precision: 0.9292 - val_loss: 0.9066 - val_categorical_accuracy: 0.8298 - val_fmeasure: 0.8296 - val_recall: 0.8158 - val_precision: 0.8442
# Epoch 5/50
# 2048/2048 [==============================] - 1576s - loss: 0.2654 - categorical_accuracy: 0.9535 - fmeasure: 0.9539 - recall: 0.9471 - precision: 0.9612 - val_loss: 1.1173 - val_categorical_accuracy: 0.8213 - val_fmeasure: 0.8217 - val_recall: 0.8110 - val_precision: 0.8330
# Epoch 6/50
# 2048/2048 [==============================] - 1563s - loss: 0.2021 - categorical_accuracy: 0.9726 - fmeasure: 0.9727 - recall: 0.9692 - precision: 0.9762 - val_loss: 0.9278 - val_categorical_accuracy: 0.8271 - val_fmeasure: 0.8295 - val_recall: 0.8241 - val_precision: 0.8351
# Epoch 7/50
# 2048/2048 [==============================] - 1627s - loss: 0.1663 - categorical_accuracy: 0.9809 - fmeasure: 0.9810 - recall: 0.9788 - precision: 0.9832 - val_loss: 1.4378 - val_categorical_accuracy: 0.7930 - val_fmeasure: 0.7943 - val_recall: 0.7915 - val_precision: 0.7973
# Epoch 8/50
# 2048/2048 [==============================] - 1598s - loss: 0.1372 - categorical_accuracy: 0.9877 - fmeasure: 0.9877 - recall: 0.9865 - precision: 0.9890 - val_loss: 1.6517 - val_categorical_accuracy: 0.7939 - val_fmeasure: 0.7943 - val_recall: 0.7916 - val_precision: 0.7971
# Epoch 9/50
# 2048/2048 [==============================] - 1597s - loss: 0.1224 - categorical_accuracy: 0.9898 - fmeasure: 0.9899 - recall: 0.9890 - precision: 0.9908 - val_loss: 1.3437 - val_categorical_accuracy: 0.8134 - val_fmeasure: 0.8136 - val_recall: 0.8091 - val_precision: 0.8184
# Epoch 10/50
# 2048/2048 [==============================] - 1568s - loss: 0.1161 - categorical_accuracy: 0.9911 - fmeasure: 0.9910 - recall: 0.9904 - precision: 0.9917 - val_loss: 1.2404 - val_categorical_accuracy: 0.8289 - val_fmeasure: 0.8294 - val_recall: 0.8266 - val_precision: 0.8323
# Epoch 11/50
# 2048/2048 [==============================] - 1570s - loss: 0.1086 - categorical_accuracy: 0.9924 - fmeasure: 0.9923 - recall: 0.9918 - precision: 0.9928 - val_loss: 1.1636 - val_categorical_accuracy: 0.8306 - val_fmeasure: 0.8307 - val_recall: 0.8268 - val_precision: 0.8348
# Epoch 12/50
# 2048/2048 [==============================] - 1565s - loss: 0.1003 - categorical_accuracy: 0.9941 - fmeasure: 0.9941 - recall: 0.9938 - precision: 0.9945 - val_loss: 1.4576 - val_categorical_accuracy: 0.8043 - val_fmeasure: 0.8056 - val_recall: 0.8009 - val_precision: 0.8106
# Epoch 13/50
# 2048/2048 [==============================] - 1591s - loss: 0.0980 - categorical_accuracy: 0.9941 - fmeasure: 0.9942 - recall: 0.9939 - precision: 0.9944 - val_loss: 1.2659 - val_categorical_accuracy: 0.8189 - val_fmeasure: 0.8194 - val_recall: 0.8170 - val_precision: 0.8220
# Epoch 14/50
# 2048/2048 [==============================] - 1550s - loss: 0.0918 - categorical_accuracy: 0.9954 - fmeasure: 0.9954 - recall: 0.9952 - precision: 0.9956 - val_loss: 1.4110 - val_categorical_accuracy: 0.8215 - val_fmeasure: 0.8219 - val_recall: 0.8196 - val_precision: 0.8244
# Epoch 15/50
# 2048/2048 [==============================] - 1560s - loss: 0.0925 - categorical_accuracy: 0.9950 - fmeasure: 0.9950 - recall: 0.9948 - precision: 0.9953 - val_loss: 1.5334 - val_categorical_accuracy: 0.8212 - val_fmeasure: 0.8223 - val_recall: 0.8181 - val_precision: 0.8266
# Epoch 16/50
# 2048/2048 [==============================] - 1558s - loss: 0.0857 - categorical_accuracy: 0.9966 - fmeasure: 0.9967 - recall: 0.9965 - precision: 0.9968 - val_loss: 1.1321 - val_categorical_accuracy: 0.8357 - val_fmeasure: 0.8360 - val_recall: 0.8338 - val_precision: 0.8383
# Epoch 17/50
# 2048/2048 [==============================] - 1556s - loss: 0.0863 - categorical_accuracy: 0.9958 - fmeasure: 0.9960 - recall: 0.9957 - precision: 0.9962 - val_loss: 1.4794 - val_categorical_accuracy: 0.7949 - val_fmeasure: 0.7959 - val_recall: 0.7941 - val_precision: 0.7977
# Epoch 18/50
# 2048/2048 [==============================] - 1555s - loss: 0.0856 - categorical_accuracy: 0.9959 - fmeasure: 0.9959 - recall: 0.9957 - precision: 0.9961 - val_loss: 1.1691 - val_categorical_accuracy: 0.8245 - val_fmeasure: 0.8247 - val_recall: 0.8226 - val_precision: 0.8270
# Epoch 19/50
# 2048/2048 [==============================] - 1543s - loss: 0.0803 - categorical_accuracy: 0.9969 - fmeasure: 0.9970 - recall: 0.9969 - precision: 0.9972 - val_loss: 1.5566 - val_categorical_accuracy: 0.8163 - val_fmeasure: 0.8175 - val_recall: 0.8139 - val_precision: 0.8212
# Epoch 20/50
# 2048/2048 [==============================] - 1529s - loss: 0.0782 - categorical_accuracy: 0.9975 - fmeasure: 0.9975 - recall: 0.9974 - precision: 0.9976 - val_loss: 1.2411 - val_categorical_accuracy: 0.8333 - val_fmeasure: 0.8341 - val_recall: 0.8317 - val_precision: 0.8364
# Epoch 21/50
# 2048/2048 [==============================] - 1548s - loss: 0.0758 - categorical_accuracy: 0.9977 - fmeasure: 0.9977 - recall: 0.9976 - precision: 0.9979 - val_loss: 1.3197 - val_categorical_accuracy: 0.8092 - val_fmeasure: 0.8096 - val_recall: 0.8076 - val_precision: 0.8116
# Epoch 22/50
# 2048/2048 [==============================] - 1528s - loss: 0.0763 - categorical_accuracy: 0.9972 - fmeasure: 0.9973 - recall: 0.9972 - precision: 0.9974 - val_loss: 1.2951 - val_categorical_accuracy: 0.8265 - val_fmeasure: 0.8271 - val_recall: 0.8257 - val_precision: 0.8285
# Epoch 23/50
# 2048/2048 [==============================] - 1537s - loss: 0.0715 - categorical_accuracy: 0.9980 - fmeasure: 0.9980 - recall: 0.9979 - precision: 0.9981 - val_loss: 1.2123 - val_categorical_accuracy: 0.8341 - val_fmeasure: 0.8344 - val_recall: 0.8322 - val_precision: 0.8366
# Epoch 24/50
# 2048/2048 [==============================] - 1524s - loss: 0.0702 - categorical_accuracy: 0.9980 - fmeasure: 0.9980 - recall: 0.9979 - precision: 0.9981 - val_loss: 1.2632 - val_categorical_accuracy: 0.8317 - val_fmeasure: 0.8316 - val_recall: 0.8297 - val_precision: 0.8336
# Epoch 25/50
# 2048/2048 [==============================] - 1546s - loss: 0.0695 - categorical_accuracy: 0.9980 - fmeasure: 0.9980 - recall: 0.9979 - precision: 0.9981 - val_loss: 1.4111 - val_categorical_accuracy: 0.8156 - val_fmeasure: 0.8155 - val_recall: 0.8136 - val_precision: 0.8174
# Epoch 26/50
# 2048/2048 [==============================] - 1533s - loss: 0.0696 - categorical_accuracy: 0.9979 - fmeasure: 0.9979 - recall: 0.9977 - precision: 0.9980 - val_loss: 1.1870 - val_categorical_accuracy: 0.8429 - val_fmeasure: 0.8438 - val_recall: 0.8417 - val_precision: 0.8459
# Epoch 27/50
# 2048/2048 [==============================] - 1542s - loss: 0.0670 - categorical_accuracy: 0.9984 - fmeasure: 0.9984 - recall: 0.9984 - precision: 0.9985 - val_loss: 1.3489 - val_categorical_accuracy: 0.8231 - val_fmeasure: 0.8239 - val_recall: 0.8219 - val_precision: 0.8261
# Epoch 28/50
# 2048/2048 [==============================] - 1534s - loss: 0.0667 - categorical_accuracy: 0.9981 - fmeasure: 0.9980 - recall: 0.9980 - precision: 0.9981 - val_loss: 1.5693 - val_categorical_accuracy: 0.8099 - val_fmeasure: 0.8108 - val_recall: 0.8091 - val_precision: 0.8126
# Epoch 29/50
# 2048/2048 [==============================] - 1548s - loss: 0.0663 - categorical_accuracy: 0.9980 - fmeasure: 0.9980 - recall: 0.9980 - precision: 0.9981 - val_loss: 1.8639 - val_categorical_accuracy: 0.7912 - val_fmeasure: 0.7910 - val_recall: 0.7905 - val_precision: 0.7917
# Epoch 30/50
# 2048/2048 [==============================] - 1540s - loss: 0.0639 - categorical_accuracy: 0.9984 - fmeasure: 0.9984 - recall: 0.9983 - precision: 0.9984 - val_loss: 1.2354 - val_categorical_accuracy: 0.8265 - val_fmeasure: 0.8275 - val_recall: 0.8249 - val_precision: 0.8301
# Epoch 31/50
# 2048/2048 [==============================] - 1556s - loss: 0.0612 - categorical_accuracy: 0.9990 - fmeasure: 0.9990 - recall: 0.9989 - precision: 0.9991 - val_loss: 1.5749 - val_categorical_accuracy: 0.8083 - val_fmeasure: 0.8101 - val_recall: 0.8063 - val_precision: 0.8140
# Epoch 32/50
# 2048/2048 [==============================] - 1569s - loss: 0.0620 - categorical_accuracy: 0.9986 - fmeasure: 0.9986 - recall: 0.9986 - precision: 0.9987 - val_loss: 1.4499 - val_categorical_accuracy: 0.8103 - val_fmeasure: 0.8100 - val_recall: 0.8072 - val_precision: 0.8128
# Epoch 33/50
# 2048/2048 [==============================] - 1536s - loss: 0.0619 - categorical_accuracy: 0.9986 - fmeasure: 0.9986 - recall: 0.9986 - precision: 0.9987 - val_loss: 1.2506 - val_categorical_accuracy: 0.8368 - val_fmeasure: 0.8373 - val_recall: 0.8345 - val_precision: 0.8403
# Epoch 34/50
# 2048/2048 [==============================] - 1541s - loss: 0.0588 - categorical_accuracy: 0.9990 - fmeasure: 0.9990 - recall: 0.9990 - precision: 0.9990 - val_loss: 1.4043 - val_categorical_accuracy: 0.8035 - val_fmeasure: 0.8040 - val_recall: 0.8023 - val_precision: 0.8058
# Epoch 35/50
# 2048/2048 [==============================] - 1556s - loss: 0.0590 - categorical_accuracy: 0.9988 - fmeasure: 0.9988 - recall: 0.9988 - precision: 0.9988 - val_loss: 1.2804 - val_categorical_accuracy: 0.8494 - val_fmeasure: 0.8497 - val_recall: 0.8486 - val_precision: 0.8509
# Epoch 36/50
# 2048/2048 [==============================] - 1510s - loss: 0.0583 - categorical_accuracy: 0.9988 - fmeasure: 0.9988 - recall: 0.9988 - precision: 0.9989 - val_loss: 1.3946 - val_categorical_accuracy: 0.8283 - val_fmeasure: 0.8285 - val_recall: 0.8275 - val_precision: 0.8294
# Epoch 37/50
# 2048/2048 [==============================] - 1577s - loss: 0.0569 - categorical_accuracy: 0.9991 - fmeasure: 0.9992 - recall: 0.9991 - precision: 0.9992 - val_loss: 1.1754 - val_categorical_accuracy: 0.8408 - val_fmeasure: 0.8405 - val_recall: 0.8393 - val_precision: 0.8419
# Epoch 38/50
# 2048/2048 [==============================] - 1542s - loss: 0.0576 - categorical_accuracy: 0.9987 - fmeasure: 0.9987 - recall: 0.9987 - precision: 0.9988 - val_loss: 1.2448 - val_categorical_accuracy: 0.8321 - val_fmeasure: 0.8323 - val_recall: 0.8309 - val_precision: 0.8338
# Epoch 39/50
# 2048/2048 [==============================] - 1556s - loss: 0.0559 - categorical_accuracy: 0.9990 - fmeasure: 0.9990 - recall: 0.9989 - precision: 0.9990 - val_loss: 1.2041 - val_categorical_accuracy: 0.8426 - val_fmeasure: 0.8430 - val_recall: 0.8422 - val_precision: 0.8438
# Epoch 40/50
# 2048/2048 [==============================] - 1560s - loss: 0.0546 - categorical_accuracy: 0.9991 - fmeasure: 0.9992 - recall: 0.9991 - precision: 0.9992 - val_loss: 1.2061 - val_categorical_accuracy: 0.8493 - val_fmeasure: 0.8500 - val_recall: 0.8485 - val_precision: 0.8515
# Epoch 41/50
# 2048/2048 [==============================] - 1575s - loss: 0.0546 - categorical_accuracy: 0.9989 - fmeasure: 0.9989 - recall: 0.9988 - precision: 0.9990 - val_loss: 1.2764 - val_categorical_accuracy: 0.8295 - val_fmeasure: 0.8296 - val_recall: 0.8280 - val_precision: 0.8312
# Epoch 42/50
# 2048/2048 [==============================] - 1536s - loss: 0.0526 - categorical_accuracy: 0.9993 - fmeasure: 0.9993 - recall: 0.9993 - precision: 0.9994 - val_loss: 1.1373 - val_categorical_accuracy: 0.8486 - val_fmeasure: 0.8496 - val_recall: 0.8486 - val_precision: 0.8506
# Epoch 43/50
# 2048/2048 [==============================] - 1555s - loss: 0.0546 - categorical_accuracy: 0.9988 - fmeasure: 0.9988 - recall: 0.9988 - precision: 0.9988 - val_loss: 1.1488 - val_categorical_accuracy: 0.8455 - val_fmeasure: 0.8452 - val_recall: 0.8436 - val_precision: 0.8469
# Epoch 44/50
# 2048/2048 [==============================] - 1536s - loss: 0.0515 - categorical_accuracy: 0.9993 - fmeasure: 0.9993 - recall: 0.9993 - precision: 0.9993 - val_loss: 1.1157 - val_categorical_accuracy: 0.8522 - val_fmeasure: 0.8527 - val_recall: 0.8514 - val_precision: 0.8540
# Epoch 45/50
# 2048/2048 [==============================] - 1549s - loss: 0.0510 - categorical_accuracy: 0.9994 - fmeasure: 0.9994 - recall: 0.9994 - precision: 0.9994 - val_loss: 1.2536 - val_categorical_accuracy: 0.8308 - val_fmeasure: 0.8312 - val_recall: 0.8304 - val_precision: 0.8320
# Epoch 46/50
# 2048/2048 [==============================] - 1543s - loss: 0.0498 - categorical_accuracy: 0.9995 - fmeasure: 0.9995 - recall: 0.9995 - precision: 0.9995 - val_loss: 1.1592 - val_categorical_accuracy: 0.8478 - val_fmeasure: 0.8490 - val_recall: 0.8471 - val_precision: 0.8510
# Epoch 47/50
# 2048/2048 [==============================] - 1557s - loss: 0.0507 - categorical_accuracy: 0.9991 - fmeasure: 0.9991 - recall: 0.9991 - precision: 0.9992 - val_loss: 1.3299 - val_categorical_accuracy: 0.8305 - val_fmeasure: 0.8310 - val_recall: 0.8305 - val_precision: 0.8315
# Epoch 48/50
# 2048/2048 [==============================] - 1523s - loss: 0.0502 - categorical_accuracy: 0.9990 - fmeasure: 0.9990 - recall: 0.9990 - precision: 0.9990 - val_loss: 1.3822 - val_categorical_accuracy: 0.8364 - val_fmeasure: 0.8370 - val_recall: 0.8348 - val_precision: 0.8393
# Epoch 49/50
# 2048/2048 [==============================] - 1542s - loss: 0.0474 - categorical_accuracy: 0.9997 - fmeasure: 0.9997 - recall: 0.9997 - precision: 0.9997 - val_loss: 1.2734 - val_categorical_accuracy: 0.8366 - val_fmeasure: 0.8366 - val_recall: 0.8355 - val_precision: 0.8377
# Epoch 50/50
# 2048/2048 [==============================] - 1545s - loss: 0.0490 - categorical_accuracy: 0.9990 - fmeasure: 0.9990 - recall: 0.9990 - precision: 0.9990 - val_loss: 1.2589 - val_categorical_accuracy: 0.8442 - val_fmeasure: 0.8451 - val_recall: 0.8438 - val_precision: 0.8464

# %%
score = model.evaluate_generator(validation_generator, steps=50)

print ('Test Score: ', score[0])
print ('Test Accuracy: ',score[1])
print ('fmeasure: ', score[2])
print ('Recall: ', score[3])
print ('Precision: ', score[4])
# Out:
# Test Score:  1.350412010923028
# Test Accuracy:  0.840625
# fmeasure:  0.8418947863578796
# Recall:  0.840625
# Precision:  0.8432056450843811

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["categorical_accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_categorical_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()

# %%
from keras.preprocessing.image import ImageDataGenerator

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True)


# target_size = (height, width)
target_size = (225, 300)


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size = target_size,       
        class_mode = 'categorical',
        shuffle = False)

validation_generator = train_datagen.flow_from_directory(
        validation_dir,
        target_size = target_size,        
        class_mode = 'categorical',
        shuffle = False)
# Out:
# Found 7285 images belonging to 7 classes.
# Found 2602 images belonging to 7 classes.

# %%
filename = validation_generator.filenames
truth = validation_generator.classes
label = validation_generator.class_indices
indexlabel = dict((value, key) for key, value in label.items())

predicts = model.predict_generator(validation_generator, steps=validation_generator.samples/validation_generator.batch_size, verbose=1)
predict_class = np.argmax(predicts, axis=1)
errors = np.where(predict_class != truth)[0]
print("No of errors = {}/{}".format(len(errors),validation_generator.samples))
# Out:
# 82/81 [==============================] - 43s
# No of errors = 406/2602

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(truth,predict_class)

labels = []
for k,v in indexlabel.items():
    labels.append(v)
    
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion Matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))    

plt.figure(figsize=(10,10))


plot_confusion_matrix(cm, classes=labels,
                      title='Confusion Matrix')
# Out:
# Confusion Matrix
# [[  32    9   19    1    5    8    0]
#  [   5   95   18    2    6   12    1]
#  [   1    6  226    0   16   35    0]
#  [   1    0    6   14    1    8    0]
#  [   3    5   35    0  178   91    0]
#  [   1   12   47    1   42 1626    1]
#  [   0    1    1    0    5    1   25]]

# %%
#ROC Curve for each class
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
import matplotlib.pyplot as plt
# %matplotlib inline  
from scipy import interp
from itertools import cycle


y_pred = predicts
y_pred_probabilities=y_pred

y_pred = np.argmax(y_pred,axis = 1) 
y_actual = validation_generator.classes

classnames=[]
for classname in validation_generator.class_indices:
    classnames.append(classname)

y_actual_binary = label_binarize(y_actual, classes=[0, 1, 2, 3, 4, 5, 6])
y_pred_binary = y_pred_probabilities#label_binarize(y_pred_probabilities, classes=[0, 1, 2, 3, 4])
n_classes=7
lw=2

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_actual_binary[:, i], y_pred_binary[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_actual_binary.ravel(), y_pred_binary.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(figsize=(7, 7))


colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="best")
plt.show()

# %%
# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=6)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=6)


colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

    
    
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-classs')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report

confusion_mtx = confusion_matrix(y_actual, y_pred) 
print(confusion_mtx)
target_names = classnames
print(classification_report(y_actual, y_pred, target_names=target_names))
# Out:
# [[  32    9   19    1    5    8    0]
#  [   5   95   18    2    6   12    1]
#  [   1    6  226    0   16   35    0]
#  [   1    0    6   14    1    8    0]
#  [   3    5   35    0  178   91    0]
#  [   1   12   47    1   42 1626    1]
#  [   0    1    1    0    5    1   25]]
#               precision    recall  f1-score   support
#
#        AKIEC       0.74      0.43      0.55        74
#          BCC       0.74      0.68      0.71       139
#          BKL       0.64      0.80      0.71       284
#           DF       0.78      0.47      0.58        30
#          MEL       0.70      0.57      0.63       312
#           NV       0.91      0.94      0.93      1730
#         VASC       0.93      0.76      0.83        33
#
#    micro avg       0.84      0.84      0.84      2602
#    macro avg       0.78      0.66      0.71      2602
# weighted avg       0.84      0.84      0.84      2602

# %%
os.mkdir('models')

# %%
model.save('models/5.VGG16-Skin-Classification-without-Aug-Model.h5')
model.save_weights('models/5.VGG16-Skin-Classification-without-Aug-Weights.h5')

# %%
from keras.models import load_model
model = load_model("models/5.VGG16-Skin-Classification-without-Aug-Model.h5", custom_objects={'fmeasure': fmeasure,  'recall': recall, 'precision': precision })
model.load_weights("models/5.VGG16-Skin-Classification-without-Aug-Weights.h5")
