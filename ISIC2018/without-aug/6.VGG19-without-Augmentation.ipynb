# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
import keras
import os
os.environ["CUDA_VISIBLE_DEVICES"]="5,6,7"

config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
keras.backend.set_session(sess)

def _get_available_devices():
    from tensorflow.python.client import device_lib
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]

print( _get_available_devices())
# Out:
# Using TensorFlow backend.
# ['/device:CPU:0', '/device:GPU:0', '/device:GPU:1', '/device:GPU:2']

# %%
import os
import pandas as pd

import numpy as np
from glob import glob

from keras import layers
from keras import models
from keras import optimizers
from keras.models import load_model
import keras.callbacks as kcall
from keras.optimizers import Adam
from keras.models import Model
from keras.models import Sequential
from keras.layers import Flatten, Dense, Activation, Dropout, Conv2D, MaxPooling2D, BatchNormalization
from keras.applications.xception import Xception, preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
train_dir = 'data-without-aug/train'
validation_dir = 'data-without-aug/validation'

# %%
for root,dirs,files in os.walk(train_dir):
    print (root, len(files))
# Out:
# data-without-aug/train 0
# data-without-aug/train/DF 85
# data-without-aug/train/VASC 109
# data-without-aug/train/MEL 801
# data-without-aug/train/AKIEC 253
# data-without-aug/train/BKL 815
# data-without-aug/train/BCC 247
# data-without-aug/train/NV 4975

# %%
for root,dirs,files in os.walk(validation_dir):
    print (root, len(files))
# Out:
# data-without-aug/validation 0
# data-without-aug/validation/DF 30
# data-without-aug/validation/VASC 33
# data-without-aug/validation/MEL 312
# data-without-aug/validation/AKIEC 74
# data-without-aug/validation/BKL 284
# data-without-aug/validation/BCC 139
# data-without-aug/validation/NV 1730

# %%
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True)


# target_size = (height, width)
target_size = (225, 300)


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size = target_size,       
        class_mode = 'categorical',
        shuffle = True)

validation_generator = train_datagen.flow_from_directory(
        validation_dir,
        target_size = target_size,        
        class_mode = 'categorical',
        shuffle = True)
# Out:
# Found 7285 images belonging to 7 classes.
# Found 2602 images belonging to 7 classes.

# %%
import keras.backend as K

def precision(y_true, y_pred):
    # Calculates the precision
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision


def recall(y_true, y_pred):
    # Calculates the recall
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def fbeta_score(y_true, y_pred, beta=1):
    # Calculates the F score, the weighted harmonic mean of precision and recall.

    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
        
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score

def fmeasure(y_true, y_pred):
    # Calculates the f-measure, the harmonic mean of precision and recall.
    return fbeta_score(y_true, y_pred, beta=1)

# %%
output_classes = 7

batch_size = 32 
epochs = 50
droput_rate= 0.5

adam_opt = Adam(lr=1e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=1e-5)

# %%
from keras.applications.vgg19 import VGG19
from keras.layers import Flatten, Dense, Dropout, BatchNormalization
from keras.regularizers import l2

model = (VGG19(include_top=False, pooling='avg', weights= "imagenet"))
x = model.output
# x = Flatten()(x)
x = Dense(1024, activation="relu", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation="relu", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
predictions = Dense(7, activation="softmax", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
model = Model(input = model.input, output = predictions)


model.compile(loss='categorical_crossentropy',
              optimizer= adam_opt,
              metrics = ["categorical_accuracy", fmeasure, recall, precision])

# %%
history = model.fit_generator(train_generator,
    steps_per_epoch=2048,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps=1024)
# Out:
# Epoch 1/50
# 2048/2048 [==============================] - 1620s - loss: 1.8846 - categorical_accuracy: 0.5703 - fmeasure: 0.5503 - recall: 0.4800 - precision: 0.6546 - val_loss: 1.3993 - val_categorical_accuracy: 0.6647 - val_fmeasure: 0.6509 - val_recall: 0.6040 - val_precision: 0.7076
# Epoch 2/50
# 2048/2048 [==============================] - 1582s - loss: 1.1489 - categorical_accuracy: 0.7428 - fmeasure: 0.7392 - recall: 0.6935 - precision: 0.7948 - val_loss: 1.0049 - val_categorical_accuracy: 0.7701 - val_fmeasure: 0.7720 - val_recall: 0.7428 - val_precision: 0.8047
# Epoch 3/50
# 2048/2048 [==============================] - 1600s - loss: 0.6644 - categorical_accuracy: 0.8515 - fmeasure: 0.8527 - recall: 0.8288 - precision: 0.8792 - val_loss: 0.8908 - val_categorical_accuracy: 0.8046 - val_fmeasure: 0.8049 - val_recall: 0.7805 - val_precision: 0.8319
# Epoch 4/50
# 2048/2048 [==============================] - 1541s - loss: 0.3767 - categorical_accuracy: 0.9267 - fmeasure: 0.9278 - recall: 0.9166 - precision: 0.9396 - val_loss: 1.3614 - val_categorical_accuracy: 0.7835 - val_fmeasure: 0.7840 - val_recall: 0.7767 - val_precision: 0.7917
# Epoch 5/50
# 2048/2048 [==============================] - 1555s - loss: 0.2366 - categorical_accuracy: 0.9664 - fmeasure: 0.9670 - recall: 0.9625 - precision: 0.9717 - val_loss: 1.1050 - val_categorical_accuracy: 0.8337 - val_fmeasure: 0.8355 - val_recall: 0.8287 - val_precision: 0.8427
# Epoch 6/50
# 2048/2048 [==============================] - 1573s - loss: 0.1955 - categorical_accuracy: 0.9777 - fmeasure: 0.9778 - recall: 0.9755 - precision: 0.9801 - val_loss: 1.1793 - val_categorical_accuracy: 0.8065 - val_fmeasure: 0.8095 - val_recall: 0.8027 - val_precision: 0.8167
# Epoch 7/50
# 2048/2048 [==============================] - 1591s - loss: 0.1648 - categorical_accuracy: 0.9852 - fmeasure: 0.9851 - recall: 0.9839 - precision: 0.9864 - val_loss: 1.3229 - val_categorical_accuracy: 0.7995 - val_fmeasure: 0.8009 - val_recall: 0.7961 - val_precision: 0.8059
# Epoch 8/50
# 2048/2048 [==============================] - 1519s - loss: 0.1482 - categorical_accuracy: 0.9879 - fmeasure: 0.9879 - recall: 0.9870 - precision: 0.9889 - val_loss: 1.1596 - val_categorical_accuracy: 0.8329 - val_fmeasure: 0.8343 - val_recall: 0.8313 - val_precision: 0.8374
# Epoch 9/50
# 2048/2048 [==============================] - 1523s - loss: 0.1333 - categorical_accuracy: 0.9904 - fmeasure: 0.9905 - recall: 0.9899 - precision: 0.9912 - val_loss: 1.3475 - val_categorical_accuracy: 0.8209 - val_fmeasure: 0.8216 - val_recall: 0.8193 - val_precision: 0.8240
# Epoch 10/50
# 2048/2048 [==============================] - 1523s - loss: 0.1257 - categorical_accuracy: 0.9909 - fmeasure: 0.9909 - recall: 0.9903 - precision: 0.9915 - val_loss: 1.2196 - val_categorical_accuracy: 0.8358 - val_fmeasure: 0.8372 - val_recall: 0.8342 - val_precision: 0.8403
# Epoch 11/50
# 2048/2048 [==============================] - 1516s - loss: 0.1154 - categorical_accuracy: 0.9936 - fmeasure: 0.9937 - recall: 0.9934 - precision: 0.9940 - val_loss: 1.4385 - val_categorical_accuracy: 0.8093 - val_fmeasure: 0.8091 - val_recall: 0.8057 - val_precision: 0.8127
# Epoch 12/50
# 2048/2048 [==============================] - 1546s - loss: 0.1094 - categorical_accuracy: 0.9940 - fmeasure: 0.9939 - recall: 0.9937 - precision: 0.9942 - val_loss: 1.1713 - val_categorical_accuracy: 0.8329 - val_fmeasure: 0.8348 - val_recall: 0.8318 - val_precision: 0.8380
# Epoch 13/50
# 2048/2048 [==============================] - 1526s - loss: 0.1063 - categorical_accuracy: 0.9947 - fmeasure: 0.9947 - recall: 0.9945 - precision: 0.9949 - val_loss: 1.3192 - val_categorical_accuracy: 0.8210 - val_fmeasure: 0.8224 - val_recall: 0.8202 - val_precision: 0.8247
# Epoch 14/50
# 2048/2048 [==============================] - 1532s - loss: 0.1020 - categorical_accuracy: 0.9952 - fmeasure: 0.9951 - recall: 0.9949 - precision: 0.9954 - val_loss: 1.0732 - val_categorical_accuracy: 0.8439 - val_fmeasure: 0.8448 - val_recall: 0.8413 - val_precision: 0.8484
# Epoch 15/50
# 2048/2048 [==============================] - 1529s - loss: 0.1036 - categorical_accuracy: 0.9947 - fmeasure: 0.9946 - recall: 0.9944 - precision: 0.9948 - val_loss: 1.1040 - val_categorical_accuracy: 0.8453 - val_fmeasure: 0.8459 - val_recall: 0.8435 - val_precision: 0.8485
# Epoch 16/50
# 2048/2048 [==============================] - 1524s - loss: 0.0947 - categorical_accuracy: 0.9964 - fmeasure: 0.9964 - recall: 0.9962 - precision: 0.9966 - val_loss: 1.2303 - val_categorical_accuracy: 0.8301 - val_fmeasure: 0.8308 - val_recall: 0.8294 - val_precision: 0.8322
# Epoch 17/50
# 2048/2048 [==============================] - 1532s - loss: 0.0911 - categorical_accuracy: 0.9966 - fmeasure: 0.9966 - recall: 0.9965 - precision: 0.9967 - val_loss: 1.1296 - val_categorical_accuracy: 0.8329 - val_fmeasure: 0.8341 - val_recall: 0.8309 - val_precision: 0.8374
# Epoch 18/50
# 2048/2048 [==============================] - 1521s - loss: 0.0893 - categorical_accuracy: 0.9969 - fmeasure: 0.9969 - recall: 0.9968 - precision: 0.9971 - val_loss: 1.1324 - val_categorical_accuracy: 0.8442 - val_fmeasure: 0.8447 - val_recall: 0.8422 - val_precision: 0.8472
# Epoch 19/50
# 2048/2048 [==============================] - 1524s - loss: 0.0901 - categorical_accuracy: 0.9962 - fmeasure: 0.9963 - recall: 0.9961 - precision: 0.9965 - val_loss: 2.0220 - val_categorical_accuracy: 0.7616 - val_fmeasure: 0.7618 - val_recall: 0.7589 - val_precision: 0.7647
# Epoch 20/50
# 2048/2048 [==============================] - 1520s - loss: 0.0850 - categorical_accuracy: 0.9976 - fmeasure: 0.9976 - recall: 0.9976 - precision: 0.9977 - val_loss: 1.2034 - val_categorical_accuracy: 0.8429 - val_fmeasure: 0.8437 - val_recall: 0.8425 - val_precision: 0.8450
# Epoch 21/50
# 2048/2048 [==============================] - 1516s - loss: 0.0874 - categorical_accuracy: 0.9966 - fmeasure: 0.9966 - recall: 0.9965 - precision: 0.9967 - val_loss: 1.2224 - val_categorical_accuracy: 0.8315 - val_fmeasure: 0.8308 - val_recall: 0.8296 - val_precision: 0.8321
# Epoch 22/50
# 2048/2048 [==============================] - 1533s - loss: 0.0863 - categorical_accuracy: 0.9971 - fmeasure: 0.9971 - recall: 0.9970 - precision: 0.9972 - val_loss: 1.1445 - val_categorical_accuracy: 0.8401 - val_fmeasure: 0.8405 - val_recall: 0.8382 - val_precision: 0.8430
# Epoch 23/50
# 2048/2048 [==============================] - 1516s - loss: 0.0834 - categorical_accuracy: 0.9979 - fmeasure: 0.9979 - recall: 0.9978 - precision: 0.9979 - val_loss: 1.3080 - val_categorical_accuracy: 0.8281 - val_fmeasure: 0.8291 - val_recall: 0.8265 - val_precision: 0.8317
# Epoch 24/50
# 2048/2048 [==============================] - 1524s - loss: 0.0833 - categorical_accuracy: 0.9977 - fmeasure: 0.9977 - recall: 0.9976 - precision: 0.9977 - val_loss: 1.2688 - val_categorical_accuracy: 0.8266 - val_fmeasure: 0.8279 - val_recall: 0.8258 - val_precision: 0.8299
# Epoch 25/50
# 2048/2048 [==============================] - 1545s - loss: 0.0831 - categorical_accuracy: 0.9974 - fmeasure: 0.9974 - recall: 0.9974 - precision: 0.9975 - val_loss: 1.1953 - val_categorical_accuracy: 0.8310 - val_fmeasure: 0.8319 - val_recall: 0.8294 - val_precision: 0.8345
# Epoch 26/50
# 2048/2048 [==============================] - 1606s - loss: 0.0793 - categorical_accuracy: 0.9982 - fmeasure: 0.9982 - recall: 0.9981 - precision: 0.9983 - val_loss: 1.1705 - val_categorical_accuracy: 0.8449 - val_fmeasure: 0.8459 - val_recall: 0.8434 - val_precision: 0.8486
# Epoch 27/50
# 2048/2048 [==============================] - 1527s - loss: 0.0786 - categorical_accuracy: 0.9980 - fmeasure: 0.9980 - recall: 0.9980 - precision: 0.9981 - val_loss: 1.7647 - val_categorical_accuracy: 0.7898 - val_fmeasure: 0.7898 - val_recall: 0.7883 - val_precision: 0.7914
# Epoch 28/50
# 2048/2048 [==============================] - 1515s - loss: 0.0784 - categorical_accuracy: 0.9980 - fmeasure: 0.9980 - recall: 0.9980 - precision: 0.9980 - val_loss: 1.2780 - val_categorical_accuracy: 0.8269 - val_fmeasure: 0.8285 - val_recall: 0.8257 - val_precision: 0.8314
# Epoch 29/50
# 2048/2048 [==============================] - 1523s - loss: 0.0763 - categorical_accuracy: 0.9981 - fmeasure: 0.9981 - recall: 0.9981 - precision: 0.9981 - val_loss: 1.1810 - val_categorical_accuracy: 0.8381 - val_fmeasure: 0.8383 - val_recall: 0.8370 - val_precision: 0.8396
# Epoch 30/50
# 2048/2048 [==============================] - 1520s - loss: 0.0780 - categorical_accuracy: 0.9977 - fmeasure: 0.9977 - recall: 0.9977 - precision: 0.9978 - val_loss: 1.5685 - val_categorical_accuracy: 0.8073 - val_fmeasure: 0.8074 - val_recall: 0.8057 - val_precision: 0.8092
# Epoch 31/50
# 2048/2048 [==============================] - 1536s - loss: 0.0755 - categorical_accuracy: 0.9984 - fmeasure: 0.9984 - recall: 0.9983 - precision: 0.9984 - val_loss: 1.1629 - val_categorical_accuracy: 0.8457 - val_fmeasure: 0.8462 - val_recall: 0.8441 - val_precision: 0.8483
# Epoch 32/50
# 2048/2048 [==============================] - 1522s - loss: 0.0725 - categorical_accuracy: 0.9986 - fmeasure: 0.9986 - recall: 0.9986 - precision: 0.9987 - val_loss: 1.1929 - val_categorical_accuracy: 0.8427 - val_fmeasure: 0.8448 - val_recall: 0.8423 - val_precision: 0.8475
# Epoch 33/50
# 2048/2048 [==============================] - 1538s - loss: 0.0718 - categorical_accuracy: 0.9985 - fmeasure: 0.9985 - recall: 0.9985 - precision: 0.9985 - val_loss: 1.2551 - val_categorical_accuracy: 0.8382 - val_fmeasure: 0.8392 - val_recall: 0.8374 - val_precision: 0.8409
# Epoch 34/50
# 2048/2048 [==============================] - 1558s - loss: 0.0729 - categorical_accuracy: 0.9984 - fmeasure: 0.9984 - recall: 0.9983 - precision: 0.9984 - val_loss: 1.2072 - val_categorical_accuracy: 0.8362 - val_fmeasure: 0.8367 - val_recall: 0.8347 - val_precision: 0.8389
# Epoch 35/50
# 2048/2048 [==============================] - 1531s - loss: 0.0691 - categorical_accuracy: 0.9991 - fmeasure: 0.9991 - recall: 0.9990 - precision: 0.9992 - val_loss: 1.7261 - val_categorical_accuracy: 0.8029 - val_fmeasure: 0.8041 - val_recall: 0.8017 - val_precision: 0.8064
# Epoch 36/50
# 2048/2048 [==============================] - 1525s - loss: 0.0709 - categorical_accuracy: 0.9984 - fmeasure: 0.9984 - recall: 0.9983 - precision: 0.9985 - val_loss: 1.2453 - val_categorical_accuracy: 0.8350 - val_fmeasure: 0.8356 - val_recall: 0.8338 - val_precision: 0.8376
# Epoch 37/50
# 2048/2048 [==============================] - 1577s - loss: 0.0670 - categorical_accuracy: 0.9992 - fmeasure: 0.9992 - recall: 0.9992 - precision: 0.9992 - val_loss: 1.2723 - val_categorical_accuracy: 0.8420 - val_fmeasure: 0.8423 - val_recall: 0.8408 - val_precision: 0.8438
# Epoch 38/50
# 2048/2048 [==============================] - 1534s - loss: 0.0695 - categorical_accuracy: 0.9983 - fmeasure: 0.9984 - recall: 0.9983 - precision: 0.9984 - val_loss: 1.2278 - val_categorical_accuracy: 0.8285 - val_fmeasure: 0.8291 - val_recall: 0.8273 - val_precision: 0.8309
# Epoch 39/50
# 2048/2048 [==============================] - 1555s - loss: 0.0672 - categorical_accuracy: 0.9989 - fmeasure: 0.9989 - recall: 0.9989 - precision: 0.9989 - val_loss: 1.7277 - val_categorical_accuracy: 0.7946 - val_fmeasure: 0.7959 - val_recall: 0.7934 - val_precision: 0.7986
# Epoch 40/50
# 2048/2048 [==============================] - 1537s - loss: 0.0678 - categorical_accuracy: 0.9983 - fmeasure: 0.9983 - recall: 0.9983 - precision: 0.9983 - val_loss: 1.2616 - val_categorical_accuracy: 0.8311 - val_fmeasure: 0.8313 - val_recall: 0.8300 - val_precision: 0.8326
# Epoch 41/50
# 2048/2048 [==============================] - 1536s - loss: 0.0661 - categorical_accuracy: 0.9989 - fmeasure: 0.9989 - recall: 0.9989 - precision: 0.9989 - val_loss: 1.2889 - val_categorical_accuracy: 0.8282 - val_fmeasure: 0.8285 - val_recall: 0.8274 - val_precision: 0.8297
# Epoch 42/50
# 2048/2048 [==============================] - 1596s - loss: 0.0651 - categorical_accuracy: 0.9987 - fmeasure: 0.9988 - recall: 0.9987 - precision: 0.9988 - val_loss: 1.2243 - val_categorical_accuracy: 0.8376 - val_fmeasure: 0.8383 - val_recall: 0.8365 - val_precision: 0.8403
# Epoch 43/50
# 2048/2048 [==============================] - 1547s - loss: 0.0642 - categorical_accuracy: 0.9989 - fmeasure: 0.9990 - recall: 0.9989 - precision: 0.9990 - val_loss: 1.3169 - val_categorical_accuracy: 0.8332 - val_fmeasure: 0.8340 - val_recall: 0.8325 - val_precision: 0.8357
# Epoch 44/50
# 2048/2048 [==============================] - 1535s - loss: 0.0640 - categorical_accuracy: 0.9988 - fmeasure: 0.9988 - recall: 0.9987 - precision: 0.9988 - val_loss: 1.3727 - val_categorical_accuracy: 0.8207 - val_fmeasure: 0.8218 - val_recall: 0.8195 - val_precision: 0.8242
# Epoch 45/50
# 2048/2048 [==============================] - 1542s - loss: 0.0607 - categorical_accuracy: 0.9995 - fmeasure: 0.9995 - recall: 0.9995 - precision: 0.9995 - val_loss: 1.2318 - val_categorical_accuracy: 0.8476 - val_fmeasure: 0.8476 - val_recall: 0.8465 - val_precision: 0.8488
# Epoch 46/50
# 2048/2048 [==============================] - 1597s - loss: 0.0633 - categorical_accuracy: 0.9985 - fmeasure: 0.9985 - recall: 0.9984 - precision: 0.9985 - val_loss: 1.1953 - val_categorical_accuracy: 0.8471 - val_fmeasure: 0.8480 - val_recall: 0.8459 - val_precision: 0.8502
# Epoch 47/50
# 2048/2048 [==============================] - 1606s - loss: 0.0598 - categorical_accuracy: 0.9991 - fmeasure: 0.9991 - recall: 0.9991 - precision: 0.9991 - val_loss: 1.3433 - val_categorical_accuracy: 0.8337 - val_fmeasure: 0.8335 - val_recall: 0.8321 - val_precision: 0.8350
# Epoch 48/50
# 2048/2048 [==============================] - 1521s - loss: 0.0593 - categorical_accuracy: 0.9989 - fmeasure: 0.9989 - recall: 0.9989 - precision: 0.9989 - val_loss: 1.2501 - val_categorical_accuracy: 0.8377 - val_fmeasure: 0.8386 - val_recall: 0.8366 - val_precision: 0.8407
# Epoch 49/50
# 2048/2048 [==============================] - 1617s - loss: 0.0582 - categorical_accuracy: 0.9990 - fmeasure: 0.9990 - recall: 0.9990 - precision: 0.9990 - val_loss: 1.2468 - val_categorical_accuracy: 0.8376 - val_fmeasure: 0.8397 - val_recall: 0.8376 - val_precision: 0.8418
# Epoch 50/50
# 2048/2048 [==============================] - 1585s - loss: 0.0573 - categorical_accuracy: 0.9991 - fmeasure: 0.9992 - recall: 0.9991 - precision: 0.9992 - val_loss: 1.2455 - val_categorical_accuracy: 0.8421 - val_fmeasure: 0.8423 - val_recall: 0.8414 - val_precision: 0.8433

# %%
score = model.evaluate_generator(validation_generator, steps=50)

print ('Test Score: ', score[0])
print ('Test Accuracy: ',score[1])
print ('fmeasure: ', score[2])
print ('Recall: ', score[3])
print ('Precision: ', score[4])
# Out:
# Test Score:  1.2210311055183412
# Test Accuracy:  0.843125
# fmeasure:  0.8429066872596741
# Recall:  0.841875
# Precision:  0.8439717745780945

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["categorical_accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_categorical_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()

# %%
from keras.preprocessing.image import ImageDataGenerator

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True)


# target_size = (height, width)
target_size = (225, 300)


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size = target_size,       
        class_mode = 'categorical',
        shuffle = False)

validation_generator = train_datagen.flow_from_directory(
        validation_dir,
        target_size = target_size,        
        class_mode = 'categorical',
        shuffle = False)
# Out:
# Found 7285 images belonging to 7 classes.
# Found 2602 images belonging to 7 classes.

# %%
filename = validation_generator.filenames
truth = validation_generator.classes
label = validation_generator.class_indices
indexlabel = dict((value, key) for key, value in label.items())

predicts = model.predict_generator(validation_generator, steps=validation_generator.samples/validation_generator.batch_size, verbose=1)
predict_class = np.argmax(predicts, axis=1)
errors = np.where(predict_class != truth)[0]
print("No of errors = {}/{}".format(len(errors),validation_generator.samples))
# Out:
# 82/81 [==============================] - 39s
# No of errors = 410/2602

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(truth,predict_class)

labels = []
for k,v in indexlabel.items():
    labels.append(v)
    
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion Matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))    

plt.figure(figsize=(10,10))


plot_confusion_matrix(cm, classes=labels,
                      title='Confusion Matrix')
# Out:
# Confusion Matrix
# [[  44    5    9    0    6   10    0]
#  [   7   76   22    1   11   20    2]
#  [   3    4  217    0   18   42    0]
#  [   1    0    3   15    0   11    0]
#  [  11    2   29    0  162  107    1]
#  [   1    5   30    1   42 1650    1]
#  [   0    0    1    0    2    2   28]]

# %%
#ROC Curve for each class
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
import matplotlib.pyplot as plt
# %matplotlib inline  
from scipy import interp
from itertools import cycle


y_pred = predicts
y_pred_probabilities=y_pred

y_pred = np.argmax(y_pred,axis = 1) 
y_actual = validation_generator.classes

classnames=[]
for classname in validation_generator.class_indices:
    classnames.append(classname)

y_actual_binary = label_binarize(y_actual, classes=[0, 1, 2, 3, 4, 5, 6])
y_pred_binary = y_pred_probabilities#label_binarize(y_pred_probabilities, classes=[0, 1, 2, 3, 4])
n_classes=7
lw=2

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_actual_binary[:, i], y_pred_binary[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_actual_binary.ravel(), y_pred_binary.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(figsize=(7, 7))


colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="best")
plt.show()

# %%
# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=6)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=6)


colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

    
    
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-classs')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report

confusion_mtx = confusion_matrix(y_actual, y_pred) 
print(confusion_mtx)
target_names = classnames
print(classification_report(y_actual, y_pred, target_names=target_names))
# Out:
# [[  44    5    9    0    6   10    0]
#  [   7   76   22    1   11   20    2]
#  [   3    4  217    0   18   42    0]
#  [   1    0    3   15    0   11    0]
#  [  11    2   29    0  162  107    1]
#  [   1    5   30    1   42 1650    1]
#  [   0    0    1    0    2    2   28]]
#               precision    recall  f1-score   support
#
#        AKIEC       0.66      0.59      0.62        74
#          BCC       0.83      0.55      0.66       139
#          BKL       0.70      0.76      0.73       284
#           DF       0.88      0.50      0.64        30
#          MEL       0.67      0.52      0.59       312
#           NV       0.90      0.95      0.92      1730
#         VASC       0.88      0.85      0.86        33
#
#    micro avg       0.84      0.84      0.84      2602
#    macro avg       0.79      0.68      0.72      2602
# weighted avg       0.84      0.84      0.84      2602

# %%
model.save('models/6.VGG19-Skin-Classification-without-Aug-Model.h5')
model.save_weights('models/6.VGG19-Skin-Classification-without-Aug-Weights.h5')

# %%
from keras.models import load_model
model = load_model("models/6.VGG19-Skin-Classification-without-Aug-Model.h5", custom_objects={'fmeasure': fmeasure,  'recall': recall, 'precision': precision })
model.load_weights("models/6.VGG19-Skin-Classification-without-Aug-Weights.h5")
