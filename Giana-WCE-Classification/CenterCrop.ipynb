# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
import numpy as np
import cv2

from scipy import ndimage, misc
import os, glob
import sys
import skimage
from skimage import feature, data, io

from scipy.misc import imread, imsave
from PIL import Image
import random

# %%
def get_file_name_dir(rootDir, ext):
 
    # Return file names with certain extension

    return glob.glob1(rootDir, "*." + ext)

def center_crop(img, h=515, w=515):
    """center crop a single image with cropsize x, y"""
    oh, ow, _ = img.shape
    dw = ow - w
    dh = oh - h
    startx = np.round(dw / 2).astype(int)
    starty = np.round(dh / 2).astype(int)
    return img[starty:starty + h, startx:startx + w, :]

# %%
input_path = 'data/train/inflammatory/'
input_extension = 'jpg'
inputs_files = sorted(get_file_name_dir(input_path, input_extension))

cont = 1
for file_name in inputs_files:
    print('Preprocessing: ' + file_name + ': ' + str(cont))
    cont += 1
    img = input_path + file_name
    im_in = cv2.imread(img)
    image = center_crop(im_in)

    cv2.imwrite(input_path + file_name , image)
# Out:
# Preprocessing: AGD2411.jpg: 1
# Preprocessing: AGD281.jpg: 2
# Preprocessing: AGD921.jpg: 3
# Preprocessing: AGD922.jpg: 4
# Preprocessing: AGD923.jpg: 5
# Preprocessing: EI1.jpg: 6
# Preprocessing: EI10.jpg: 7
# Preprocessing: EI11.jpg: 8
# Preprocessing: EI12.jpg: 9
# Preprocessing: EI13.jpg: 10
# Preprocessing: EI14.jpg: 11
# Preprocessing: EI15.jpg: 12
# Preprocessing: EI16.jpg: 13
# Preprocessing: EI17.jpg: 14
# Preprocessing: EI18.jpg: 15
# Preprocessing: EI19.jpg: 16
# Preprocessing: EI2.jpg: 17
# Preprocessing: EI20.jpg: 18
# Preprocessing: EI21.jpg: 19
# Preprocessing: EI22.jpg: 20
# Preprocessing: EI23.jpg: 21
# Preprocessing: EI24.jpg: 22
# Preprocessing: EI25.jpg: 23
# Preprocessing: EI26.jpg: 24
# Preprocessing: EI27.jpg: 25
# Preprocessing: EI28.jpg: 26
# Preprocessing: EI29.jpg: 27
# Preprocessing: EI3.jpg: 28
# Preprocessing: EI30.jpg: 29
# Preprocessing: EI31.jpg: 30
# Preprocessing: EI32.jpg: 31
# Preprocessing: EI33.jpg: 32
# Preprocessing: EI34.jpg: 33
# Preprocessing: EI35.jpg: 34
# Preprocessing: EI36.jpg: 35
# Preprocessing: EI4.jpg: 36
# Preprocessing: EI8.jpg: 37
# Preprocessing: EP19.jpg: 38
# Preprocessing: EP22.jpg: 39
# Preprocessing: EP23.jpg: 40
# Preprocessing: EP24.jpg: 41
# Preprocessing: EP3.jpg: 42
# Preprocessing: EP31.jpg: 43
# Preprocessing: EP32.jpg: 44
# Preprocessing: EP4.jpg: 45
# Preprocessing: EP5.jpg: 46
# Preprocessing: EP6.jpg: 47
# Preprocessing: O2.jpg: 48
# Preprocessing: O3.jpg: 49
# Preprocessing: O4.jpg: 50
# Preprocessing: OV2.jpg: 51
# Preprocessing: OV3.jpg: 52
# Preprocessing: OV4.jpg: 53
# Preprocessing: OV5.jpg: 54
# Preprocessing: OV6.jpg: 55
# Preprocessing: OV8.jpg: 56
# Preprocessing: OV9.jpg: 57
# Preprocessing: PR37.jpg: 58
# Preprocessing: PR38.jpg: 59
# Preprocessing: PR39.jpg: 60
# Preprocessing: TR1.jpg: 61
# Preprocessing: TR151.jpg: 62
# Preprocessing: TR162.jpg: 63
# Preprocessing: TR2.jpg: 64
# Preprocessing: TR3.jpg: 65
# Preprocessing: U1.jpg: 66
# Preprocessing: U10.jpg: 67
# Preprocessing: U100.jpg: 68
# Preprocessing: U101.jpg: 69
# Preprocessing: U102.jpg: 70
# Preprocessing: U103.jpg: 71
# Preprocessing: U104.jpg: 72
# Preprocessing: U105.jpg: 73
# Preprocessing: U106.jpg: 74
# Preprocessing: U108.jpg: 75
# Preprocessing: U109.jpg: 76
# Preprocessing: U11.jpg: 77
# Preprocessing: U110.jpg: 78
# Preprocessing: U111.jpg: 79
# Preprocessing: U112.jpg: 80
# Preprocessing: U113.jpg: 81
# Preprocessing: U114.jpg: 82
# Preprocessing: U115.jpg: 83
# Preprocessing: U116.jpg: 84
# Preprocessing: U117.jpg: 85
# Preprocessing: U118.jpg: 86
# Preprocessing: U119.jpg: 87
# Preprocessing: U12.jpg: 88
# Preprocessing: U120.jpg: 89
# Preprocessing: U121.jpg: 90
# Preprocessing: U122.jpg: 91
# Preprocessing: U123.jpg: 92
# Preprocessing: U124.jpg: 93
# Preprocessing: U125.jpg: 94
# Preprocessing: U126.jpg: 95
# Preprocessing: U127.jpg: 96
# Preprocessing: U128.jpg: 97
# Preprocessing: U129.jpg: 98
# Preprocessing: U13.jpg: 99
# Preprocessing: U130.jpg: 100
# Preprocessing: U131.jpg: 101
# Preprocessing: U132.jpg: 102
# Preprocessing: U133.jpg: 103
# Preprocessing: U134.jpg: 104
# Preprocessing: U135.jpg: 105
# Preprocessing: U136.jpg: 106
# Preprocessing: U137.jpg: 107
# Preprocessing: U138.jpg: 108
# Preprocessing: U139.jpg: 109
# Preprocessing: U14.jpg: 110
# Preprocessing: U140.jpg: 111
# Preprocessing: U141.jpg: 112
# Preprocessing: U142.jpg: 113
# Preprocessing: U143.jpg: 114
# Preprocessing: U144.jpg: 115
# Preprocessing: U145.jpg: 116
# Preprocessing: U146.jpg: 117
# Preprocessing: U147.jpg: 118
# Preprocessing: U148.jpg: 119
# Preprocessing: U149.jpg: 120
# Preprocessing: U15.jpg: 121
# Preprocessing: U150.jpg: 122
# Preprocessing: U151.jpg: 123
# Preprocessing: U152.jpg: 124
# Preprocessing: U153.jpg: 125
# Preprocessing: U154.jpg: 126
# Preprocessing: U155.jpg: 127
# Preprocessing: U156.jpg: 128
# Preprocessing: U157.jpg: 129
# Preprocessing: U158.jpg: 130
# Preprocessing: U159.jpg: 131
# Preprocessing: U16.jpg: 132
# Preprocessing: U160.jpg: 133
# Preprocessing: U161.jpg: 134
# Preprocessing: U162.jpg: 135
# Preprocessing: U163.jpg: 136
# Preprocessing: U164.jpg: 137
# Preprocessing: U165.jpg: 138
# Preprocessing: U166.jpg: 139
# Preprocessing: U167.jpg: 140
# Preprocessing: U168.jpg: 141
# Preprocessing: U169.jpg: 142
# Preprocessing: U17.jpg: 143
# Preprocessing: U170.jpg: 144
# Preprocessing: U171.jpg: 145
# Preprocessing: U172.jpg: 146
# Preprocessing: U173.jpg: 147
# Preprocessing: U174.jpg: 148
# Preprocessing: U175.jpg: 149
# Preprocessing: U176.jpg: 150
# Preprocessing: U178.jpg: 151
# Preprocessing: U179.jpg: 152
# Preprocessing: U18.jpg: 153
# Preprocessing: U180.jpg: 154
# Preprocessing: U181.jpg: 155
# Preprocessing: U182.jpg: 156
# Preprocessing: U183.jpg: 157
# Preprocessing: U185.jpg: 158
# Preprocessing: U186.jpg: 159
# Preprocessing: U187.jpg: 160
# Preprocessing: U188.jpg: 161
# Preprocessing: U189.jpg: 162
# Preprocessing: U19.jpg: 163
# Preprocessing: U190.jpg: 164
# Preprocessing: U191.jpg: 165
# Preprocessing: U192.jpg: 166
# Preprocessing: U193.jpg: 167
# Preprocessing: U195.jpg: 168
# Preprocessing: U198.jpg: 169
# Preprocessing: U199.jpg: 170
# Preprocessing: U2.jpg: 171
# Preprocessing: U20.jpg: 172
# Preprocessing: U201.jpg: 173
# Preprocessing: U202.jpg: 174
# Preprocessing: U203.jpg: 175
# Preprocessing: U204.jpg: 176
# Preprocessing: U205.jpg: 177
# Preprocessing: U206.jpg: 178
# Preprocessing: U207.jpg: 179
# Preprocessing: U208.jpg: 180
# Preprocessing: U209.jpg: 181
# Preprocessing: U21.jpg: 182
# Preprocessing: U210.jpg: 183
# Preprocessing: U211.jpg: 184
# Preprocessing: U212.jpg: 185
# Preprocessing: U215.jpg: 186
# Preprocessing: U216.jpg: 187
# Preprocessing: U217.jpg: 188
# Preprocessing: U218.jpg: 189
# Preprocessing: U219.jpg: 190
# Preprocessing: U22.jpg: 191
# Preprocessing: U220.jpg: 192
# Preprocessing: U221.jpg: 193
# Preprocessing: U224.jpg: 194
# Preprocessing: U226.jpg: 195
# Preprocessing: U227.jpg: 196
# Preprocessing: U228.jpg: 197
# Preprocessing: U229.jpg: 198
# Preprocessing: U23.jpg: 199
# Preprocessing: U230.jpg: 200
# Preprocessing: U231.jpg: 201
# Preprocessing: U232.jpg: 202
# Preprocessing: U235.jpg: 203
# Preprocessing: U236.jpg: 204
# Preprocessing: U24.jpg: 205
# Preprocessing: U243.jpg: 206
# Preprocessing: U245.jpg: 207
# Preprocessing: U247.jpg: 208
# Preprocessing: U248.jpg: 209
# Preprocessing: U249.jpg: 210
# Preprocessing: U25.jpg: 211
# Preprocessing: U26.jpg: 212
# Preprocessing: U262.jpg: 213
# Preprocessing: U263.jpg: 214
# Preprocessing: U264.jpg: 215
# Preprocessing: U266.jpg: 216
# Preprocessing: U268.jpg: 217
# Preprocessing: U269.jpg: 218
# Preprocessing: U27.jpg: 219
# Preprocessing: U271.jpg: 220
# Preprocessing: U272.jpg: 221
# Preprocessing: U273.jpg: 222
# Preprocessing: U274.jpg: 223
# Preprocessing: U275.jpg: 224
# Preprocessing: U276.jpg: 225
# Preprocessing: U277.jpg: 226
# Preprocessing: U278.jpg: 227
# Preprocessing: U279.jpg: 228
# Preprocessing: U28.jpg: 229
# Preprocessing: U281.jpg: 230
# Preprocessing: U282.jpg: 231
# Preprocessing: U287.jpg: 232
# Preprocessing: U288.jpg: 233
# Preprocessing: U29.jpg: 234
# Preprocessing: U292.jpg: 235
# Preprocessing: U293.jpg: 236
# Preprocessing: U294.jpg: 237
# Preprocessing: U295.jpg: 238
# Preprocessing: U296.jpg: 239
# Preprocessing: U297.jpg: 240
# Preprocessing: U298.jpg: 241
# Preprocessing: U299.jpg: 242
# Preprocessing: U3.jpg: 243
# Preprocessing: U30.jpg: 244
# Preprocessing: U300.jpg: 245
# Preprocessing: U301.jpg: 246
# Preprocessing: U303.jpg: 247
# Preprocessing: U306.jpg: 248
# Preprocessing: U307.jpg: 249
# Preprocessing: U309.jpg: 250
# Preprocessing: U31.jpg: 251
# Preprocessing: U310.jpg: 252
# Preprocessing: U311.jpg: 253
# Preprocessing: U313.jpg: 254
# Preprocessing: U314.jpg: 255
# Preprocessing: U315.jpg: 256
# Preprocessing: U316.jpg: 257
# Preprocessing: U317.jpg: 258
# Preprocessing: U318.jpg: 259
# Preprocessing: U319.jpg: 260
# Preprocessing: U32.jpg: 261
# Preprocessing: U320.jpg: 262
# Preprocessing: U321.jpg: 263
# Preprocessing: U322.jpg: 264
# Preprocessing: U323.jpg: 265
# Preprocessing: U33.jpg: 266
# Preprocessing: U330.jpg: 267
# Preprocessing: U331.jpg: 268
# Preprocessing: U333.jpg: 269
# Preprocessing: U336.jpg: 270
# Preprocessing: U337.jpg: 271
# Preprocessing: U338.jpg: 272
# Preprocessing: U34.jpg: 273
# Preprocessing: U344.jpg: 274
# Preprocessing: U345.jpg: 275
# Preprocessing: U346.jpg: 276
# Preprocessing: U347.jpg: 277
# Preprocessing: U35.jpg: 278
# Preprocessing: U36.jpg: 279
# Preprocessing: U360.jpg: 280
# Preprocessing: U363.jpg: 281
# Preprocessing: U366.jpg: 282
# Preprocessing: U367.jpg: 283
# Preprocessing: U368.jpg: 284
# Preprocessing: U369.jpg: 285
# Preprocessing: U37.jpg: 286
# Preprocessing: U370.jpg: 287
# Preprocessing: U371.jpg: 288
# Preprocessing: U373.jpg: 289
# Preprocessing: U377.jpg: 290
# Preprocessing: U378.jpg: 291
# Preprocessing: U379.jpg: 292
# Preprocessing: U38.jpg: 293
# Preprocessing: U380.jpg: 294
# Preprocessing: U381.jpg: 295
# Preprocessing: U383.jpg: 296
# Preprocessing: U384.jpg: 297
# Preprocessing: U385.jpg: 298
# Preprocessing: U386.jpg: 299
# Preprocessing: U387.jpg: 300
# Preprocessing: U388.jpg: 301
# Preprocessing: U389.jpg: 302
# Preprocessing: U39.jpg: 303
# Preprocessing: U390.jpg: 304
# Preprocessing: U391.jpg: 305
# Preprocessing: U392.jpg: 306
# Preprocessing: U395.jpg: 307
# Preprocessing: U396.jpg: 308
# Preprocessing: U397.jpg: 309
# Preprocessing: U398.jpg: 310
# Preprocessing: U399.jpg: 311
# Preprocessing: U4.jpg: 312
# Preprocessing: U40.jpg: 313
# Preprocessing: U400.jpg: 314
# Preprocessing: U401.jpg: 315
# Preprocessing: U402.jpg: 316
# Preprocessing: U403.jpg: 317
# Preprocessing: U404.jpg: 318
# Preprocessing: U408.jpg: 319
# Preprocessing: U409.jpg: 320
# Preprocessing: U41.jpg: 321
# Preprocessing: U410.jpg: 322
# Preprocessing: U411.jpg: 323
# Preprocessing: U413.jpg: 324
# Preprocessing: U415.jpg: 325
# Preprocessing: U416.jpg: 326
# Preprocessing: U418.jpg: 327
# Preprocessing: U419.jpg: 328
# Preprocessing: U42.jpg: 329
# Preprocessing: U420.jpg: 330
# Preprocessing: U427.jpg: 331
# Preprocessing: U428.jpg: 332
# Preprocessing: U429.jpg: 333
# Preprocessing: U43.jpg: 334
# Preprocessing: U430.jpg: 335
# Preprocessing: U431.jpg: 336
# Preprocessing: U432.jpg: 337
# Preprocessing: U435.jpg: 338
# Preprocessing: U439.jpg: 339
# Preprocessing: U44.jpg: 340
# Preprocessing: U440.jpg: 341
# Preprocessing: U441.jpg: 342
# Preprocessing: U442.jpg: 343
# Preprocessing: U443.jpg: 344
# Preprocessing: U444.jpg: 345
# Preprocessing: U445.jpg: 346
# Preprocessing: U446.jpg: 347
# Preprocessing: U447.jpg: 348
# Preprocessing: U448.jpg: 349
# Preprocessing: U449.jpg: 350
# Preprocessing: U45.jpg: 351
# Preprocessing: U450.jpg: 352
# Preprocessing: U453.jpg: 353
# Preprocessing: U454.jpg: 354
# Preprocessing: U455.jpg: 355
# Preprocessing: U456.jpg: 356
# Preprocessing: U457.jpg: 357
# Preprocessing: U458.jpg: 358
# Preprocessing: U459.jpg: 359
# Preprocessing: U46.jpg: 360
# Preprocessing: U460.jpg: 361
# Preprocessing: U461.jpg: 362
# Preprocessing: U462.jpg: 363
# Preprocessing: U463.jpg: 364
# Preprocessing: U464.jpg: 365
# Preprocessing: U469.jpg: 366
# Preprocessing: U47.jpg: 367
# Preprocessing: U471.jpg: 368
# Preprocessing: U474.jpg: 369
# Preprocessing: U475.jpg: 370
# Preprocessing: U478.jpg: 371
# Preprocessing: U479.jpg: 372
# Preprocessing: U48.jpg: 373
# Preprocessing: U480.jpg: 374
# Preprocessing: U481.jpg: 375
# Preprocessing: U482.jpg: 376
# Preprocessing: U484.jpg: 377
# Preprocessing: U485.jpg: 378
# Preprocessing: U486.jpg: 379
# Preprocessing: U488.jpg: 380
# Preprocessing: U489.jpg: 381
# Preprocessing: U49.jpg: 382
# Preprocessing: U490.jpg: 383
# Preprocessing: U493.jpg: 384
# Preprocessing: U494.jpg: 385
# Preprocessing: U495.jpg: 386
# Preprocessing: U496.jpg: 387
# Preprocessing: U497.jpg: 388
# Preprocessing: U498.jpg: 389
# Preprocessing: U499.jpg: 390
# Preprocessing: U5.jpg: 391
# Preprocessing: U50.jpg: 392
# Preprocessing: U501.jpg: 393
# Preprocessing: U502.jpg: 394
# Preprocessing: U505.jpg: 395
# Preprocessing: U506.jpg: 396
# Preprocessing: U507.jpg: 397
# Preprocessing: U508.jpg: 398
# Preprocessing: U509.jpg: 399
# Preprocessing: U51.jpg: 400
# Preprocessing: U510.jpg: 401
# Preprocessing: U511.jpg: 402
# Preprocessing: U512.jpg: 403
# Preprocessing: U513.jpg: 404
# Preprocessing: U514.jpg: 405
# Preprocessing: U515.jpg: 406
# Preprocessing: U516.jpg: 407
# Preprocessing: U517.jpg: 408
# Preprocessing: U518.jpg: 409
# Preprocessing: U519.jpg: 410
# Preprocessing: U52.jpg: 411
# Preprocessing: U520.jpg: 412
# Preprocessing: U521.jpg: 413
# Preprocessing: U522.jpg: 414
# Preprocessing: U523.jpg: 415
# Preprocessing: U524.jpg: 416
# Preprocessing: U525.jpg: 417
# Preprocessing: U526.jpg: 418
# Preprocessing: U527.jpg: 419
# Preprocessing: U528.jpg: 420
# Preprocessing: U529.jpg: 421
# Preprocessing: U53.jpg: 422
# Preprocessing: U534.jpg: 423
# Preprocessing: U535.jpg: 424
# Preprocessing: U536.jpg: 425
# Preprocessing: U537.jpg: 426
# Preprocessing: U538.jpg: 427
# Preprocessing: U539.jpg: 428
# Preprocessing: U54.jpg: 429
# Preprocessing: U540.jpg: 430
# Preprocessing: U541.jpg: 431
# Preprocessing: U542.jpg: 432
# Preprocessing: U543.jpg: 433
# Preprocessing: U544.jpg: 434
# Preprocessing: U545.jpg: 435
# Preprocessing: U546.jpg: 436
# Preprocessing: U547.jpg: 437
# Preprocessing: U548.jpg: 438
# Preprocessing: U549.jpg: 439
# Preprocessing: U55.jpg: 440
# Preprocessing: U550.jpg: 441
# Preprocessing: U551.jpg: 442
# Preprocessing: U552.jpg: 443
# Preprocessing: U553.jpg: 444
# Preprocessing: U554.jpg: 445
# Preprocessing: U555.jpg: 446
# Preprocessing: U556.jpg: 447
# Preprocessing: U557.jpg: 448
# Preprocessing: U558.jpg: 449
# Preprocessing: U559.jpg: 450
# Preprocessing: U56.jpg: 451
# Preprocessing: U560.jpg: 452
# Preprocessing: U561.jpg: 453
# Preprocessing: U562.jpg: 454
# Preprocessing: U563.jpg: 455
# Preprocessing: U564.jpg: 456
# Preprocessing: U565.jpg: 457
# Preprocessing: U566.jpg: 458
# Preprocessing: U567.jpg: 459
# Preprocessing: U568.jpg: 460
# Preprocessing: U569.jpg: 461
# Preprocessing: U57.jpg: 462
# Preprocessing: U570.jpg: 463
# Preprocessing: U572.jpg: 464
# Preprocessing: U573.jpg: 465
# Preprocessing: U574.jpg: 466
# Preprocessing: U575.jpg: 467
# Preprocessing: U576.jpg: 468
# Preprocessing: U577.jpg: 469
# Preprocessing: U578.jpg: 470
# Preprocessing: U579.jpg: 471
# Preprocessing: U58.jpg: 472
# Preprocessing: U580.jpg: 473
# Preprocessing: U581.jpg: 474
# Preprocessing: U582.jpg: 475
# Preprocessing: U583.jpg: 476
# Preprocessing: U584.jpg: 477
# Preprocessing: U585.jpg: 478
# Preprocessing: U586.jpg: 479
# Preprocessing: U587.jpg: 480
# Preprocessing: U588.jpg: 481
# Preprocessing: U589.jpg: 482
# Preprocessing: U59.jpg: 483
# Preprocessing: U590.jpg: 484
# Preprocessing: U591.jpg: 485
# Preprocessing: U592.jpg: 486
# Preprocessing: U593.jpg: 487
# Preprocessing: U594.jpg: 488
# Preprocessing: U595.jpg: 489
# Preprocessing: U596.jpg: 490
# Preprocessing: U597.jpg: 491
# Preprocessing: U598.jpg: 492
# Preprocessing: U599.jpg: 493
# Preprocessing: U6.jpg: 494
# Preprocessing: U60.jpg: 495
# Preprocessing: U600.jpg: 496
# Preprocessing: U601.jpg: 497
# Preprocessing: U602.jpg: 498
# Preprocessing: U603.jpg: 499
# Preprocessing: U604.jpg: 500
# Preprocessing: U605.jpg: 501
# Preprocessing: U606.jpg: 502
# Preprocessing: U607.jpg: 503
# Preprocessing: U608.jpg: 504
# Preprocessing: U609.jpg: 505
# Preprocessing: U61.jpg: 506
# Preprocessing: U610.jpg: 507
# Preprocessing: U611.jpg: 508
# Preprocessing: U612.jpg: 509
# Preprocessing: U613.jpg: 510
# Preprocessing: U614.jpg: 511
# Preprocessing: U615.jpg: 512
# Preprocessing: U616.jpg: 513
# Preprocessing: U617.jpg: 514
# Preprocessing: U618.jpg: 515
# Preprocessing: U619.jpg: 516
# Preprocessing: U62.jpg: 517
# Preprocessing: U620.jpg: 518
# Preprocessing: U621.jpg: 519
# Preprocessing: U622.jpg: 520
# Preprocessing: U623.jpg: 521
# Preprocessing: U624.jpg: 522
# Preprocessing: U625.jpg: 523
# Preprocessing: U626.jpg: 524
# Preprocessing: U627.jpg: 525
# Preprocessing: U628.jpg: 526
# Preprocessing: U629.jpg: 527
# Preprocessing: U63.jpg: 528
# Preprocessing: U630.jpg: 529
# Preprocessing: U631.jpg: 530
# Preprocessing: U632.jpg: 531
# Preprocessing: U633.jpg: 532
# Preprocessing: U634.jpg: 533
# Preprocessing: U635.jpg: 534
# Preprocessing: U636.jpg: 535
# Preprocessing: U637.jpg: 536
# Preprocessing: U638.jpg: 537
# Preprocessing: U639.jpg: 538
# Preprocessing: U64.jpg: 539
# Preprocessing: U640.jpg: 540
# Preprocessing: U641.jpg: 541
# Preprocessing: U642.jpg: 542
# Preprocessing: U643.jpg: 543
# Preprocessing: U644.jpg: 544
# Preprocessing: U645.jpg: 545
# Preprocessing: U646.jpg: 546
# Preprocessing: U648.jpg: 547
# Preprocessing: U649.jpg: 548
# Preprocessing: U65.jpg: 549
# Preprocessing: U650.jpg: 550
# Preprocessing: U652.jpg: 551
# Preprocessing: U653.jpg: 552
# Preprocessing: U654.jpg: 553
# Preprocessing: U655.jpg: 554
# Preprocessing: U656.jpg: 555
# Preprocessing: U657.jpg: 556
# Preprocessing: U658.jpg: 557
# Preprocessing: U659.jpg: 558
# Preprocessing: U66.jpg: 559
# Preprocessing: U660.jpg: 560
# Preprocessing: U662.jpg: 561
# Preprocessing: U663.jpg: 562
# Preprocessing: U664.jpg: 563
# Preprocessing: U665.jpg: 564
# Preprocessing: U666.jpg: 565
# Preprocessing: U667.jpg: 566
# Preprocessing: U668.jpg: 567
# Preprocessing: U669.jpg: 568
# Preprocessing: U67.jpg: 569
# Preprocessing: U670.jpg: 570
# Preprocessing: U671.jpg: 571
# Preprocessing: U672.jpg: 572
# Preprocessing: U673.jpg: 573
# Preprocessing: U674.jpg: 574
# Preprocessing: U675.jpg: 575
# Preprocessing: U676.jpg: 576
# Preprocessing: U678.jpg: 577
# Preprocessing: U679.jpg: 578
# Preprocessing: U68.jpg: 579
# Preprocessing: U680.jpg: 580
# Preprocessing: U681.jpg: 581
# Preprocessing: U682.jpg: 582
# Preprocessing: U69.jpg: 583
# Preprocessing: U7.jpg: 584
# Preprocessing: U70.jpg: 585
# Preprocessing: U71.jpg: 586
# Preprocessing: U73.jpg: 587
# Preprocessing: U74.jpg: 588
# Preprocessing: U75.jpg: 589
# Preprocessing: U76.jpg: 590
# Preprocessing: U77.jpg: 591
# Preprocessing: U78.jpg: 592
# Preprocessing: U79.jpg: 593
# Preprocessing: U8.jpg: 594
# Preprocessing: U81.jpg: 595
# Preprocessing: U82.jpg: 596
# Preprocessing: U83.jpg: 597
# Preprocessing: U84.jpg: 598
# Preprocessing: U85.jpg: 599
# Preprocessing: U86.jpg: 600
# Preprocessing: U9.jpg: 601
# Preprocessing: U91.jpg: 602
# Preprocessing: U92.jpg: 603
# Preprocessing: U93.jpg: 604
# Preprocessing: U94.jpg: 605
# Preprocessing: U98.jpg: 606
# Preprocessing: U99.jpg: 607
