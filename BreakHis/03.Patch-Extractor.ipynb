# %%
import cv2 as cv
import os
import random
from skimage import transform
import numpy as np

def read_image(path):
    """
    Read an image to RGB uint8
    :param path:
    :return:
    """
    im = cv.imread(path)
    im = cv.cvtColor(im, cv.COLOR_BGR2RGB)
    return im


def i2str(i):
    """
    Convert an integer <=999 to a string
    :param i:
    :return:
    """
    s = str(i)
    if len(s) == 1:
        return '00' + s
    elif len(s) == 2:
        return '0' + s
    else:
        return s


def save_aspng(im, full_save_path, compression=3):
    """
    Save an image as png with optional compression (not sure this works!). Specify full_save_path e.g. '/home/peter/mypic.png'. Directory is built if not present.
    :param im:
    :param full_save_path:
    :param compression:
    :return:
    """
    os.makedirs(os.path.dirname(full_save_path), exist_ok=True)
    if len(im.shape) == 3:
        im = cv.cvtColor(im, cv.COLOR_RGB2BGR)
    cv.imwrite(full_save_path, im, [cv.IMWRITE_PNG_COMPRESSION, compression])

# %%
data_dir = 'data/'
save_dir_train = data_dir + 'train_patched'
save_dir_val = data_dir + 'validation_patched'
save_dir_test = data_dir + 'test_patched'


classes = ('Benign', 'InSitu', 'Invasive', 'Normal')
prefixes = {'Benign': 'b', 'InSitu': 'is', 'Invasive': 'iv', 'Normal': 'n'}

perm = np.random.permutation(100)
train_idx = perm[:60]
val_idx = perm[60:80]
test_idx = perm[80:]

# %%
def get_patches(img, save_path_sub):
    cnt = 1
    for i in range(5):
        for j in range(7):
            patch = img[256 * i:256 * i + 512, 256 * j:256 * j + 512]
            save_aspng(patch, save_path_sub + '_patch' + i2str(cnt) + '.png', compression=1)
            cnt += 1


###

for c in classes:
    for i in train_idx:
        filename = prefixes[c] + i2str(i + 1) + '.tif'
        print('Doing Image {}'.format(filename))
        path = os.path.join(data_dir, c, filename)
#         print(path)
        image = read_image(path)

        sub = os.path.join(save_dir_train, c, prefixes[c] + i2str(i + 1))
        print (sub)
        get_patches(image, sub)

for c in classes:
    for i in val_idx:
        filename = prefixes[c] + i2str(i + 1) + '.tif'
        print('Doing Image {}'.format(filename))
        path = os.path.join(data_dir, c, filename)
        image = read_image(path)

        sub = os.path.join(save_dir_val, c, prefixes[c] + i2str(i + 1))
        get_patches(image, sub)

for c in classes:
    for i in test_idx:
        filename = prefixes[c] + i2str(i + 1) + '.tif'
        print('Doing Image {}'.format(filename))
        path = os.path.join(data_dir, c, filename)
        image = read_image(path)

        sub = os.path.join(save_dir_test, c, prefixes[c] + i2str(i + 1))
        save_aspng(image, sub + '.png', compression=1)
# Out:
# Doing Image b085.tif
# data/train_patched/Benign/b085
# Doing Image b043.tif
# data/train_patched/Benign/b043
# Doing Image b065.tif
# data/train_patched/Benign/b065
# Doing Image b005.tif
# data/train_patched/Benign/b005
# Doing Image b091.tif
# data/train_patched/Benign/b091
# Doing Image b003.tif
# data/train_patched/Benign/b003
# Doing Image b075.tif
# data/train_patched/Benign/b075
# Doing Image b036.tif
# data/train_patched/Benign/b036
# Doing Image b034.tif
# data/train_patched/Benign/b034
# Doing Image b070.tif
# data/train_patched/Benign/b070
# Doing Image b001.tif
# data/train_patched/Benign/b001
# Doing Image b054.tif
# data/train_patched/Benign/b054
# Doing Image b023.tif
# data/train_patched/Benign/b023
# Doing Image b002.tif
# data/train_patched/Benign/b002
# Doing Image b042.tif
# data/train_patched/Benign/b042
# Doing Image b012.tif
# data/train_patched/Benign/b012
# Doing Image b059.tif
# data/train_patched/Benign/b059
# Doing Image b013.tif
# data/train_patched/Benign/b013
# Doing Image b090.tif
# data/train_patched/Benign/b090
# Doing Image b015.tif
# data/train_patched/Benign/b015
# Doing Image b097.tif
# data/train_patched/Benign/b097
# Doing Image b020.tif
# data/train_patched/Benign/b020
# Doing Image b031.tif
# data/train_patched/Benign/b031
# Doing Image b033.tif
# data/train_patched/Benign/b033
# Doing Image b006.tif
# data/train_patched/Benign/b006
# Doing Image b088.tif
# data/train_patched/Benign/b088
# Doing Image b032.tif
# data/train_patched/Benign/b032
# Doing Image b038.tif
# data/train_patched/Benign/b038
# Doing Image b089.tif
# data/train_patched/Benign/b089
# Doing Image b056.tif
# data/train_patched/Benign/b056
# Doing Image b053.tif
# data/train_patched/Benign/b053
# Doing Image b018.tif
# data/train_patched/Benign/b018
# Doing Image b055.tif
# data/train_patched/Benign/b055
# Doing Image b062.tif
# data/train_patched/Benign/b062
# Doing Image b051.tif
# data/train_patched/Benign/b051
# Doing Image b041.tif
# data/train_patched/Benign/b041
# Doing Image b061.tif
# data/train_patched/Benign/b061
# Doing Image b025.tif
# data/train_patched/Benign/b025
# Doing Image b057.tif
# data/train_patched/Benign/b057
# Doing Image b011.tif
# data/train_patched/Benign/b011
# Doing Image b030.tif
# data/train_patched/Benign/b030
# Doing Image b100.tif
# data/train_patched/Benign/b100
# Doing Image b095.tif
# data/train_patched/Benign/b095
# Doing Image b071.tif
# data/train_patched/Benign/b071
# Doing Image b086.tif
# data/train_patched/Benign/b086
# Doing Image b009.tif
# data/train_patched/Benign/b009
# Doing Image b084.tif
# data/train_patched/Benign/b084
# Doing Image b014.tif
# data/train_patched/Benign/b014
# Doing Image b010.tif
# data/train_patched/Benign/b010
# Doing Image b028.tif
# data/train_patched/Benign/b028
# Doing Image b069.tif
# data/train_patched/Benign/b069
# Doing Image b016.tif
# data/train_patched/Benign/b016
# Doing Image b037.tif
# data/train_patched/Benign/b037
# Doing Image b064.tif
# data/train_patched/Benign/b064
# Doing Image b021.tif
# data/train_patched/Benign/b021
# Doing Image b072.tif
# data/train_patched/Benign/b072
# Doing Image b083.tif
# data/train_patched/Benign/b083
# Doing Image b079.tif
# data/train_patched/Benign/b079
# Doing Image b046.tif
# data/train_patched/Benign/b046
# Doing Image b029.tif
# data/train_patched/Benign/b029
# Doing Image is085.tif
# data/train_patched/InSitu/is085
# Doing Image is043.tif
# data/train_patched/InSitu/is043
# Doing Image is065.tif
# data/train_patched/InSitu/is065
# Doing Image is005.tif
# data/train_patched/InSitu/is005
# Doing Image is091.tif
# data/train_patched/InSitu/is091
# Doing Image is003.tif
# data/train_patched/InSitu/is003
# Doing Image is075.tif
# data/train_patched/InSitu/is075
# Doing Image is036.tif
# data/train_patched/InSitu/is036
# Doing Image is034.tif
# data/train_patched/InSitu/is034
# Doing Image is070.tif
# data/train_patched/InSitu/is070
# Doing Image is001.tif
# data/train_patched/InSitu/is001
# Doing Image is054.tif
# data/train_patched/InSitu/is054
# Doing Image is023.tif
# data/train_patched/InSitu/is023
# Doing Image is002.tif
# data/train_patched/InSitu/is002
# Doing Image is042.tif
# data/train_patched/InSitu/is042
# Doing Image is012.tif
# data/train_patched/InSitu/is012
# Doing Image is059.tif
# data/train_patched/InSitu/is059
# Doing Image is013.tif
# data/train_patched/InSitu/is013
# Doing Image is090.tif
# data/train_patched/InSitu/is090
# Doing Image is015.tif
# data/train_patched/InSitu/is015
# Doing Image is097.tif
# data/train_patched/InSitu/is097
# Doing Image is020.tif
# data/train_patched/InSitu/is020
# Doing Image is031.tif
# data/train_patched/InSitu/is031
# Doing Image is033.tif
# data/train_patched/InSitu/is033
# Doing Image is006.tif
# data/train_patched/InSitu/is006
# Doing Image is088.tif
# data/train_patched/InSitu/is088
# Doing Image is032.tif
# data/train_patched/InSitu/is032
# Doing Image is038.tif
# data/train_patched/InSitu/is038
# Doing Image is089.tif
# data/train_patched/InSitu/is089
# Doing Image is056.tif
# data/train_patched/InSitu/is056
# Doing Image is053.tif
# data/train_patched/InSitu/is053
# Doing Image is018.tif
# data/train_patched/InSitu/is018
# Doing Image is055.tif
# data/train_patched/InSitu/is055
# Doing Image is062.tif
# data/train_patched/InSitu/is062
# Doing Image is051.tif
# data/train_patched/InSitu/is051
# Doing Image is041.tif
# data/train_patched/InSitu/is041
# Doing Image is061.tif
# data/train_patched/InSitu/is061
# Doing Image is025.tif
# data/train_patched/InSitu/is025
# Doing Image is057.tif
# data/train_patched/InSitu/is057
# Doing Image is011.tif
# data/train_patched/InSitu/is011
# Doing Image is030.tif
# data/train_patched/InSitu/is030
# Doing Image is100.tif
# data/train_patched/InSitu/is100
# Doing Image is095.tif
# data/train_patched/InSitu/is095
# Doing Image is071.tif
# data/train_patched/InSitu/is071
# Doing Image is086.tif
# data/train_patched/InSitu/is086
# Doing Image is009.tif
# data/train_patched/InSitu/is009
# Doing Image is084.tif
# data/train_patched/InSitu/is084
# Doing Image is014.tif
# data/train_patched/InSitu/is014
# Doing Image is010.tif
# data/train_patched/InSitu/is010
# Doing Image is028.tif
# data/train_patched/InSitu/is028
# Doing Image is069.tif
# data/train_patched/InSitu/is069
# Doing Image is016.tif
# data/train_patched/InSitu/is016
# Doing Image is037.tif
# data/train_patched/InSitu/is037
# Doing Image is064.tif
# data/train_patched/InSitu/is064
# Doing Image is021.tif
# data/train_patched/InSitu/is021
# Doing Image is072.tif
# data/train_patched/InSitu/is072
# Doing Image is083.tif
# data/train_patched/InSitu/is083
# Doing Image is079.tif
# data/train_patched/InSitu/is079
# Doing Image is046.tif
# data/train_patched/InSitu/is046
# Doing Image is029.tif
# data/train_patched/InSitu/is029
# Doing Image iv085.tif
# data/train_patched/Invasive/iv085
# Doing Image iv043.tif
# data/train_patched/Invasive/iv043
# Doing Image iv065.tif
# data/train_patched/Invasive/iv065
# Doing Image iv005.tif
# data/train_patched/Invasive/iv005
# Doing Image iv091.tif
# data/train_patched/Invasive/iv091
# Doing Image iv003.tif
# data/train_patched/Invasive/iv003
# Doing Image iv075.tif
# data/train_patched/Invasive/iv075
# Doing Image iv036.tif
# data/train_patched/Invasive/iv036
# Doing Image iv034.tif
# data/train_patched/Invasive/iv034
# Doing Image iv070.tif
# data/train_patched/Invasive/iv070
# Doing Image iv001.tif
# data/train_patched/Invasive/iv001
# Doing Image iv054.tif
# data/train_patched/Invasive/iv054
# Doing Image iv023.tif
# data/train_patched/Invasive/iv023
# Doing Image iv002.tif
# data/train_patched/Invasive/iv002
# Doing Image iv042.tif
# data/train_patched/Invasive/iv042
# Doing Image iv012.tif
# data/train_patched/Invasive/iv012
# Doing Image iv059.tif
# data/train_patched/Invasive/iv059
# Doing Image iv013.tif
# data/train_patched/Invasive/iv013
# Doing Image iv090.tif
# data/train_patched/Invasive/iv090
# Doing Image iv015.tif
# data/train_patched/Invasive/iv015
# Doing Image iv097.tif
# data/train_patched/Invasive/iv097
# Doing Image iv020.tif
# data/train_patched/Invasive/iv020
# Doing Image iv031.tif
# data/train_patched/Invasive/iv031
# Doing Image iv033.tif
# data/train_patched/Invasive/iv033
# Doing Image iv006.tif
# data/train_patched/Invasive/iv006
# Doing Image iv088.tif
# data/train_patched/Invasive/iv088
# Doing Image iv032.tif
# data/train_patched/Invasive/iv032
# Doing Image iv038.tif
# data/train_patched/Invasive/iv038
# Doing Image iv089.tif
# data/train_patched/Invasive/iv089
# Doing Image iv056.tif
# data/train_patched/Invasive/iv056
# Doing Image iv053.tif
# data/train_patched/Invasive/iv053
# Doing Image iv018.tif
# data/train_patched/Invasive/iv018
# Doing Image iv055.tif
# data/train_patched/Invasive/iv055
# Doing Image iv062.tif
# data/train_patched/Invasive/iv062
# Doing Image iv051.tif
# data/train_patched/Invasive/iv051
# Doing Image iv041.tif
# data/train_patched/Invasive/iv041
# Doing Image iv061.tif
# data/train_patched/Invasive/iv061
# Doing Image iv025.tif
# data/train_patched/Invasive/iv025
# Doing Image iv057.tif
# data/train_patched/Invasive/iv057
# Doing Image iv011.tif
# data/train_patched/Invasive/iv011
# Doing Image iv030.tif
# data/train_patched/Invasive/iv030
# Doing Image iv100.tif
# data/train_patched/Invasive/iv100
# Doing Image iv095.tif
# data/train_patched/Invasive/iv095
# Doing Image iv071.tif
# data/train_patched/Invasive/iv071
# Doing Image iv086.tif
# data/train_patched/Invasive/iv086
# Doing Image iv009.tif
# data/train_patched/Invasive/iv009
# Doing Image iv084.tif
# data/train_patched/Invasive/iv084
# Doing Image iv014.tif
# data/train_patched/Invasive/iv014
# Doing Image iv010.tif
# data/train_patched/Invasive/iv010
# Doing Image iv028.tif
# data/train_patched/Invasive/iv028
# Doing Image iv069.tif
# data/train_patched/Invasive/iv069
# Doing Image iv016.tif
# data/train_patched/Invasive/iv016
# Doing Image iv037.tif
# data/train_patched/Invasive/iv037
# Doing Image iv064.tif
# data/train_patched/Invasive/iv064
# Doing Image iv021.tif
# data/train_patched/Invasive/iv021
# Doing Image iv072.tif
# data/train_patched/Invasive/iv072
# Doing Image iv083.tif
# data/train_patched/Invasive/iv083
# Doing Image iv079.tif
# data/train_patched/Invasive/iv079
# Doing Image iv046.tif
# data/train_patched/Invasive/iv046
# Doing Image iv029.tif
# data/train_patched/Invasive/iv029
# Doing Image n085.tif
# data/train_patched/Normal/n085
# Doing Image n043.tif
# data/train_patched/Normal/n043
# Doing Image n065.tif
# data/train_patched/Normal/n065
# Doing Image n005.tif
# data/train_patched/Normal/n005
# Doing Image n091.tif
# data/train_patched/Normal/n091
# Doing Image n003.tif
# data/train_patched/Normal/n003
# Doing Image n075.tif
# data/train_patched/Normal/n075
# Doing Image n036.tif
# data/train_patched/Normal/n036
# Doing Image n034.tif
# data/train_patched/Normal/n034
# Doing Image n070.tif
# data/train_patched/Normal/n070
# Doing Image n001.tif
# data/train_patched/Normal/n001
# Doing Image n054.tif
# data/train_patched/Normal/n054
# Doing Image n023.tif
# data/train_patched/Normal/n023
# Doing Image n002.tif
# data/train_patched/Normal/n002
# Doing Image n042.tif
# data/train_patched/Normal/n042
# Doing Image n012.tif
# data/train_patched/Normal/n012
# Doing Image n059.tif
# data/train_patched/Normal/n059
# Doing Image n013.tif
# data/train_patched/Normal/n013
# Doing Image n090.tif
# data/train_patched/Normal/n090
# Doing Image n015.tif
# data/train_patched/Normal/n015
# Doing Image n097.tif
# data/train_patched/Normal/n097
# Doing Image n020.tif
# data/train_patched/Normal/n020
# Doing Image n031.tif
# data/train_patched/Normal/n031
# Doing Image n033.tif
# data/train_patched/Normal/n033
# Doing Image n006.tif
# data/train_patched/Normal/n006
# Doing Image n088.tif
# data/train_patched/Normal/n088
# Doing Image n032.tif
# data/train_patched/Normal/n032
# Doing Image n038.tif
# data/train_patched/Normal/n038
# Doing Image n089.tif
# data/train_patched/Normal/n089
# Doing Image n056.tif
# data/train_patched/Normal/n056
# Doing Image n053.tif
# data/train_patched/Normal/n053
# Doing Image n018.tif
# data/train_patched/Normal/n018
# Doing Image n055.tif
# data/train_patched/Normal/n055
# Doing Image n062.tif
# data/train_patched/Normal/n062
# Doing Image n051.tif
# data/train_patched/Normal/n051
# Doing Image n041.tif
# data/train_patched/Normal/n041
# Doing Image n061.tif
# data/train_patched/Normal/n061
# Doing Image n025.tif
# data/train_patched/Normal/n025
# Doing Image n057.tif
# data/train_patched/Normal/n057
# Doing Image n011.tif
# data/train_patched/Normal/n011
# Doing Image n030.tif
# data/train_patched/Normal/n030
# Doing Image n100.tif
# data/train_patched/Normal/n100
# Doing Image n095.tif
# data/train_patched/Normal/n095
# Doing Image n071.tif
# data/train_patched/Normal/n071
# Doing Image n086.tif
# data/train_patched/Normal/n086
# Doing Image n009.tif
# data/train_patched/Normal/n009
# Doing Image n084.tif
# data/train_patched/Normal/n084
# Doing Image n014.tif
# data/train_patched/Normal/n014
# Doing Image n010.tif
# data/train_patched/Normal/n010
# Doing Image n028.tif
# data/train_patched/Normal/n028
# Doing Image n069.tif
# data/train_patched/Normal/n069
# Doing Image n016.tif
# data/train_patched/Normal/n016
# Doing Image n037.tif
# data/train_patched/Normal/n037
# Doing Image n064.tif
# data/train_patched/Normal/n064
# Doing Image n021.tif
# data/train_patched/Normal/n021
# Doing Image n072.tif
# data/train_patched/Normal/n072
# Doing Image n083.tif
# data/train_patched/Normal/n083
# Doing Image n079.tif
# data/train_patched/Normal/n079
# Doing Image n046.tif
# data/train_patched/Normal/n046
# Doing Image n029.tif
# data/train_patched/Normal/n029
# Doing Image b027.tif
# Doing Image b039.tif
# Doing Image b078.tif
# Doing Image b098.tif
# Doing Image b099.tif
# Doing Image b077.tif
# Doing Image b008.tif
# Doing Image b047.tif
# Doing Image b058.tif
# Doing Image b080.tif
# Doing Image b087.tif
# Doing Image b066.tif
# Doing Image b045.tif
# Doing Image b022.tif
# Doing Image b073.tif
# Doing Image b076.tif
# Doing Image b082.tif
# Doing Image b060.tif
# Doing Image b050.tif
# Doing Image b004.tif
# Doing Image is027.tif
# Doing Image is039.tif
# Doing Image is078.tif
# Doing Image is098.tif
# Doing Image is099.tif
# Doing Image is077.tif
# Doing Image is008.tif
# Doing Image is047.tif
# Doing Image is058.tif
# Doing Image is080.tif
# Doing Image is087.tif
# Doing Image is066.tif
# Doing Image is045.tif
# Doing Image is022.tif
# Doing Image is073.tif
# Doing Image is076.tif
# Doing Image is082.tif
# Doing Image is060.tif
# Doing Image is050.tif
# Doing Image is004.tif
# Doing Image iv027.tif
# Doing Image iv039.tif
# Doing Image iv078.tif
# Doing Image iv098.tif
# Doing Image iv099.tif
# Doing Image iv077.tif
# Doing Image iv008.tif
# Doing Image iv047.tif
# Doing Image iv058.tif
# Doing Image iv080.tif
# Doing Image iv087.tif
# Doing Image iv066.tif
# Doing Image iv045.tif
# Doing Image iv022.tif
# Doing Image iv073.tif
# Doing Image iv076.tif
# Doing Image iv082.tif
# Doing Image iv060.tif
# Doing Image iv050.tif
# Doing Image iv004.tif
# Doing Image n027.tif
# Doing Image n039.tif
# Doing Image n078.tif
# Doing Image n098.tif
# Doing Image n099.tif
# Doing Image n077.tif
# Doing Image n008.tif
# Doing Image n047.tif
# Doing Image n058.tif
# Doing Image n080.tif
# Doing Image n087.tif
# Doing Image n066.tif
# Doing Image n045.tif
# Doing Image n022.tif
# Doing Image n073.tif
# Doing Image n076.tif
# Doing Image n082.tif
# Doing Image n060.tif
# Doing Image n050.tif
# Doing Image n004.tif
# Doing Image b074.tif
# Doing Image b035.tif
# Doing Image b094.tif
# Doing Image b024.tif
# Doing Image b096.tif
# Doing Image b092.tif
# Doing Image b052.tif
# Doing Image b019.tif
# Doing Image b093.tif
# Doing Image b048.tif
# Doing Image b063.tif
# Doing Image b044.tif
# Doing Image b081.tif
# Doing Image b049.tif
# Doing Image b017.tif
# Doing Image b067.tif
# Doing Image b040.tif
# Doing Image b026.tif
# Doing Image b068.tif
# Doing Image b007.tif
# Doing Image is074.tif
# Doing Image is035.tif
# Doing Image is094.tif
# Doing Image is024.tif
# Doing Image is096.tif
# Doing Image is092.tif
# Doing Image is052.tif
# Doing Image is019.tif
# Doing Image is093.tif
# Doing Image is048.tif
# Doing Image is063.tif
# Doing Image is044.tif
# Doing Image is081.tif
# Doing Image is049.tif
# Doing Image is017.tif
# Doing Image is067.tif
# Doing Image is040.tif
# Doing Image is026.tif
# Doing Image is068.tif
# Doing Image is007.tif
# Doing Image iv074.tif
# Doing Image iv035.tif
# Doing Image iv094.tif
# Doing Image iv024.tif
# Doing Image iv096.tif
# Doing Image iv092.tif
# Doing Image iv052.tif
# Doing Image iv019.tif
# Doing Image iv093.tif
# Doing Image iv048.tif
# Doing Image iv063.tif
# Doing Image iv044.tif
# Doing Image iv081.tif
# Doing Image iv049.tif
# Doing Image iv017.tif
# Doing Image iv067.tif
# Doing Image iv040.tif
# Doing Image iv026.tif
# Doing Image iv068.tif
# Doing Image iv007.tif
# Doing Image n074.tif
# Doing Image n035.tif
# Doing Image n094.tif
# Doing Image n024.tif
# Doing Image n096.tif
# Doing Image n092.tif
# Doing Image n052.tif
# Doing Image n019.tif
# Doing Image n093.tif
# Doing Image n048.tif
# Doing Image n063.tif
# Doing Image n044.tif
# Doing Image n081.tif
# Doing Image n049.tif
# Doing Image n017.tif
# Doing Image n067.tif
# Doing Image n040.tif
# Doing Image n026.tif
# Doing Image n068.tif
# Doing Image n007.tif
